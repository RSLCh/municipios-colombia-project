# %% [markdown]
# # Creación de Dataset de Municipios de Colombia

# %% [markdown]
# #### Tarea #1: Obtener la información para un municipio

# %%
# Importar librerías principales

import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import pickle

# %%
# Cargar el contenido de la pagina web (Recurso: Wikipedia)
w = requests.get("https://es.wikipedia.org/wiki/Bogot%C3%A1")

# Convertir a un objeto "BeautifulSoup"
bsobj = bs(w.content)

# Imprimir (Revisar estructura del código html)
print(bsobj.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="es">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Bogotá - Wikipedia, la enciclopedia libre
#   </title>
#   <script>
#    document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":[",\t."," \t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","enero","febrero","marzo","abril","mayo","junio","julio","agosto","septiembre","octubre","noviembre","diciembre"],"wgRequestId":"eb5ee6e5-ea46-4f19-81b1-3d2d8652a5d8","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Bogotá","wgTitle":"Bogotá","wgCurRevisionId":137593937,"wgRevisionId":137593937,"wgArticleId":5131,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia:Páginas que utilizan Timeline","Wikipedia:Páginas con referencias con parámetros obsoletos","Wikipedia:Artículos con enlaces externos rotos","Wikipedia:Páginas con enlaces mágicos de ISBN","Wikipedia:Artículos con datos por trasladar a Wikidata",
# "Wikipedia:Artículos con datos locales","Wikipedia:Artículos con pasajes que requieren referencias","Wikipedia:Artículos buenos en la Wikipedia en esperanto","Wikipedia:Artículos buenos en la Wikipedia en alemán","Wikipedia:Artículos con ficha sin actualizar","Páginas con panorama","Wikipedia:Artículos que necesitan referencias","Wikipedia:Referenciar (aún sin clasificar)","Wikipedia:Artículos con extractos","Wikipedia:Artículos grabados","Wikipedia:Artículos con identificadores VIAF","Wikipedia:Artículos con identificadores ISNI","Wikipedia:Artículos con identificadores BNE","Wikipedia:Artículos con identificadores BNF","Wikipedia:Artículos con identificadores GND","Wikipedia:Artículos con identificadores LCCN","Wikipedia:Artículos con identificadores Relación OSM","Wikipedia:Artículos con identificadores TGN","Wikipedia:Control de autoridades con 17 elementos","Wikipedia:Páginas con gráficos","Bogotá"],"wgPageContentLanguage":"es","wgPageContentModel":
# "wikitext","wgRelevantPageName":"Bogotá","wgRelevantArticleId":5131,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsFlags":10,"wgVisualEditor":{"pageLanguageCode":"es","pageLanguageDir":"ltr","pageVariantFallbacks":"es"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!0},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"español","wgNoticeProject":"wikipedia","wgGraphSpecs":{"c9e97389018d9d7efc6e3034d448f17068f9313a":{"legends":[],"scales":[{"domain":{"data":"chart","field":"x"},"type":"ordinal","name":"color","range":["purple","blue","grey","yellowgreen","#2ca02c","#98df8a","#d62728","#ff9896","#9467bd","#c5b0d5","#8c564b","#c49c94","#e377c2","#f7b6d2","#7f7f7f","#c7c7c7","#bcbd22","#dbdb8d","#17becf","#9edae5"]}],"version":2,"marks":[{"type":"arc","properties":{"hover":{"fill":{
# "value":"red"}},"update":{"fill":{"scale":"color","field":"x"}},"enter":{"endAngle":{"field":"layout_end"},"innerRadius":{"value":0},"outerRadius":{"value":100},"startAngle":{"field":"layout_start"},"stroke":{"value":"white"},"fill":{"scale":"color","field":"x"},"strokeWidth":{"value":1}}},"from":{"data":"chart","transform":[{"type":"pie","field":"y"}]}}],"height":100,"axes":[],"data":[{"format":{"parse":{"y":"number","x":"string"},"type":"json"},"name":"chart","values":[{"y":65.9,"x":"[[Católico]] (65"},{"y":23.5,"x":"9\u0026nbsp;%)"},{"y":8.1,"x":"[[Protestante]] (23"},{"y":2.5,"x":"5\u0026nbsp;%)"},{"x":"Ninguna (8"},{"x":"1\u0026nbsp;%)"},{"x":"otras (2"},{"x":"5\u0026nbsp;%)"}]}],"width":100}},"wgCoordinates":{"lat":4.6126388888889,"lon":-74.0705},"wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":!0,"wgGENewcomerTasksGuidanceEnabled":!0,"wgGEAskQuestionEnabled":!1,
# "wgGELinkRecommendationsFrontendEnabled":!0,"wgWikibaseItemId":"Q2841"};RLSTATE={"ext.gadget.imagenesinfobox":"ready","ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","ext.timeline.styles":"ready","mediawiki.page.gallery.styles":"ready","ext.tmh.thumbnail.styles":"ready","ext.graph.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","mediawiki.page.gallery","mw.MediaWikiPlayer.loader","mw.PopUpMediaTransform","mw.TMHGalleryHook.js","ext.graph.vega2","ext.scribunto.logs","site","mediawiki.page.ready","jquery.tablesorter","mediawiki.toc","skins.vector.legacy.js","ext.gadget.a-commons-directo",
# "ext.gadget.ReferenceTooltips","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.growthExperiments.SuggestedEditSession"];
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});mw.user.options.set({"variant":"es"});
# });});
#   </script>
#   <link href="/w/load.php?lang=es&amp;modules=ext.cite.styles%7Cext.graph.styles%7Cext.timeline.styles%7Cext.tmh.thumbnail.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cmediawiki.page.gallery.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <script async="" src="/w/load.php?lang=es&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector">
#   </script>
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="/w/load.php?lang=es&amp;modules=ext.gadget.imagenesinfobox&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <link href="/w/load.php?lang=es&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <noscript>
#    <link href="/w/load.php?lang=es&amp;modules=noscript&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   </noscript>
#   <meta content="MediaWiki 1.37.0-wmf.17" name="generator"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="origin-when-crossorigin" name="referrer"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Centro_internacional.JPG/1200px-Centro_internacional.JPG" property="og:image"/>
#   <meta content="Bogotá - Wikipedia, la enciclopedia libre" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <link href="//upload.wikimedia.org" rel="preconnect"/>
#   <link href="//es.m.wikipedia.org/wiki/Bogot%C3%A1" media="only screen and (max-width: 720px)" rel="alternate"/>
#   <link href="/w/index.php?title=Bogot%C3%A1&amp;action=edit" rel="alternate" title="Editar" type="application/x-wiki"/>
#   <link href="/w/index.php?title=Bogot%C3%A1&amp;action=edit" rel="edit" title="Editar"/>
#   <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
#   <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
#   <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (es)" type="application/opensearchdescription+xml"/>
#   <link href="//es.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <link href="//creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
#   <link href="https://es.wikipedia.org/wiki/Bogot%C3%A1" rel="canonical"/>
#   <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#   <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
#  </head>
#  <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-Bogotá rootpage-Bogotá skin-vector action-view skin-vector-legacy">
#   <div class="noprint" id="mw-page-base">
#   </div>
#   <div class="noprint" id="mw-head-base">
#   </div>
#   <div class="mw-body" id="content" role="main">
#    <a id="top">
#    </a>
#    <div id="siteNotice">
#     <!-- CentralNotice -->
#    </div>
#    <div class="mw-indicators">
#     <div class="mw-indicator" id="mw-indicator-spoken-icon">
#      <a href="//es.wikipedia.org/wiki/Wikiproyecto:Wikipedia_grabada" title="Existe una versión en audio de este artículo. Haz clic aquí para saber más">
#       <img alt="Existe una versión en audio de este artículo. Haz clic aquí para saber más" data-file-height="96" data-file-width="128" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/47/Sound-icon.svg/18px-Sound-icon.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/47/Sound-icon.svg/27px-Sound-icon.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/47/Sound-icon.svg/36px-Sound-icon.svg.png 2x" width="18"/>
#      </a>
#     </div>
#    </div>
#    <h1 class="firstHeading" id="firstHeading">
#     Bogotá
#    </h1>
#    <div class="vector-body" id="bodyContent">
#     <div class="noprint" id="siteSub">
#      De Wikipedia, la enciclopedia libre
#     </div>
#     <div id="contentSub">
#     </div>
#     <div id="contentSub2">
#     </div>
#     <div id="jump-to-nav">
#     </div>
#     <a class="mw-jump-link" href="#mw-head">
#      Ir a la navegación
#     </a>
#     <a class="mw-jump-link" href="#searchInput">
#      Ir a la búsqueda
#     </a>
#     <div class="mw-body-content mw-content-ltr" dir="ltr" id="mw-content-text" lang="es">
#      <div class="mw-parser-output">
#       <div class="rellink noprint hatnote">
#        Para otros usos de este término, véase
#        <a class="mw-disambig" href="/wiki/Bogot%C3%A1_(desambiguaci%C3%B3n)" title="Bogotá (desambiguación)">
#         Bogotá (desambiguación)
#        </a>
#        .
#       </div>
#       <div class="rellink noprint hatnote">
#        «Santafé» redirige aquí. Para otras acepciones, véase
#        <a class="mw-disambig" href="/wiki/Santa_Fe" title="Santa Fe">
#         Santa Fe
#        </a>
#        .
#       </div>
#       <table class="infobox geography vcard" style="width:22.7em; line-height: 1.4em; text-align:left; padding:.23em;">
#        <tbody>
#         <tr>
#          <th class="cabecera mapa fn org" colspan="3" style="text-align:center;background-color:transparent;color:black;padding:0;">
#           Bogotá
#          </th>
#         </tr>
#         <tr>
#          <td colspan="3" style="text-align:center;font-size:100%; font-weight:bold; background-color:#cddeff;">
#           <a href="/wiki/Capital_(pol%C3%ADtica)" title="Capital (política)">
#            Capital
#           </a>
#           de
#           <a href="/wiki/Colombia" title="Colombia">
#            Colombia
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td colspan="3" style="text-align:center;">
#           <table align="right" bgcolor="white" cellspacing="0" style="border:1px solid white">
#            <tbody>
#             <tr>
#              <td style="padding:2px 0px 0px 2px">
#               <table bgcolor="white" cellspacing="0" style="border:0px">
#                <tbody>
#                 <tr>
#                  <td style="padding:0px 2px 2px 0px">
#                   <a class="image" href="/wiki/Archivo:Centro_internacional.JPG" title="Centro">
#                    <img alt="Centro" data-file-height="1080" data-file-width="1920" decoding="async" height="152" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Centro_internacional.JPG/270px-Centro_internacional.JPG" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Centro_internacional.JPG/405px-Centro_internacional.JPG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Centro_internacional.JPG/540px-Centro_internacional.JPG 2x" width="270"/>
#                   </a>
#                  </td>
#                 </tr>
#                </tbody>
#               </table>
#               <table bgcolor="white" cellspacing="0" style="border:0px">
#                <tbody>
#                 <tr>
#                  <td style="padding:0px 2px 2px 0px">
#                   <a class="image" href="/wiki/Archivo:Casa_Cural_de_la_Catedral_2.jpg" title="La Candelaria">
#                    <img alt="La Candelaria" data-file-height="1536" data-file-width="2048" decoding="async" height="101" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Casa_Cural_de_la_Catedral_2.jpg/134px-Casa_Cural_de_la_Catedral_2.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Casa_Cural_de_la_Catedral_2.jpg/201px-Casa_Cural_de_la_Catedral_2.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Casa_Cural_de_la_Catedral_2.jpg/268px-Casa_Cural_de_la_Catedral_2.jpg 2x" width="134"/>
#                   </a>
#                  </td>
#                  <td style="padding:0px 2px 2px 0px">
#                   <a class="image" href="/wiki/Archivo:Movistar_Arena,_lugar_de_conciertos_y_eventos_de_todo_tipo,_en_Bogot%C3%A1.jpg" title="arena">
#                    <img alt="arena" data-file-height="3120" data-file-width="4160" decoding="async" height="101" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/02/Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg/134px-Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/02/Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg/201px-Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/02/Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg/268px-Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg 2x" width="134"/>
#                   </a>
#                  </td>
#                 </tr>
#                </tbody>
#               </table>
#               <table bgcolor="white" cellspacing="0" style="border:0px">
#                <tbody>
#                 <tr>
#                  <td style="padding:0px 2px 2px 0px">
#                   <a class="image" href="/wiki/Archivo:Entrada_del_Museo_Nacional_de_Colombia.jpg" title="Museo Nacional de Colombia">
#                    <img alt="Museo Nacional de Colombia" data-file-height="2736" data-file-width="3648" decoding="async" height="101" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/90/Entrada_del_Museo_Nacional_de_Colombia.jpg/134px-Entrada_del_Museo_Nacional_de_Colombia.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/90/Entrada_del_Museo_Nacional_de_Colombia.jpg/201px-Entrada_del_Museo_Nacional_de_Colombia.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/90/Entrada_del_Museo_Nacional_de_Colombia.jpg/268px-Entrada_del_Museo_Nacional_de_Colombia.jpg 2x" width="134"/>
#                   </a>
#                  </td>
#                  <td style="padding:0px 2px 2px 0px">
#                   <a class="image" href="/wiki/Archivo:Fachada_Capitolio.jpg" title="Fachada del Capitolio Nacional de Colombia">
#                    <img alt="Fachada del Capitolio Nacional de Colombia" data-file-height="2134" data-file-width="2848" decoding="async" height="100" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Fachada_Capitolio.jpg/134px-Fachada_Capitolio.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Fachada_Capitolio.jpg/201px-Fachada_Capitolio.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Fachada_Capitolio.jpg/268px-Fachada_Capitolio.jpg 2x" width="134"/>
#                   </a>
#                  </td>
#                 </tr>
#                </tbody>
#               </table>
#               <table bgcolor="white" cellspacing="0" style="border:0px">
#                <tbody>
#                 <tr>
#                  <td style="padding:0px 2px 2px 0px">
#                   <a class="image" href="/wiki/Archivo:Santa_Barbara,_Bogot%C3%A1.png" title="Santa Bárbara, Usaquén, Bogotá.">
#                    <img alt="Santa Bárbara, Usaquén, Bogotá." data-file-height="960" data-file-width="720" decoding="async" height="179" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Santa_Barbara%2C_Bogot%C3%A1.png/134px-Santa_Barbara%2C_Bogot%C3%A1.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Santa_Barbara%2C_Bogot%C3%A1.png/201px-Santa_Barbara%2C_Bogot%C3%A1.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Santa_Barbara%2C_Bogot%C3%A1.png/268px-Santa_Barbara%2C_Bogot%C3%A1.png 2x" width="134"/>
#                   </a>
#                  </td>
#                  <td style="padding:0px 2px 2px 0px">
#                   <a class="image" href="/wiki/Archivo:Monserrate.jpg" title="Basicilica de nuestro señor caído de Monserrate.">
#                    <img alt="Basicilica de nuestro señor caído de Monserrate." data-file-height="980" data-file-width="720" decoding="async" height="182" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/7b/Monserrate.jpg/134px-Monserrate.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/7b/Monserrate.jpg/201px-Monserrate.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/7b/Monserrate.jpg/268px-Monserrate.jpg 2x" width="134"/>
#                   </a>
#                  </td>
#                 </tr>
#                </tbody>
#               </table>
#              </td>
#             </tr>
#            </tbody>
#           </table>
#           <br/>
#           <span style="font-size:smaller">
#            Desde arriba y de izquierda a derecha:
#            <a href="/wiki/Centro_Internacional_de_Bogot%C3%A1" title="Centro Internacional de Bogotá">
#             Centro Internacional de Bogotá
#            </a>
#            ,
#            <a href="/wiki/La_Candelaria" title="La Candelaria">
#             La Candelaria
#            </a>
#            ,
#            <a class="mw-redirect" href="/wiki/Movistar_Arena_(Bogot%C3%A1)" title="Movistar Arena (Bogotá)">
#             Movistar Arena
#            </a>
#            , el
#            <a href="/wiki/Museo_Nacional_de_Colombia" title="Museo Nacional de Colombia">
#             Museo Nacional de Colombia
#            </a>
#            ,
#            <a href="/wiki/Capitolio_Nacional_de_Colombia" title="Capitolio Nacional de Colombia">
#             Capitolio Nacional de Colombia
#            </a>
#            , Barrio Santa Barbará en
#            <a href="/wiki/Usaqu%C3%A9n" title="Usaquén">
#             Usaquén
#            </a>
#            y Monasterio de
#            <a href="/wiki/Monserrate" title="Monserrate">
#             Monserrate
#            </a>
#           </span>
#           <br/>
#           <div style="display:inline;font-size:smaller; font-weight:normal;">
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td colspan="3" style="align:center;">
#           <br/>
#           <table class="mergedrow" style="width:100%;">
#            <tbody>
#             <tr>
#              <td style="text-align:center;background-color:transparent;align:center;vertical-align:middle;">
#               <a class="image" href="/wiki/Archivo:Flag_of_Bogot%C3%A1.svg">
#                <img alt="Flag of Bogotá.svg" class="thumbborder" data-file-height="500" data-file-width="750" decoding="async" height="67" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Flag_of_Bogot%C3%A1.svg/100px-Flag_of_Bogot%C3%A1.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Flag_of_Bogot%C3%A1.svg/150px-Flag_of_Bogot%C3%A1.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Flag_of_Bogot%C3%A1.svg/200px-Flag_of_Bogot%C3%A1.svg.png 2x" width="100"/>
#               </a>
#               <br/>
#               <div style="display:inline;font-size:smaller; font-weight:bold;">
#                <a href="/wiki/Bandera_de_Bogot%C3%A1" title="Bandera de Bogotá">
#                 Bandera
#                </a>
#               </div>
#              </td>
#              <td style="text-align:center;align:center;vertical-align:middle;background-color:transparent;">
#               <a class="image" href="/wiki/Archivo:Escudo_de_Armas_de_Bogota.svg">
#                <img alt="Escudo de Armas de Bogota.svg" data-file-height="425" data-file-width="354" decoding="async" height="88" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Escudo_de_Armas_de_Bogota.svg/73px-Escudo_de_Armas_de_Bogota.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Escudo_de_Armas_de_Bogota.svg/110px-Escudo_de_Armas_de_Bogota.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Escudo_de_Armas_de_Bogota.svg/147px-Escudo_de_Armas_de_Bogota.svg.png 2x" width="73"/>
#               </a>
#               <br/>
#               <div style="display:inline;font-size:smaller; font-weight:bold;">
#                <a href="/wiki/Escudo_de_Bogot%C3%A1" title="Escudo de Bogotá">
#                 Escudo
#                </a>
#               </div>
#               <br/>
#              </td>
#             </tr>
#            </tbody>
#           </table>
#          </td>
#         </tr>
#         <tr>
#          <td colspan="3" style="text-align:center;padding:2px 7px 1px 1px;">
#           <a href="/wiki/Apodo" title="Apodo">
#            Otros nombres
#           </a>
#           :
#           <span style="font-style:italic">
#            La Atenas Suramericana.
#            <br/>
#            La Ciudad de Todos.
#            <br/>
#            La Capital Mundial del Teatro.
#            <sup class="reference separada" id="cite_ref-8">
#             <a href="#cite_note-8">
#              <span class="corchete-llamada">
#               [
#              </span>
#              8
#              <span class="corchete-llamada">
#               ]
#              </span>
#             </a>
#            </sup>
#            ​ Muy Noble y Muy Leal Ciudad.
#            <sup class="reference separada" id="cite_ref-9">
#             <a href="#cite_note-9">
#              <span class="corchete-llamada">
#               [
#              </span>
#              9
#              <span class="corchete-llamada">
#               ]
#              </span>
#             </a>
#            </sup>
#            ​
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td colspan="3" style="text-align:center;padding:2px 7px 1px 1px;">
#           <a class="mw-redirect" href="/wiki/Anexo:Lemas_de_Estado" title="Anexo:Lemas de Estado">
#            Lema
#           </a>
#           : 2600 metros más cerca de las estrellas.
#           <sup class="reference separada" id="cite_ref-10">
#            <a href="#cite_note-10">
#             <span class="corchete-llamada">
#              [
#             </span>
#             10
#             <span class="corchete-llamada">
#              ]
#             </span>
#            </a>
#           </sup>
#           ​
#          </td>
#         </tr>
#         <tr>
#          <td colspan="3" style="text-align:center;padding:2px 7px 1px 1px;">
#           <a href="/wiki/Himno" title="Himno">
#            Himno
#           </a>
#           :
#           <a href="/wiki/Himno_de_Bogot%C3%A1" title="Himno de Bogotá">
#            Himno de Bogotá
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td colspan="3" style="text-align:center;padding:0.8em 0.7em; text-align:center;">
#           <div class="center">
#            <div style="width:250px;float:none;clear:both;margin-left:auto;margin-right:auto">
#             <div style="width:250px;padding:0">
#              <div style="position:relative;width:250px">
#               <a class="image" href="/wiki/Archivo:Colombia_location_map.svg">
#                <img alt="Bogotá ubicada en Colombia" data-file-height="2294" data-file-width="2027" decoding="async" height="283" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/8f/Colombia_location_map.svg/250px-Colombia_location_map.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/8f/Colombia_location_map.svg/375px-Colombia_location_map.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/8f/Colombia_location_map.svg/500px-Colombia_location_map.svg.png 2x" width="250"/>
#               </a>
#               <div style="position:absolute;top:56.508%;left:58.888%;height:0;width:0;margin:0;padding:0">
#                <div style="position:absolute;text-align:center;left:-3px;top:-3px;width:5px;font-size:5px;line-height:0">
#                 <img alt="Bogotá" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/5px-Red_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/8px-Red_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/10px-Red_pog.svg.png 2x" title="Bogotá" width="5"/>
#                </div>
#                <div style="font-size:90%;line-height:110%;position:absolute;width:6em;top:-0.75em;left:4px;text-align:left">
#                 <span style="padding:1px;float:left">
#                  Bogotá
#                 </span>
#                </div>
#               </div>
#              </div>
#              <div style="font-size:90%;padding-top:3px">
#              </div>
#             </div>
#            </div>
#           </div>
#           <div style="display:inline;font-size:smaller; font-weight:bold;">
#            Localización de Bogotá en Colombia
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td colspan="3" style="text-align:center;padding:0.8em 0.7em; text-align:center;">
#           <a class="image" href="/wiki/Archivo:Colombia_Distrito_Capital_location_map_(%2Burban_areas_%2Blocator_map).svg">
#            <img alt="Colombia Distrito Capital location map (+urban areas +locator map).svg" data-file-height="1331" data-file-width="602" decoding="async" height="542" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Colombia_Distrito_Capital_location_map_%28%2Burban_areas_%2Blocator_map%29.svg/245px-Colombia_Distrito_Capital_location_map_%28%2Burban_areas_%2Blocator_map%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Colombia_Distrito_Capital_location_map_%28%2Burban_areas_%2Blocator_map%29.svg/368px-Colombia_Distrito_Capital_location_map_%28%2Burban_areas_%2Blocator_map%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Colombia_Distrito_Capital_location_map_%28%2Burban_areas_%2Blocator_map%29.svg/490px-Colombia_Distrito_Capital_location_map_%28%2Burban_areas_%2Blocator_map%29.svg.png 2x" width="245"/>
#           </a>
#           <br/>
#           <div style="display:inline;font-size:smaller; font-weight:bold;">
#            Bogotá y su área urbana
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#           <a href="/wiki/Coordenadas_geogr%C3%A1ficas" title="Coordenadas geográficas">
#            Coordenadas
#           </a>
#          </th>
#          <td colspan="2" style="padding:2px 7px 1px 1px;">
#           <span class="plainlinks nourlexpansion">
#            <a class="external text" href="http://tools.wmflabs.org/geohack/geohack.php?language=es&amp;pagename=Bogot%C3%A1&amp;params=4.6126388888889_N_-74.0705_E_type:city">
#             <span class="geo-default">
#              <span class="geo-dms" title="Mapas, fotos y otros datos de 4°36′46″N 74°04′14″O">
#               <span class="latitude">
#                4°36′46″N
#               </span>
#               <span class="longitude">
#                74°04′14″O
#               </span>
#              </span>
#             </span>
#             <span class="geo-multi-punct">
#              ﻿ / ﻿
#             </span>
#             <span class="geo-nondefault">
#              <span class="geo-dec" title="Mapas, fotos y otros datos de 4.6126388888889 -74.0705">
#               <span class="geo">
#                <span class="latitude">
#                 4.6126388888889,
#                </span>
#                <span class="longitude">
#                 -74.0705
#                </span>
#               </span>
#              </span>
#             </span>
#            </a>
#           </span>
#           <span style="font-size: small;">
#            <span id="coordinates">
#             <a href="/wiki/Coordenadas_geogr%C3%A1ficas" title="Coordenadas geográficas">
#              Coordenadas
#             </a>
#             :
#             <span class="plainlinks nourlexpansion">
#              <a class="external text" href="http://tools.wmflabs.org/geohack/geohack.php?language=es&amp;pagename=Bogot%C3%A1&amp;params=4.6126388888889_N_-74.0705_E_type:city">
#               <span class="geo-default">
#                <span class="geo-dms" title="Mapas, fotos y otros datos de 4°36′46″N 74°04′14″O">
#                 <span class="latitude">
#                  4°36′46″N
#                 </span>
#                 <span class="longitude">
#                  74°04′14″O
#                 </span>
#                </span>
#               </span>
#               <span class="geo-multi-punct">
#                ﻿ / ﻿
#               </span>
#               <span class="geo-nondefault">
#                <span class="geo-dec" title="Mapas, fotos y otros datos de 4.6126388888889 -74.0705">
#                 <span class="geo">
#                  <span class="latitude">
#                   4.6126388888889,
#                  </span>
#                  <span class="longitude">
#                   -74.0705
#                  </span>
#                 </span>
#                </span>
#               </span>
#              </a>
#             </span>
#            </span>
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#           <a href="/wiki/Idioma_oficial" title="Idioma oficial">
#            Idioma oficial
#           </a>
#          </th>
#          <td colspan="2" style="padding:2px 7px 1px 1px;">
#           <a href="/wiki/Idioma_espa%C3%B1ol" title="Idioma español">
#            Español
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#           <a class="mw-redirect" href="/wiki/Entidad_subnacional" title="Entidad subnacional">
#            Entidad
#           </a>
#          </th>
#          <td colspan="2" style="padding:2px 7px 1px 1px;">
#           <a href="/wiki/Capital_(pol%C3%ADtica)" title="Capital (política)">
#            Capital
#           </a>
#           de
#           <a href="/wiki/Colombia" title="Colombia">
#            Colombia
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#           •
#           <a href="/wiki/Anexo:Pa%C3%ADses" title="Anexo:Países">
#            País
#           </a>
#          </th>
#          <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#           <span class="flagicon">
#            <img alt="Bandera de Colombia" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/20px-Flag_of_Colombia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/30px-Flag_of_Colombia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/40px-Flag_of_Colombia.svg.png 2x" title="Bandera de Colombia" width="20"/>
#           </span>
#           <a href="/wiki/Colombia" title="Colombia">
#            Colombia
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#           •
#           <a href="/wiki/Departamentos_de_Colombia" title="Departamentos de Colombia">
#            Departamento
#           </a>
#          </th>
#          <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#           <span class="flagicon">
#            <img alt="Bandera de Cundinamarca" class="thumbborder" data-file-height="500" data-file-width="750" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/65/Flag_of_Cundinamarca.svg/20px-Flag_of_Cundinamarca.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/65/Flag_of_Cundinamarca.svg/30px-Flag_of_Cundinamarca.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/65/Flag_of_Cundinamarca.svg/40px-Flag_of_Cundinamarca.svg.png 2x" title="Bandera de Cundinamarca" width="20"/>
#           </span>
#           <a href="/wiki/Cundinamarca" title="Cundinamarca">
#            Cundinamarca
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#           •
#           <a href="/wiki/Distritos_de_Colombia" title="Distritos de Colombia">
#            Distrito
#           </a>
#          </th>
#          <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#           <span class="flagicon">
#            <img alt="Flag of Bogotá.svg" class="thumbborder" data-file-height="500" data-file-width="750" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Flag_of_Bogot%C3%A1.svg/20px-Flag_of_Bogot%C3%A1.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Flag_of_Bogot%C3%A1.svg/30px-Flag_of_Bogot%C3%A1.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Flag_of_Bogot%C3%A1.svg/40px-Flag_of_Bogot%C3%A1.svg.png 2x" width="20"/>
#           </span>
#           <a href="/wiki/Distrito_capital" title="Distrito capital">
#            Capital
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#           <a href="/wiki/Alcalde_de_Bogot%C3%A1" title="Alcalde de Bogotá">
#            Alcaldesa
#           </a>
#          </th>
#          <td colspan="2" style="padding:2px 7px 1px 1px;">
#           <a class="mw-redirect" href="/wiki/Claudia_Nayibe_L%C3%B3pez_Hern%C3%A1ndez" title="Claudia Nayibe López Hernández">
#            Claudia López
#           </a>
#           <br/>
#           (
#           <a class="mw-redirect" href="/wiki/Partido_Verde_(Colombia)" title="Partido Verde (Colombia)">
#            AV
#           </a>
#           )
#           <a class="image" href="/wiki/Archivo:Alianza_Verde.png">
#            <img alt="Alianza Verde.png" data-file-height="124" data-file-width="292" decoding="async" height="8" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/7e/Alianza_Verde.png/20px-Alianza_Verde.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/7e/Alianza_Verde.png/30px-Alianza_Verde.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/7e/Alianza_Verde.png/40px-Alianza_Verde.png 2x" width="20"/>
#           </a>
#           <small>
#            (
#            <a href="/wiki/2020" title="2020">
#             2020
#            </a>
#            -
#            <a href="/wiki/2023" title="2023">
#             2023
#            </a>
#            )
#           </small>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#           Subdivisiones
#          </th>
#          <td colspan="2" style="padding:2px 7px 1px 1px;">
#           20
#           <a href="/wiki/Anexo:Localidades_de_Bogot%C3%A1" title="Anexo:Localidades de Bogotá">
#            localidades
#           </a>
#           <br/>
#           1922
#           <a href="/wiki/Barrio" title="Barrio">
#            barrios
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#           Localidades
#          </th>
#          <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#           <div class="NavFrame collapsed" style="border:none; padding: 0;">
#            <div align="left" class="NavHead" style="width:100%; background:transparent">
#             Ver lista
#            </div>
#            <div class="NavContent" style="text-align:left;">
#             <a href="/wiki/Usaqu%C3%A9n" title="Usaquén">
#              Usaquén
#             </a>
#             <br/>
#             <a href="/wiki/Chapinero" title="Chapinero">
#              Chapinero
#             </a>
#             <br/>
#             <a href="/wiki/Santa_Fe_(Bogot%C3%A1)" title="Santa Fe (Bogotá)">
#              Santa Fe
#             </a>
#             <br/>
#             <a href="/wiki/San_Crist%C3%B3bal_(Bogot%C3%A1)" title="San Cristóbal (Bogotá)">
#              San Cristóbal
#             </a>
#             <br/>
#             <a href="/wiki/Usme" title="Usme">
#              Usme
#             </a>
#             <br/>
#             <a href="/wiki/Tunjuelito" title="Tunjuelito">
#              Tunjuelito
#             </a>
#             <br/>
#             <a href="/wiki/Bosa_(Bogot%C3%A1)" title="Bosa (Bogotá)">
#              Bosa
#             </a>
#             <br/>
#             <a href="/wiki/Kennedy_(Bogot%C3%A1)" title="Kennedy (Bogotá)">
#              Kennedy
#             </a>
#             <br/>
#             <a href="/wiki/Fontib%C3%B3n" title="Fontibón">
#              Fontibón
#             </a>
#             <br/>
#             <a href="/wiki/Engativ%C3%A1" title="Engativá">
#              Engativá
#             </a>
#             <br/>
#             <a href="/wiki/Suba" title="Suba">
#              Suba
#             </a>
#             <br/>
#             <a href="/wiki/Barrios_Unidos_(Bogot%C3%A1)" title="Barrios Unidos (Bogotá)">
#              Barrios Unidos
#             </a>
#             <br/>
#             <a href="/wiki/Teusaquillo" title="Teusaquillo">
#              Teusaquillo
#             </a>
#             <br/>
#             <a href="/wiki/Los_M%C3%A1rtires" title="Los Mártires">
#              Los Mártires
#             </a>
#             <br/>
#             <a href="/wiki/Antonio_Nari%C3%B1o_(Bogot%C3%A1)" title="Antonio Nariño (Bogotá)">
#              Antonio Nariño
#             </a>
#             <br/>
#             <a href="/wiki/Puente_Aranda" title="Puente Aranda">
#              Puente Aranda
#             </a>
#             <br/>
#             <a href="/wiki/La_Candelaria" title="La Candelaria">
#              La Candelaria
#             </a>
#             <small>
#              (Centro Histórico)
#             </small>
#             <br/>
#             <a href="/wiki/Rafael_Uribe_Uribe_(Bogot%C3%A1)" title="Rafael Uribe Uribe (Bogotá)">
#              Rafael Uribe Uribe
#             </a>
#             <br/>
#             <a href="/wiki/Ciudad_Bol%C3%ADvar_(Bogot%C3%A1)" title="Ciudad Bolívar (Bogotá)">
#              Ciudad Bolívar
#             </a>
#             <br/>
#             <a href="/wiki/Sumapaz_(Bogot%C3%A1)" title="Sumapaz (Bogotá)">
#              Sumapaz
#             </a>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#           Eventos históricos
#          </th>
#          <td colspan="2" style="padding:2px 7px 1px 1px;">
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#           • Fundación
#          </th>
#          <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#           6 de agosto de 1538 (483 años)
#           <br/>
#           <span style="font-size:90%">
#            (
#            <a href="/wiki/Gonzalo_Jim%C3%A9nez_de_Quesada" title="Gonzalo Jiménez de Quesada">
#             Gonzalo Jiménez de Quesada
#            </a>
#            )
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#           • Erección
#          </th>
#          <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#           3 de diciembre de 1548 (472 años)
#           <br/>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#           • Creación
#          </th>
#          <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#           17 de diciembre de 1954 (66 años) (conformación del
#           <a href="/wiki/Distrito_Especial_de_Bogot%C3%A1" title="Distrito Especial de Bogotá">
#            Distrito Capital
#           </a>
#           )
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#           <a href="/wiki/%C3%81rea" title="Área">
#            Superficie
#           </a>
#          </th>
#          <td colspan="2" style="padding:2px 7px 1px 1px;">
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#           • Total
#          </th>
#          <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#           1775
#           <a href="/wiki/Kil%C3%B3metro_cuadrado" title="Kilómetro cuadrado">
#            km²
#           </a>
#           <sup class="reference separada" id="cite_ref-GB_1-0">
#            <a href="#cite_note-GB-1">
#             <span class="corchete-llamada">
#              [
#             </span>
#             1
#             <span class="corchete-llamada">
#              ]
#             </span>
#            </a>
#           </sup>
#           ​
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#           <a href="/wiki/Altitud" title="Altitud">
#            Altitud
#           </a>
#          </th>
#          <td colspan="2" style="padding:2px 7px 1px 1px;">
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#           • Media
#          </th>
#          <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#           2640
#           <a class="mw-redirect" href="/wiki/Msnm" title="Msnm">
#            m s. n. m.
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#           • Máxima
#          </th>
#          <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#           4000
#           <sup class="reference separada" id="cite_ref-2">
#            <a href="#cite_note-2">
#             <span class="corchete-llamada">
#              [
#             </span>
#             2
#             <span class="corchete-llamada">
#              ]
#             </span>
#            </a>
#           </sup>
#           ​ m s. n. m.
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#           • Mínima
#          </th>
#          <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#           2540
#           <sup>
#            [
#            <i>
#             <a href="/wiki/Wikipedia:Verificabilidad" title="Wikipedia:Verificabilidad">
#              cita requerida
#             </a>
#            </i>
#            ]
#           </sup>
#           m s. n. m.
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#           <a href="/wiki/Clima" title="Clima">
#            Clima
#           </a>
#          </th>
#          <td colspan="2" style="padding:2px 7px 1px 1px;">
#           <a href="/wiki/Clima_mediterr%C3%A1neo#Mediterráneo_con_influencia_oceánica_(Csb)" title="Clima mediterráneo">
#            Oceánico mediterráneo
#            <i>
#             Csb
#            </i>
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#           <a href="/wiki/Poblaci%C3%B3n" title="Población">
#            Población
#           </a>
#           (2020)
#          </th>
#          <td colspan="2" style="padding:2px 7px 1px 1px;">
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#           • Total
#          </th>
#          <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#           7 743 955 hab.
#           <sup class="reference separada" id="cite_ref-El_Tiempo_3-0">
#            <a href="#cite_note-El_Tiempo-3">
#             <span class="corchete-llamada">
#              [
#             </span>
#             3
#             <span class="corchete-llamada">
#              ]
#             </span>
#            </a>
#           </sup>
#           ​
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#           •
#           <a href="/wiki/Densidad_de_poblaci%C3%B3n" title="Densidad de población">
#            Densidad
#           </a>
#          </th>
#          <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#           4907,45 hab/km²
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#           • Urbana
#          </th>
#          <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#           7 412 566 hab.
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#           • Metropolitana
#          </th>
#          <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#           8 848 588
#           <sup class="reference separada" id="cite_ref-DANE_2020_ciudades_4-0">
#            <a href="#cite_note-DANE_2020_ciudades-4">
#             <span class="corchete-llamada">
#              [
#             </span>
#             4
#             <span class="corchete-llamada">
#              ]
#             </span>
#            </a>
#           </sup>
#           ​ hab.
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#           <a href="/wiki/Gentilicio" title="Gentilicio">
#            Gentilicio
#           </a>
#          </th>
#          <td colspan="2" style="padding:2px 7px 1px 1px;">
#           Bogotano, -na
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#           <a href="/wiki/Producto_interno_bruto" title="Producto interno bruto">
#            PIB
#           </a>
#           (nominal)
#          </th>
#          <td colspan="2" style="padding:2px 7px 1px 1px;">
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#           • Total
#          </th>
#          <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#           201.174 millones
#           <a class="mw-redirect" href="/wiki/D%C3%B3lar_estadunidense" title="Dólar estadunidense">
#            dólares
#           </a>
#           <sup class="reference separada" id="cite_ref-brookingsgdp_5-0">
#            <a href="#cite_note-brookingsgdp-5">
#             <span class="corchete-llamada">
#              [
#             </span>
#             5
#             <span class="corchete-llamada">
#              ]
#             </span>
#            </a>
#           </sup>
#           ​
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#           • PIB per cápita
#          </th>
#          <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#           26.013
#           <a class="mw-redirect" href="/wiki/D%C3%B3lar_estadunidense" title="Dólar estadunidense">
#            dólares
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#           <a class="mw-redirect" href="/wiki/%C3%8Dndice_de_Desarrollo_Humano" title="Índice de Desarrollo Humano">
#            IDH
#           </a>
#           (2018
#           <sup class="reference separada" id="cite_ref-6">
#            <a href="#cite_note-6">
#             <span class="corchete-llamada">
#              [
#             </span>
#             6
#             <span class="corchete-llamada">
#              ]
#             </span>
#            </a>
#           </sup>
#           ​)
#          </th>
#          <td colspan="2" style="padding:2px 7px 1px 1px;">
# ...
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-sw">
#         <a class="interlanguage-link-target" href="https://sw.wikipedia.org/wiki/Bogota" hreflang="sw" lang="sw" title="Bogota (suajili)">
#          Kiswahili
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-szl">
#         <a class="interlanguage-link-target" href="https://szl.wikipedia.org/wiki/Bogota" hreflang="szl" lang="szl" title="Bogota (Silesian)">
#          Ślůnski
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ta">
#         <a class="interlanguage-link-target" href="https://ta.wikipedia.org/wiki/%E0%AE%AA%E0%AF%8A%E0%AE%95%E0%AF%8B%E0%AE%9F%E0%AF%8D%E0%AE%9F%E0%AE%BE" hreflang="ta" lang="ta" title="பொகோட்டா (tamil)">
#          தமிழ்
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-te">
#         <a class="interlanguage-link-target" href="https://te.wikipedia.org/wiki/%E0%B0%AC%E0%B1%8A%E0%B0%97%E0%B1%8B%E0%B0%9F%E0%B0%BE" hreflang="te" lang="te" title="బొగోటా (telugu)">
#          తెలుగు
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tet">
#         <a class="interlanguage-link-target" href="https://tet.wikipedia.org/wiki/Bogot%C3%A1" hreflang="tet" lang="tet" title="Bogotá (tetún)">
#          Tetun
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tg">
#         <a class="interlanguage-link-target" href="https://tg.wikipedia.org/wiki/%D0%91%D0%BE%D0%B3%D0%BE%D1%82%D0%B0" hreflang="tg" lang="tg" title="Богота (tayiko)">
#          Тоҷикӣ
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-th">
#         <a class="interlanguage-link-target" href="https://th.wikipedia.org/wiki/%E0%B9%82%E0%B8%9A%E0%B9%82%E0%B8%81%E0%B8%95%E0%B8%B2" hreflang="th" lang="th" title="โบโกตา (tailandés)">
#          ไทย
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tk">
#         <a class="interlanguage-link-target" href="https://tk.wikipedia.org/wiki/Bogota" hreflang="tk" lang="tk" title="Bogota (turcomano)">
#          Türkmençe
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tl">
#         <a class="interlanguage-link-target" href="https://tl.wikipedia.org/wiki/Bogot%C3%A1" hreflang="tl" lang="tl" title="Bogotá (tagalo)">
#          Tagalog
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tn">
#         <a class="interlanguage-link-target" href="https://tn.wikipedia.org/wiki/Bogot%C3%A1" hreflang="tn" lang="tn" title="Bogotá (setsuana)">
#          Setswana
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-to">
#         <a class="interlanguage-link-target" href="https://to.wikipedia.org/wiki/Pokot%C4%81" hreflang="to" lang="to" title="Pokotā (tongano)">
#          Lea faka-Tonga
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tpi">
#         <a class="interlanguage-link-target" href="https://tpi.wikipedia.org/wiki/Bogot%C3%A1" hreflang="tpi" lang="tpi" title="Bogotá (tok pisin)">
#          Tok Pisin
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tr">
#         <a class="interlanguage-link-target" href="https://tr.wikipedia.org/wiki/Bogot%C3%A1" hreflang="tr" lang="tr" title="Bogotá (turco)">
#          Türkçe
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tt">
#         <a class="interlanguage-link-target" href="https://tt.wikipedia.org/wiki/%D0%91%D0%BE%D0%B3%D0%BE%D1%82%D0%B0" hreflang="tt" lang="tt" title="Богота (tártaro)">
#          Татарча/tatarça
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ty">
#         <a class="interlanguage-link-target" href="https://ty.wikipedia.org/wiki/Bogota" hreflang="ty" lang="ty" title="Bogota (tahitiano)">
#          Reo tahiti
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-udm">
#         <a class="interlanguage-link-target" href="https://udm.wikipedia.org/wiki/%D0%91%D0%BE%D0%B3%D0%BE%D1%82%D0%B0" hreflang="udm" lang="udm" title="Богота (udmurt)">
#          Удмурт
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ug">
#         <a class="interlanguage-link-target" href="https://ug.wikipedia.org/wiki/Bogota" hreflang="ug" lang="ug" title="Bogota (uigur)">
#          ئۇيغۇرچە / Uyghurche
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-uk">
#         <a class="interlanguage-link-target" href="https://uk.wikipedia.org/wiki/%D0%91%D0%BE%D0%B3%D0%BE%D1%82%D0%B0" hreflang="uk" lang="uk" title="Богота (ucraniano)">
#          Українська
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ur">
#         <a class="interlanguage-link-target" href="https://ur.wikipedia.org/wiki/%D8%A8%D9%88%DA%AF%D9%88%D8%AA%D8%A7" hreflang="ur" lang="ur" title="بوگوتا (urdu)">
#          اردو
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-uz">
#         <a class="interlanguage-link-target" href="https://uz.wikipedia.org/wiki/Bogota" hreflang="uz" lang="uz" title="Bogota (uzbeko)">
#          Oʻzbekcha/ўзбекча
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ve">
#         <a class="interlanguage-link-target" href="https://ve.wikipedia.org/wiki/Bogot%C3%A1" hreflang="ve" lang="ve" title="Bogotá (venda)">
#          Tshivenda
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-vec">
#         <a class="interlanguage-link-target" href="https://vec.wikipedia.org/wiki/Bogot%C3%A0" hreflang="vec" lang="vec" title="Bogotà (Venetian)">
#          Vèneto
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-vep">
#         <a class="interlanguage-link-target" href="https://vep.wikipedia.org/wiki/Bogota" hreflang="vep" lang="vep" title="Bogota (Veps)">
#          Vepsän kel’
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-vi">
#         <a class="interlanguage-link-target" href="https://vi.wikipedia.org/wiki/Bogot%C3%A1" hreflang="vi" lang="vi" title="Bogotá (vietnamita)">
#          Tiếng Việt
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-vls">
#         <a class="interlanguage-link-target" href="https://vls.wikipedia.org/wiki/Bogot%C3%A1" hreflang="vls" lang="vls" title="Bogotá (West Flemish)">
#          West-Vlams
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-vo">
#         <a class="interlanguage-link-target" href="https://vo.wikipedia.org/wiki/Bogot%C3%A1" hreflang="vo" lang="vo" title="Bogotá (volapük)">
#          Volapük
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-wa">
#         <a class="interlanguage-link-target" href="https://wa.wikipedia.org/wiki/Bogota" hreflang="wa" lang="wa" title="Bogota (valón)">
#          Walon
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-war">
#         <a class="interlanguage-link-target" href="https://war.wikipedia.org/wiki/Bogot%C3%A1" hreflang="war" lang="war" title="Bogotá (waray)">
#          Winaray
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-wuu">
#         <a class="interlanguage-link-target" href="https://wuu.wikipedia.org/wiki/%E6%B3%A2%E5%93%A5%E5%A4%A7" hreflang="wuu" lang="wuu" title="波哥大 (chino wu)">
#          吴语
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-xmf">
#         <a class="interlanguage-link-target" href="https://xmf.wikipedia.org/wiki/%E1%83%91%E1%83%9D%E1%83%92%E1%83%9D%E1%83%A2%E1%83%90" hreflang="xmf" lang="xmf" title="ბოგოტა (Mingrelian)">
#          მარგალური
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-yi">
#         <a class="interlanguage-link-target" href="https://yi.wikipedia.org/wiki/%D7%91%D7%90%D7%92%D7%90%D7%98%D7%90" hreflang="yi" lang="yi" title="באגאטא (yidis)">
#          ייִדיש
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-yo">
#         <a class="interlanguage-link-target" href="https://yo.wikipedia.org/wiki/Bogot%C3%A1" hreflang="yo" lang="yo" title="Bogotá (yoruba)">
#          Yorùbá
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-za">
#         <a class="interlanguage-link-target" href="https://za.wikipedia.org/wiki/Bogot%C3%A1" hreflang="za" lang="za" title="Bogotá (zhuang)">
#          Vahcuengh
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zh">
#         <a class="interlanguage-link-target" href="https://zh.wikipedia.org/wiki/%E6%B3%A2%E5%93%A5%E5%A4%A7" hreflang="zh" lang="zh" title="波哥大 (chino)">
#          中文
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zh-classical">
#         <a class="interlanguage-link-target" href="https://zh-classical.wikipedia.org/wiki/%E6%B3%A2%E5%93%A5%E5%A4%A7" hreflang="lzh" lang="lzh" title="波哥大 (Classical Chinese)">
#          文言
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zh-min-nan">
#         <a class="interlanguage-link-target" href="https://zh-min-nan.wikipedia.org/wiki/Bogot%C3%A1" hreflang="nan" lang="nan" title="Bogotá (Chinese (Min Nan))">
#          Bân-lâm-gú
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zh-yue">
#         <a class="interlanguage-link-target" href="https://zh-yue.wikipedia.org/wiki/%E6%B3%A2%E5%93%A5%E5%A4%A7" hreflang="yue" lang="yue" title="波哥大 (Cantonese)">
#          粵語
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zu">
#         <a class="interlanguage-link-target" href="https://zu.wikipedia.org/wiki/IBogotaa" hreflang="zu" lang="zu" title="IBogotaa (zulú)">
#          IsiZulu
#         </a>
#        </li>
#       </ul>
#       <div class="after-portlet after-portlet-lang">
#        <span class="wb-langlinks-edit wb-langlinks-link">
#         <a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q2841#sitelinks-wikipedia" title="Editar enlaces interlingüísticos">
#          Editar enlaces
#         </a>
#        </span>
#       </div>
#      </div>
#     </nav>
#    </div>
#   </div>
#   <footer class="mw-footer" id="footer" role="contentinfo">
#    <ul id="footer-info">
#     <li id="footer-info-lastmod">
#      Esta página se editó por última vez el 10 ago 2021 a las 23:19.
#     </li>
#     <li id="footer-info-copyright">
#      El texto está disponible bajo la
#      <a href="//es.wikipedia.org/wiki/Wikipedia:Texto_de_la_Licencia_Creative_Commons_Atribuci%C3%B3n-CompartirIgual_3.0_Unported" rel="license">
#       Licencia Creative Commons Atribución Compartir Igual 3.0
#      </a>
#      <a href="http://creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;">
#      </a>
#      ;
# pueden aplicarse cláusulas adicionales. Al usar este sitio, usted acepta nuestros
#      <a href="//wikimediafoundation.org/wiki/Terms_of_Use">
#       términos de uso
#      </a>
#      y nuestra
#      <a href="//wikimediafoundation.org/wiki/Privacy_policy">
#       política de privacidad
#      </a>
#      .
#      <br/>
#      Wikipedia® es una marca registrada de la
#      <a href="//www.wikimediafoundation.org/">
#       Fundación Wikimedia, Inc.
#      </a>
#      , una organización sin ánimo de lucro.
#     </li>
#    </ul>
#    <ul id="footer-places">
#     <li id="footer-places-privacy">
#      <a class="extiw" href="https://meta.wikimedia.org/wiki/Privacy_policy/es" title="m:Privacy policy/es">
#       Política de privacidad
#      </a>
#     </li>
#     <li id="footer-places-about">
#      <a href="/wiki/Wikipedia:Acerca_de" title="Wikipedia:Acerca de">
#       Acerca de Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-disclaimer">
#      <a href="/wiki/Wikipedia:Limitaci%C3%B3n_general_de_responsabilidad" title="Wikipedia:Limitación general de responsabilidad">
#       Limitación de responsabilidad
#      </a>
#     </li>
#     <li id="footer-places-mobileview">
#      <a class="noprint stopMobileRedirectToggle" href="//es.m.wikipedia.org/w/index.php?title=Bogot%C3%A1&amp;mobileaction=toggle_view_mobile">
#       Versión para móviles
#      </a>
#     </li>
#     <li id="footer-places-developers">
#      <a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">
#       Desarrolladores
#      </a>
#     </li>
#     <li id="footer-places-statslink">
#      <a href="https://stats.wikimedia.org/#/es.wikipedia.org">
#       Estadísticas
#      </a>
#     </li>
#     <li id="footer-places-cookiestatement">
#      <a href="https://foundation.wikimedia.org/wiki/Cookie_statement/es">
#       Declaración de cookies
#      </a>
#     </li>
#    </ul>
#    <ul class="noprint" id="footer-icons">
#     <li id="footer-copyrightico">
#      <a href="https://wikimediafoundation.org/">
#       <img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/>
#      </a>
#     </li>
#     <li id="footer-poweredbyico">
#      <a href="https://www.mediawiki.org/">
#       <img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/>
#      </a>
#     </li>
#    </ul>
#   </footer>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"3.495","walltime":"4.453","ppvisitednodes":{"value":30533,"limit":1000000},"postexpandincludesize":{"value":521799,"limit":2097152},"templateargumentsize":{"value":48357,"limit":2097152},"expansiondepth":{"value":23,"limit":40},"expensivefunctioncount":{"value":18,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":308408,"limit":5000000},"entityaccesscount":{"value":14,"limit":400},"timingprofile":["100.00% 3522.142      1 -total"," 34.62% 1219.481      1 Plantilla:Ficha_de_entidad_subnacional"," 33.85% 1192.279      1 Plantilla:Ficha"," 21.45%  755.522     25 Plantilla:Propiedad"," 19.00%  669.366      2 Plantilla:Listaref"," 11.91%  419.638    148 Plantilla:Cita_web","  9.49%  334.197      1 Plantilla:Control_de_autoridades","  4.86%  171.266      1 Plantilla:Gráfica_de_evolución","  4.15%  146.069      1 Plantilla:Clima","  4.00%  141.048     29 Plantilla:Bandera"]},"scribunto":{"limitreport-timeusage":{"value":"1.477","limit":"10.000"},"limitreport-memusage":{"value":9191774,"limit":52428800},"limitreport-logs":"No detectados args\nNombre Colombia\n  \nNo existe x\nNo existe y\n","limitreport-profile":[["recursiveClone \u003CmwInit.lua:41\u003E","480","27.3"],["?","320","18.2"],["Scribunto_LuaSandboxCallback::getEntity","220","12.5"],["Scribunto_LuaSandboxCallback::getExpandedArgument","100","5.7"],["dataWrapper \u003Cmw.lua:668\u003E","80","4.5"],["(for generator)","60","3.4"],["Scribunto_LuaSandboxCallback::getAllExpandedArguments","60","3.4"],["\u003Cmw.title.lua:50\u003E","40","2.3"],["Scribunto_LuaSandboxCallback::plain","40","2.3"],["\u003Cmw.lua:690\u003E","40","2.3"],["[others]","320","18.2"]]},"cachereport":{"origin":"mw2301","timestamp":"20210811162316","ttl":3600,"transientcontent":true}}});});
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"Article","name":"Bogot\u00e1","url":"https:\/\/es.wikipedia.org\/wiki\/Bogot%C3%A1","sameAs":"http:\/\/www.wikidata.org\/entity\/Q2841","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q2841","author":{"@type":"Organization","name":"Colaboradores de los proyectos Wikimedia"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2003-02-20T17:46:16Z","dateModified":"2021-08-10T23:19:52Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/4\/4c\/Centro_internacional.JPG","headline":"capital de Colombia y el departamento de Cundinamarca"}
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":197,"wgHostname":"mw2389"});});
#   </script>
#  </body>
# </html>

# %%
# Revisar la información de la "tabla de datos" usando una clase específica

info_caja = bsobj.find(class_="infobox geography vcard")
info_filas = info_caja.find_all("tr")
for fila in info_filas:
    print(fila.prettify())
# Out:
# <tr>
#  <th class="cabecera mapa fn org" colspan="3" style="text-align:center;background-color:transparent;color:black;padding:0;">
#   Bogotá
#  </th>
# </tr>
#
# <tr>
#  <td colspan="3" style="text-align:center;font-size:100%; font-weight:bold; background-color:#cddeff;">
#   <a href="/wiki/Capital_(pol%C3%ADtica)" title="Capital (política)">
#    Capital
#   </a>
#   de
#   <a href="/wiki/Colombia" title="Colombia">
#    Colombia
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <td colspan="3" style="text-align:center;">
#   <table align="right" bgcolor="white" cellspacing="0" style="border:1px solid white">
#    <tbody>
#     <tr>
#      <td style="padding:2px 0px 0px 2px">
#       <table bgcolor="white" cellspacing="0" style="border:0px">
#        <tbody>
#         <tr>
#          <td style="padding:0px 2px 2px 0px">
#           <a class="image" href="/wiki/Archivo:Centro_internacional.JPG" title="Centro">
#            <img alt="Centro" data-file-height="1080" data-file-width="1920" decoding="async" height="152" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Centro_internacional.JPG/270px-Centro_internacional.JPG" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Centro_internacional.JPG/405px-Centro_internacional.JPG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Centro_internacional.JPG/540px-Centro_internacional.JPG 2x" width="270"/>
#           </a>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <table bgcolor="white" cellspacing="0" style="border:0px">
#        <tbody>
#         <tr>
#          <td style="padding:0px 2px 2px 0px">
#           <a class="image" href="/wiki/Archivo:Casa_Cural_de_la_Catedral_2.jpg" title="La Candelaria">
#            <img alt="La Candelaria" data-file-height="1536" data-file-width="2048" decoding="async" height="101" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Casa_Cural_de_la_Catedral_2.jpg/134px-Casa_Cural_de_la_Catedral_2.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Casa_Cural_de_la_Catedral_2.jpg/201px-Casa_Cural_de_la_Catedral_2.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Casa_Cural_de_la_Catedral_2.jpg/268px-Casa_Cural_de_la_Catedral_2.jpg 2x" width="134"/>
#           </a>
#          </td>
#          <td style="padding:0px 2px 2px 0px">
#           <a class="image" href="/wiki/Archivo:Movistar_Arena,_lugar_de_conciertos_y_eventos_de_todo_tipo,_en_Bogot%C3%A1.jpg" title="arena">
#            <img alt="arena" data-file-height="3120" data-file-width="4160" decoding="async" height="101" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/02/Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg/134px-Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/02/Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg/201px-Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/02/Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg/268px-Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg 2x" width="134"/>
#           </a>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <table bgcolor="white" cellspacing="0" style="border:0px">
#        <tbody>
#         <tr>
#          <td style="padding:0px 2px 2px 0px">
#           <a class="image" href="/wiki/Archivo:Entrada_del_Museo_Nacional_de_Colombia.jpg" title="Museo Nacional de Colombia">
#            <img alt="Museo Nacional de Colombia" data-file-height="2736" data-file-width="3648" decoding="async" height="101" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/90/Entrada_del_Museo_Nacional_de_Colombia.jpg/134px-Entrada_del_Museo_Nacional_de_Colombia.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/90/Entrada_del_Museo_Nacional_de_Colombia.jpg/201px-Entrada_del_Museo_Nacional_de_Colombia.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/90/Entrada_del_Museo_Nacional_de_Colombia.jpg/268px-Entrada_del_Museo_Nacional_de_Colombia.jpg 2x" width="134"/>
#           </a>
#          </td>
#          <td style="padding:0px 2px 2px 0px">
#           <a class="image" href="/wiki/Archivo:Fachada_Capitolio.jpg" title="Fachada del Capitolio Nacional de Colombia">
#            <img alt="Fachada del Capitolio Nacional de Colombia" data-file-height="2134" data-file-width="2848" decoding="async" height="100" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Fachada_Capitolio.jpg/134px-Fachada_Capitolio.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Fachada_Capitolio.jpg/201px-Fachada_Capitolio.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Fachada_Capitolio.jpg/268px-Fachada_Capitolio.jpg 2x" width="134"/>
#           </a>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <table bgcolor="white" cellspacing="0" style="border:0px">
#        <tbody>
#         <tr>
#          <td style="padding:0px 2px 2px 0px">
#           <a class="image" href="/wiki/Archivo:Santa_Barbara,_Bogot%C3%A1.png" title="Santa Bárbara, Usaquén, Bogotá.">
#            <img alt="Santa Bárbara, Usaquén, Bogotá." data-file-height="960" data-file-width="720" decoding="async" height="179" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Santa_Barbara%2C_Bogot%C3%A1.png/134px-Santa_Barbara%2C_Bogot%C3%A1.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Santa_Barbara%2C_Bogot%C3%A1.png/201px-Santa_Barbara%2C_Bogot%C3%A1.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Santa_Barbara%2C_Bogot%C3%A1.png/268px-Santa_Barbara%2C_Bogot%C3%A1.png 2x" width="134"/>
#           </a>
#          </td>
#          <td style="padding:0px 2px 2px 0px">
#           <a class="image" href="/wiki/Archivo:Monserrate.jpg" title="Basicilica de nuestro señor caído de Monserrate.">
#            <img alt="Basicilica de nuestro señor caído de Monserrate." data-file-height="980" data-file-width="720" decoding="async" height="182" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/7b/Monserrate.jpg/134px-Monserrate.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/7b/Monserrate.jpg/201px-Monserrate.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/7b/Monserrate.jpg/268px-Monserrate.jpg 2x" width="134"/>
#           </a>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </td>
#     </tr>
#    </tbody>
#   </table>
#   <br/>
#   <span style="font-size:smaller">
#    Desde arriba y de izquierda a derecha:
#    <a href="/wiki/Centro_Internacional_de_Bogot%C3%A1" title="Centro Internacional de Bogotá">
#     Centro Internacional de Bogotá
#    </a>
#    ,
#    <a href="/wiki/La_Candelaria" title="La Candelaria">
#     La Candelaria
#    </a>
#    ,
#    <a class="mw-redirect" href="/wiki/Movistar_Arena_(Bogot%C3%A1)" title="Movistar Arena (Bogotá)">
#     Movistar Arena
#    </a>
#    , el
#    <a href="/wiki/Museo_Nacional_de_Colombia" title="Museo Nacional de Colombia">
#     Museo Nacional de Colombia
#    </a>
#    ,
#    <a href="/wiki/Capitolio_Nacional_de_Colombia" title="Capitolio Nacional de Colombia">
#     Capitolio Nacional de Colombia
#    </a>
#    , Barrio Santa Barbará en
#    <a href="/wiki/Usaqu%C3%A9n" title="Usaquén">
#     Usaquén
#    </a>
#    y Monasterio de
#    <a href="/wiki/Monserrate" title="Monserrate">
#     Monserrate
#    </a>
#   </span>
#   <br/>
#   <div style="display:inline;font-size:smaller; font-weight:normal;">
#   </div>
#  </td>
# </tr>
#
# <tr>
#  <td style="padding:2px 0px 0px 2px">
#   <table bgcolor="white" cellspacing="0" style="border:0px">
#    <tbody>
#     <tr>
#      <td style="padding:0px 2px 2px 0px">
#       <a class="image" href="/wiki/Archivo:Centro_internacional.JPG" title="Centro">
#        <img alt="Centro" data-file-height="1080" data-file-width="1920" decoding="async" height="152" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Centro_internacional.JPG/270px-Centro_internacional.JPG" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Centro_internacional.JPG/405px-Centro_internacional.JPG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Centro_internacional.JPG/540px-Centro_internacional.JPG 2x" width="270"/>
#       </a>
#      </td>
#     </tr>
#    </tbody>
#   </table>
#   <table bgcolor="white" cellspacing="0" style="border:0px">
#    <tbody>
#     <tr>
#      <td style="padding:0px 2px 2px 0px">
#       <a class="image" href="/wiki/Archivo:Casa_Cural_de_la_Catedral_2.jpg" title="La Candelaria">
#        <img alt="La Candelaria" data-file-height="1536" data-file-width="2048" decoding="async" height="101" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Casa_Cural_de_la_Catedral_2.jpg/134px-Casa_Cural_de_la_Catedral_2.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Casa_Cural_de_la_Catedral_2.jpg/201px-Casa_Cural_de_la_Catedral_2.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Casa_Cural_de_la_Catedral_2.jpg/268px-Casa_Cural_de_la_Catedral_2.jpg 2x" width="134"/>
#       </a>
#      </td>
#      <td style="padding:0px 2px 2px 0px">
#       <a class="image" href="/wiki/Archivo:Movistar_Arena,_lugar_de_conciertos_y_eventos_de_todo_tipo,_en_Bogot%C3%A1.jpg" title="arena">
#        <img alt="arena" data-file-height="3120" data-file-width="4160" decoding="async" height="101" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/02/Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg/134px-Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/02/Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg/201px-Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/02/Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg/268px-Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg 2x" width="134"/>
#       </a>
#      </td>
#     </tr>
#    </tbody>
#   </table>
#   <table bgcolor="white" cellspacing="0" style="border:0px">
#    <tbody>
#     <tr>
#      <td style="padding:0px 2px 2px 0px">
#       <a class="image" href="/wiki/Archivo:Entrada_del_Museo_Nacional_de_Colombia.jpg" title="Museo Nacional de Colombia">
#        <img alt="Museo Nacional de Colombia" data-file-height="2736" data-file-width="3648" decoding="async" height="101" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/90/Entrada_del_Museo_Nacional_de_Colombia.jpg/134px-Entrada_del_Museo_Nacional_de_Colombia.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/90/Entrada_del_Museo_Nacional_de_Colombia.jpg/201px-Entrada_del_Museo_Nacional_de_Colombia.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/90/Entrada_del_Museo_Nacional_de_Colombia.jpg/268px-Entrada_del_Museo_Nacional_de_Colombia.jpg 2x" width="134"/>
#       </a>
#      </td>
#      <td style="padding:0px 2px 2px 0px">
#       <a class="image" href="/wiki/Archivo:Fachada_Capitolio.jpg" title="Fachada del Capitolio Nacional de Colombia">
#        <img alt="Fachada del Capitolio Nacional de Colombia" data-file-height="2134" data-file-width="2848" decoding="async" height="100" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Fachada_Capitolio.jpg/134px-Fachada_Capitolio.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Fachada_Capitolio.jpg/201px-Fachada_Capitolio.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Fachada_Capitolio.jpg/268px-Fachada_Capitolio.jpg 2x" width="134"/>
#       </a>
#      </td>
#     </tr>
#    </tbody>
#   </table>
#   <table bgcolor="white" cellspacing="0" style="border:0px">
#    <tbody>
#     <tr>
#      <td style="padding:0px 2px 2px 0px">
#       <a class="image" href="/wiki/Archivo:Santa_Barbara,_Bogot%C3%A1.png" title="Santa Bárbara, Usaquén, Bogotá.">
#        <img alt="Santa Bárbara, Usaquén, Bogotá." data-file-height="960" data-file-width="720" decoding="async" height="179" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Santa_Barbara%2C_Bogot%C3%A1.png/134px-Santa_Barbara%2C_Bogot%C3%A1.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Santa_Barbara%2C_Bogot%C3%A1.png/201px-Santa_Barbara%2C_Bogot%C3%A1.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Santa_Barbara%2C_Bogot%C3%A1.png/268px-Santa_Barbara%2C_Bogot%C3%A1.png 2x" width="134"/>
#       </a>
#      </td>
#      <td style="padding:0px 2px 2px 0px">
#       <a class="image" href="/wiki/Archivo:Monserrate.jpg" title="Basicilica de nuestro señor caído de Monserrate.">
#        <img alt="Basicilica de nuestro señor caído de Monserrate." data-file-height="980" data-file-width="720" decoding="async" height="182" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/7b/Monserrate.jpg/134px-Monserrate.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/7b/Monserrate.jpg/201px-Monserrate.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/7b/Monserrate.jpg/268px-Monserrate.jpg 2x" width="134"/>
#       </a>
#      </td>
#     </tr>
#    </tbody>
#   </table>
#  </td>
# </tr>
#
# <tr>
#  <td style="padding:0px 2px 2px 0px">
#   <a class="image" href="/wiki/Archivo:Centro_internacional.JPG" title="Centro">
#    <img alt="Centro" data-file-height="1080" data-file-width="1920" decoding="async" height="152" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Centro_internacional.JPG/270px-Centro_internacional.JPG" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Centro_internacional.JPG/405px-Centro_internacional.JPG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Centro_internacional.JPG/540px-Centro_internacional.JPG 2x" width="270"/>
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <td style="padding:0px 2px 2px 0px">
#   <a class="image" href="/wiki/Archivo:Casa_Cural_de_la_Catedral_2.jpg" title="La Candelaria">
#    <img alt="La Candelaria" data-file-height="1536" data-file-width="2048" decoding="async" height="101" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Casa_Cural_de_la_Catedral_2.jpg/134px-Casa_Cural_de_la_Catedral_2.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Casa_Cural_de_la_Catedral_2.jpg/201px-Casa_Cural_de_la_Catedral_2.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Casa_Cural_de_la_Catedral_2.jpg/268px-Casa_Cural_de_la_Catedral_2.jpg 2x" width="134"/>
#   </a>
#  </td>
#  <td style="padding:0px 2px 2px 0px">
#   <a class="image" href="/wiki/Archivo:Movistar_Arena,_lugar_de_conciertos_y_eventos_de_todo_tipo,_en_Bogot%C3%A1.jpg" title="arena">
#    <img alt="arena" data-file-height="3120" data-file-width="4160" decoding="async" height="101" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/02/Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg/134px-Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/02/Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg/201px-Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/02/Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg/268px-Movistar_Arena%2C_lugar_de_conciertos_y_eventos_de_todo_tipo%2C_en_Bogot%C3%A1.jpg 2x" width="134"/>
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <td style="padding:0px 2px 2px 0px">
#   <a class="image" href="/wiki/Archivo:Entrada_del_Museo_Nacional_de_Colombia.jpg" title="Museo Nacional de Colombia">
#    <img alt="Museo Nacional de Colombia" data-file-height="2736" data-file-width="3648" decoding="async" height="101" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/90/Entrada_del_Museo_Nacional_de_Colombia.jpg/134px-Entrada_del_Museo_Nacional_de_Colombia.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/90/Entrada_del_Museo_Nacional_de_Colombia.jpg/201px-Entrada_del_Museo_Nacional_de_Colombia.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/90/Entrada_del_Museo_Nacional_de_Colombia.jpg/268px-Entrada_del_Museo_Nacional_de_Colombia.jpg 2x" width="134"/>
#   </a>
#  </td>
#  <td style="padding:0px 2px 2px 0px">
#   <a class="image" href="/wiki/Archivo:Fachada_Capitolio.jpg" title="Fachada del Capitolio Nacional de Colombia">
#    <img alt="Fachada del Capitolio Nacional de Colombia" data-file-height="2134" data-file-width="2848" decoding="async" height="100" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Fachada_Capitolio.jpg/134px-Fachada_Capitolio.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Fachada_Capitolio.jpg/201px-Fachada_Capitolio.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Fachada_Capitolio.jpg/268px-Fachada_Capitolio.jpg 2x" width="134"/>
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <td style="padding:0px 2px 2px 0px">
#   <a class="image" href="/wiki/Archivo:Santa_Barbara,_Bogot%C3%A1.png" title="Santa Bárbara, Usaquén, Bogotá.">
#    <img alt="Santa Bárbara, Usaquén, Bogotá." data-file-height="960" data-file-width="720" decoding="async" height="179" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Santa_Barbara%2C_Bogot%C3%A1.png/134px-Santa_Barbara%2C_Bogot%C3%A1.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Santa_Barbara%2C_Bogot%C3%A1.png/201px-Santa_Barbara%2C_Bogot%C3%A1.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Santa_Barbara%2C_Bogot%C3%A1.png/268px-Santa_Barbara%2C_Bogot%C3%A1.png 2x" width="134"/>
#   </a>
#  </td>
#  <td style="padding:0px 2px 2px 0px">
#   <a class="image" href="/wiki/Archivo:Monserrate.jpg" title="Basicilica de nuestro señor caído de Monserrate.">
#    <img alt="Basicilica de nuestro señor caído de Monserrate." data-file-height="980" data-file-width="720" decoding="async" height="182" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/7b/Monserrate.jpg/134px-Monserrate.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/7b/Monserrate.jpg/201px-Monserrate.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/7b/Monserrate.jpg/268px-Monserrate.jpg 2x" width="134"/>
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <td colspan="3" style="align:center;">
#   <br/>
#   <table class="mergedrow" style="width:100%;">
#    <tbody>
#     <tr>
#      <td style="text-align:center;background-color:transparent;align:center;vertical-align:middle;">
#       <a class="image" href="/wiki/Archivo:Flag_of_Bogot%C3%A1.svg">
#        <img alt="Flag of Bogotá.svg" class="thumbborder" data-file-height="500" data-file-width="750" decoding="async" height="67" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Flag_of_Bogot%C3%A1.svg/100px-Flag_of_Bogot%C3%A1.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Flag_of_Bogot%C3%A1.svg/150px-Flag_of_Bogot%C3%A1.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Flag_of_Bogot%C3%A1.svg/200px-Flag_of_Bogot%C3%A1.svg.png 2x" width="100"/>
#       </a>
#       <br/>
#       <div style="display:inline;font-size:smaller; font-weight:bold;">
#        <a href="/wiki/Bandera_de_Bogot%C3%A1" title="Bandera de Bogotá">
#         Bandera
#        </a>
#       </div>
#      </td>
#      <td style="text-align:center;align:center;vertical-align:middle;background-color:transparent;">
#       <a class="image" href="/wiki/Archivo:Escudo_de_Armas_de_Bogota.svg">
#        <img alt="Escudo de Armas de Bogota.svg" data-file-height="425" data-file-width="354" decoding="async" height="88" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Escudo_de_Armas_de_Bogota.svg/73px-Escudo_de_Armas_de_Bogota.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Escudo_de_Armas_de_Bogota.svg/110px-Escudo_de_Armas_de_Bogota.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Escudo_de_Armas_de_Bogota.svg/147px-Escudo_de_Armas_de_Bogota.svg.png 2x" width="73"/>
#       </a>
#       <br/>
#       <div style="display:inline;font-size:smaller; font-weight:bold;">
#        <a href="/wiki/Escudo_de_Bogot%C3%A1" title="Escudo de Bogotá">
#         Escudo
#        </a>
#       </div>
#       <br/>
#      </td>
#     </tr>
#    </tbody>
#   </table>
#  </td>
# </tr>
#
# <tr>
#  <td style="text-align:center;background-color:transparent;align:center;vertical-align:middle;">
#   <a class="image" href="/wiki/Archivo:Flag_of_Bogot%C3%A1.svg">
#    <img alt="Flag of Bogotá.svg" class="thumbborder" data-file-height="500" data-file-width="750" decoding="async" height="67" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Flag_of_Bogot%C3%A1.svg/100px-Flag_of_Bogot%C3%A1.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Flag_of_Bogot%C3%A1.svg/150px-Flag_of_Bogot%C3%A1.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Flag_of_Bogot%C3%A1.svg/200px-Flag_of_Bogot%C3%A1.svg.png 2x" width="100"/>
#   </a>
#   <br/>
#   <div style="display:inline;font-size:smaller; font-weight:bold;">
#    <a href="/wiki/Bandera_de_Bogot%C3%A1" title="Bandera de Bogotá">
#     Bandera
#    </a>
#   </div>
#  </td>
#  <td style="text-align:center;align:center;vertical-align:middle;background-color:transparent;">
#   <a class="image" href="/wiki/Archivo:Escudo_de_Armas_de_Bogota.svg">
#    <img alt="Escudo de Armas de Bogota.svg" data-file-height="425" data-file-width="354" decoding="async" height="88" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Escudo_de_Armas_de_Bogota.svg/73px-Escudo_de_Armas_de_Bogota.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Escudo_de_Armas_de_Bogota.svg/110px-Escudo_de_Armas_de_Bogota.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Escudo_de_Armas_de_Bogota.svg/147px-Escudo_de_Armas_de_Bogota.svg.png 2x" width="73"/>
#   </a>
#   <br/>
#   <div style="display:inline;font-size:smaller; font-weight:bold;">
#    <a href="/wiki/Escudo_de_Bogot%C3%A1" title="Escudo de Bogotá">
#     Escudo
#    </a>
#   </div>
#   <br/>
#  </td>
# </tr>
# <tr>
#  <td colspan="3" style="text-align:center;padding:2px 7px 1px 1px;">
#   <a href="/wiki/Apodo" title="Apodo">
#    Otros nombres
#   </a>
#   :
#   <span style="font-style:italic">
#    La Atenas Suramericana.
#    <br/>
#    La Ciudad de Todos.
#    <br/>
#    La Capital Mundial del Teatro.
#    <sup class="reference separada" id="cite_ref-8">
#     <a href="#cite_note-8">
#      <span class="corchete-llamada">
#       [
#      </span>
#      8
#      <span class="corchete-llamada">
#       ]
#      </span>
#     </a>
#    </sup>
#    ​ Muy Noble y Muy Leal Ciudad.
#    <sup class="reference separada" id="cite_ref-9">
#     <a href="#cite_note-9">
#      <span class="corchete-llamada">
#       [
#      </span>
#      9
#      <span class="corchete-llamada">
#       ]
#      </span>
#     </a>
#    </sup>
#    ​
#   </span>
#  </td>
# </tr>
#
# <tr>
#  <td colspan="3" style="text-align:center;padding:2px 7px 1px 1px;">
#   <a class="mw-redirect" href="/wiki/Anexo:Lemas_de_Estado" title="Anexo:Lemas de Estado">
#    Lema
#   </a>
#   : 2600 metros más cerca de las estrellas.
#   <sup class="reference separada" id="cite_ref-10">
#    <a href="#cite_note-10">
#     <span class="corchete-llamada">
#      [
#     </span>
#     10
#     <span class="corchete-llamada">
#      ]
#     </span>
#    </a>
#   </sup>
#   ​
#  </td>
# </tr>
#
# <tr>
#  <td colspan="3" style="text-align:center;padding:2px 7px 1px 1px;">
#   <a href="/wiki/Himno" title="Himno">
#    Himno
#   </a>
#   :
#   <a href="/wiki/Himno_de_Bogot%C3%A1" title="Himno de Bogotá">
#    Himno de Bogotá
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <td colspan="3" style="text-align:center;padding:0.8em 0.7em; text-align:center;">
#   <div class="center">
#    <div style="width:250px;float:none;clear:both;margin-left:auto;margin-right:auto">
#     <div style="width:250px;padding:0">
#      <div style="position:relative;width:250px">
#       <a class="image" href="/wiki/Archivo:Colombia_location_map.svg">
#        <img alt="Bogotá ubicada en Colombia" data-file-height="2294" data-file-width="2027" decoding="async" height="283" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/8f/Colombia_location_map.svg/250px-Colombia_location_map.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/8f/Colombia_location_map.svg/375px-Colombia_location_map.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/8f/Colombia_location_map.svg/500px-Colombia_location_map.svg.png 2x" width="250"/>
#       </a>
#       <div style="position:absolute;top:56.508%;left:58.888%;height:0;width:0;margin:0;padding:0">
#        <div style="position:absolute;text-align:center;left:-3px;top:-3px;width:5px;font-size:5px;line-height:0">
#         <img alt="Bogotá" data-file-height="64" data-file-width="64" decoding="async" height="5" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/5px-Red_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/8px-Red_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/10px-Red_pog.svg.png 2x" title="Bogotá" width="5"/>
#        </div>
#        <div style="font-size:90%;line-height:110%;position:absolute;width:6em;top:-0.75em;left:4px;text-align:left">
#         <span style="padding:1px;float:left">
#          Bogotá
#         </span>
#        </div>
#       </div>
#      </div>
#      <div style="font-size:90%;padding-top:3px">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div style="display:inline;font-size:smaller; font-weight:bold;">
#    Localización de Bogotá en Colombia
#   </div>
#  </td>
# </tr>
#
# <tr>
#  <td colspan="3" style="text-align:center;padding:0.8em 0.7em; text-align:center;">
#   <a class="image" href="/wiki/Archivo:Colombia_Distrito_Capital_location_map_(%2Burban_areas_%2Blocator_map).svg">
#    <img alt="Colombia Distrito Capital location map (+urban areas +locator map).svg" data-file-height="1331" data-file-width="602" decoding="async" height="542" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Colombia_Distrito_Capital_location_map_%28%2Burban_areas_%2Blocator_map%29.svg/245px-Colombia_Distrito_Capital_location_map_%28%2Burban_areas_%2Blocator_map%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Colombia_Distrito_Capital_location_map_%28%2Burban_areas_%2Blocator_map%29.svg/368px-Colombia_Distrito_Capital_location_map_%28%2Burban_areas_%2Blocator_map%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Colombia_Distrito_Capital_location_map_%28%2Burban_areas_%2Blocator_map%29.svg/490px-Colombia_Distrito_Capital_location_map_%28%2Burban_areas_%2Blocator_map%29.svg.png 2x" width="245"/>
#   </a>
#   <br/>
#   <div style="display:inline;font-size:smaller; font-weight:bold;">
#    Bogotá y su área urbana
#   </div>
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#   <a href="/wiki/Coordenadas_geogr%C3%A1ficas" title="Coordenadas geográficas">
#    Coordenadas
#   </a>
#  </th>
#  <td colspan="2" style="padding:2px 7px 1px 1px;">
#   <span class="plainlinks nourlexpansion">
#    <a class="external text" href="http://tools.wmflabs.org/geohack/geohack.php?language=es&amp;pagename=Bogot%C3%A1&amp;params=4.6126388888889_N_-74.0705_E_type:city">
#     <span class="geo-default">
#      <span class="geo-dms" title="Mapas, fotos y otros datos de 4°36′46″N 74°04′14″O">
#       <span class="latitude">
#        4°36′46″N
#       </span>
#       <span class="longitude">
#        74°04′14″O
#       </span>
#      </span>
#     </span>
#     <span class="geo-multi-punct">
#      ﻿ / ﻿
#     </span>
#     <span class="geo-nondefault">
#      <span class="geo-dec" title="Mapas, fotos y otros datos de 4.6126388888889 -74.0705">
#       <span class="geo">
#        <span class="latitude">
#         4.6126388888889,
#        </span>
#        <span class="longitude">
#         -74.0705
#        </span>
#       </span>
#      </span>
#     </span>
#    </a>
#   </span>
#   <span style="font-size: small;">
#    <span id="coordinates">
#     <a href="/wiki/Coordenadas_geogr%C3%A1ficas" title="Coordenadas geográficas">
#      Coordenadas
#     </a>
#     :
#     <span class="plainlinks nourlexpansion">
#      <a class="external text" href="http://tools.wmflabs.org/geohack/geohack.php?language=es&amp;pagename=Bogot%C3%A1&amp;params=4.6126388888889_N_-74.0705_E_type:city">
#       <span class="geo-default">
#        <span class="geo-dms" title="Mapas, fotos y otros datos de 4°36′46″N 74°04′14″O">
#         <span class="latitude">
#          4°36′46″N
#         </span>
#         <span class="longitude">
#          74°04′14″O
#         </span>
#        </span>
#       </span>
#       <span class="geo-multi-punct">
#        ﻿ / ﻿
#       </span>
#       <span class="geo-nondefault">
#        <span class="geo-dec" title="Mapas, fotos y otros datos de 4.6126388888889 -74.0705">
#         <span class="geo">
#          <span class="latitude">
#           4.6126388888889,
#          </span>
#          <span class="longitude">
#           -74.0705
#          </span>
#         </span>
#        </span>
#       </span>
#      </a>
#     </span>
#    </span>
#   </span>
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#   <a href="/wiki/Idioma_oficial" title="Idioma oficial">
#    Idioma oficial
#   </a>
#  </th>
#  <td colspan="2" style="padding:2px 7px 1px 1px;">
#   <a href="/wiki/Idioma_espa%C3%B1ol" title="Idioma español">
#    Español
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#   <a class="mw-redirect" href="/wiki/Entidad_subnacional" title="Entidad subnacional">
#    Entidad
#   </a>
#  </th>
#  <td colspan="2" style="padding:2px 7px 1px 1px;">
#   <a href="/wiki/Capital_(pol%C3%ADtica)" title="Capital (política)">
#    Capital
#   </a>
#   de
#   <a href="/wiki/Colombia" title="Colombia">
#    Colombia
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#   •
#   <a href="/wiki/Anexo:Pa%C3%ADses" title="Anexo:Países">
#    País
#   </a>
#  </th>
#  <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#   <span class="flagicon">
#    <img alt="Bandera de Colombia" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/20px-Flag_of_Colombia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/30px-Flag_of_Colombia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/21/Flag_of_Colombia.svg/40px-Flag_of_Colombia.svg.png 2x" title="Bandera de Colombia" width="20"/>
#   </span>
#   <a href="/wiki/Colombia" title="Colombia">
#    Colombia
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#   •
#   <a href="/wiki/Departamentos_de_Colombia" title="Departamentos de Colombia">
#    Departamento
#   </a>
#  </th>
#  <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#   <span class="flagicon">
#    <img alt="Bandera de Cundinamarca" class="thumbborder" data-file-height="500" data-file-width="750" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/65/Flag_of_Cundinamarca.svg/20px-Flag_of_Cundinamarca.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/65/Flag_of_Cundinamarca.svg/30px-Flag_of_Cundinamarca.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/65/Flag_of_Cundinamarca.svg/40px-Flag_of_Cundinamarca.svg.png 2x" title="Bandera de Cundinamarca" width="20"/>
#   </span>
#   <a href="/wiki/Cundinamarca" title="Cundinamarca">
#    Cundinamarca
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#   •
#   <a href="/wiki/Distritos_de_Colombia" title="Distritos de Colombia">
#    Distrito
#   </a>
#  </th>
#  <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#   <span class="flagicon">
#    <img alt="Flag of Bogotá.svg" class="thumbborder" data-file-height="500" data-file-width="750" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Flag_of_Bogot%C3%A1.svg/20px-Flag_of_Bogot%C3%A1.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Flag_of_Bogot%C3%A1.svg/30px-Flag_of_Bogot%C3%A1.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Flag_of_Bogot%C3%A1.svg/40px-Flag_of_Bogot%C3%A1.svg.png 2x" width="20"/>
#   </span>
#   <a href="/wiki/Distrito_capital" title="Distrito capital">
#    Capital
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#   <a href="/wiki/Alcalde_de_Bogot%C3%A1" title="Alcalde de Bogotá">
#    Alcaldesa
#   </a>
#  </th>
#  <td colspan="2" style="padding:2px 7px 1px 1px;">
#   <a class="mw-redirect" href="/wiki/Claudia_Nayibe_L%C3%B3pez_Hern%C3%A1ndez" title="Claudia Nayibe López Hernández">
#    Claudia López
#   </a>
#   <br/>
#   (
#   <a class="mw-redirect" href="/wiki/Partido_Verde_(Colombia)" title="Partido Verde (Colombia)">
#    AV
#   </a>
#   )
#   <a class="image" href="/wiki/Archivo:Alianza_Verde.png">
#    <img alt="Alianza Verde.png" data-file-height="124" data-file-width="292" decoding="async" height="8" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/7e/Alianza_Verde.png/20px-Alianza_Verde.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/7e/Alianza_Verde.png/30px-Alianza_Verde.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/7e/Alianza_Verde.png/40px-Alianza_Verde.png 2x" width="20"/>
#   </a>
#   <small>
#    (
#    <a href="/wiki/2020" title="2020">
#     2020
#    </a>
#    -
#    <a href="/wiki/2023" title="2023">
#     2023
#    </a>
#    )
#   </small>
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#   Subdivisiones
#  </th>
#  <td colspan="2" style="padding:2px 7px 1px 1px;">
#   20
#   <a href="/wiki/Anexo:Localidades_de_Bogot%C3%A1" title="Anexo:Localidades de Bogotá">
#    localidades
#   </a>
#   <br/>
#   1922
#   <a href="/wiki/Barrio" title="Barrio">
#    barrios
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#   Localidades
#  </th>
#  <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#   <div class="NavFrame collapsed" style="border:none; padding: 0;">
#    <div align="left" class="NavHead" style="width:100%; background:transparent">
#     Ver lista
#    </div>
#    <div class="NavContent" style="text-align:left;">
#     <a href="/wiki/Usaqu%C3%A9n" title="Usaquén">
#      Usaquén
#     </a>
#     <br/>
#     <a href="/wiki/Chapinero" title="Chapinero">
#      Chapinero
#     </a>
#     <br/>
#     <a href="/wiki/Santa_Fe_(Bogot%C3%A1)" title="Santa Fe (Bogotá)">
#      Santa Fe
#     </a>
#     <br/>
#     <a href="/wiki/San_Crist%C3%B3bal_(Bogot%C3%A1)" title="San Cristóbal (Bogotá)">
#      San Cristóbal
#     </a>
#     <br/>
#     <a href="/wiki/Usme" title="Usme">
#      Usme
#     </a>
#     <br/>
#     <a href="/wiki/Tunjuelito" title="Tunjuelito">
#      Tunjuelito
#     </a>
#     <br/>
#     <a href="/wiki/Bosa_(Bogot%C3%A1)" title="Bosa (Bogotá)">
#      Bosa
#     </a>
#     <br/>
#     <a href="/wiki/Kennedy_(Bogot%C3%A1)" title="Kennedy (Bogotá)">
#      Kennedy
#     </a>
#     <br/>
#     <a href="/wiki/Fontib%C3%B3n" title="Fontibón">
#      Fontibón
#     </a>
#     <br/>
#     <a href="/wiki/Engativ%C3%A1" title="Engativá">
#      Engativá
#     </a>
#     <br/>
#     <a href="/wiki/Suba" title="Suba">
#      Suba
#     </a>
#     <br/>
#     <a href="/wiki/Barrios_Unidos_(Bogot%C3%A1)" title="Barrios Unidos (Bogotá)">
#      Barrios Unidos
#     </a>
#     <br/>
#     <a href="/wiki/Teusaquillo" title="Teusaquillo">
#      Teusaquillo
#     </a>
#     <br/>
#     <a href="/wiki/Los_M%C3%A1rtires" title="Los Mártires">
#      Los Mártires
#     </a>
#     <br/>
#     <a href="/wiki/Antonio_Nari%C3%B1o_(Bogot%C3%A1)" title="Antonio Nariño (Bogotá)">
#      Antonio Nariño
#     </a>
#     <br/>
#     <a href="/wiki/Puente_Aranda" title="Puente Aranda">
#      Puente Aranda
#     </a>
#     <br/>
#     <a href="/wiki/La_Candelaria" title="La Candelaria">
#      La Candelaria
#     </a>
#     <small>
#      (Centro Histórico)
#     </small>
#     <br/>
#     <a href="/wiki/Rafael_Uribe_Uribe_(Bogot%C3%A1)" title="Rafael Uribe Uribe (Bogotá)">
#      Rafael Uribe Uribe
#     </a>
#     <br/>
#     <a href="/wiki/Ciudad_Bol%C3%ADvar_(Bogot%C3%A1)" title="Ciudad Bolívar (Bogotá)">
#      Ciudad Bolívar
#     </a>
#     <br/>
#     <a href="/wiki/Sumapaz_(Bogot%C3%A1)" title="Sumapaz (Bogotá)">
#      Sumapaz
#     </a>
#    </div>
#   </div>
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#   Eventos históricos
#  </th>
#  <td colspan="2" style="padding:2px 7px 1px 1px;">
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#   • Fundación
#  </th>
#  <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#   6 de agosto de 1538 (483 años)
#   <br/>
#   <span style="font-size:90%">
#    (
#    <a href="/wiki/Gonzalo_Jim%C3%A9nez_de_Quesada" title="Gonzalo Jiménez de Quesada">
#     Gonzalo Jiménez de Quesada
#    </a>
#    )
#   </span>
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#   • Erección
#  </th>
#  <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#   3 de diciembre de 1548 (472 años)
#   <br/>
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#   • Creación
#  </th>
#  <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#   17 de diciembre de 1954 (66 años) (conformación del
#   <a href="/wiki/Distrito_Especial_de_Bogot%C3%A1" title="Distrito Especial de Bogotá">
#    Distrito Capital
#   </a>
#   )
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#   <a href="/wiki/%C3%81rea" title="Área">
#    Superficie
#   </a>
#  </th>
#  <td colspan="2" style="padding:2px 7px 1px 1px;">
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#   • Total
#  </th>
#  <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#   1775
#   <a href="/wiki/Kil%C3%B3metro_cuadrado" title="Kilómetro cuadrado">
#    km²
#   </a>
#   <sup class="reference separada" id="cite_ref-GB_1-0">
#    <a href="#cite_note-GB-1">
#     <span class="corchete-llamada">
#      [
#     </span>
#     1
#     <span class="corchete-llamada">
#      ]
#     </span>
#    </a>
#   </sup>
#   ​
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#   <a href="/wiki/Altitud" title="Altitud">
#    Altitud
#   </a>
#  </th>
#  <td colspan="2" style="padding:2px 7px 1px 1px;">
#  </td>
# </tr>
# <tr>
#  <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#   • Media
#  </th>
#  <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#   2640
#   <a class="mw-redirect" href="/wiki/Msnm" title="Msnm">
#    m s. n. m.
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#   • Máxima
#  </th>
#  <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#   4000
#   <sup class="reference separada" id="cite_ref-2">
#    <a href="#cite_note-2">
#     <span class="corchete-llamada">
#      [
#     </span>
#     2
#     <span class="corchete-llamada">
#      ]
#     </span>
#    </a>
#   </sup>
#   ​ m s. n. m.
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#   • Mínima
#  </th>
#  <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#   2540
#   <sup>
#    [
#    <i>
#     <a href="/wiki/Wikipedia:Verificabilidad" title="Wikipedia:Verificabilidad">
#      cita requerida
#     </a>
#    </i>
#    ]
#   </sup>
#   m s. n. m.
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#   <a href="/wiki/Clima" title="Clima">
#    Clima
#   </a>
#  </th>
#  <td colspan="2" style="padding:2px 7px 1px 1px;">
#   <a href="/wiki/Clima_mediterr%C3%A1neo#Mediterráneo_con_influencia_oceánica_(Csb)" title="Clima mediterráneo">
#    Oceánico mediterráneo
#    <i>
#     Csb
#    </i>
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#   <a href="/wiki/Poblaci%C3%B3n" title="Población">
#    Población
#   </a>
#   (2020)
#  </th>
#  <td colspan="2" style="padding:2px 7px 1px 1px;">
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#   • Total
#  </th>
#  <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#   7 743 955 hab.
#   <sup class="reference separada" id="cite_ref-El_Tiempo_3-0">
#    <a href="#cite_note-El_Tiempo-3">
#     <span class="corchete-llamada">
#      [
#     </span>
#     3
#     <span class="corchete-llamada">
#      ]
#     </span>
#    </a>
#   </sup>
#   ​
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#   •
#   <a href="/wiki/Densidad_de_poblaci%C3%B3n" title="Densidad de población">
#    Densidad
#   </a>
#  </th>
#  <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#   4907,45 hab/km²
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#   • Urbana
#  </th>
#  <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#   7 412 566 hab.
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#   • Metropolitana
#  </th>
#  <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#   8 848 588
#   <sup class="reference separada" id="cite_ref-DANE_2020_ciudades_4-0">
#    <a href="#cite_note-DANE_2020_ciudades-4">
#     <span class="corchete-llamada">
#      [
#     </span>
#     4
#     <span class="corchete-llamada">
#      ]
#     </span>
#    </a>
#   </sup>
#   ​ hab.
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#   <a href="/wiki/Gentilicio" title="Gentilicio">
#    Gentilicio
#   </a>
#  </th>
#  <td colspan="2" style="padding:2px 7px 1px 1px;">
#   Bogotano, -na
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#   <a href="/wiki/Producto_interno_bruto" title="Producto interno bruto">
#    PIB
#   </a>
#   (nominal)
#  </th>
#  <td colspan="2" style="padding:2px 7px 1px 1px;">
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#   • Total
#  </th>
#  <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#   201.174 millones
#   <a class="mw-redirect" href="/wiki/D%C3%B3lar_estadunidense" title="Dólar estadunidense">
#    dólares
#   </a>
#   <sup class="reference separada" id="cite_ref-brookingsgdp_5-0">
#    <a href="#cite_note-brookingsgdp-5">
#     <span class="corchete-llamada">
#      [
#     </span>
#     5
#     <span class="corchete-llamada">
#      ]
#     </span>
#    </a>
#   </sup>
#   ​
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;border:0;padding:1px 7px;font-weight:100;">
#   • PIB per cápita
#  </th>
#  <td colspan="2" style="border:0;padding:1px 7px 1px 1px;">
#   26.013
#   <a class="mw-redirect" href="/wiki/D%C3%B3lar_estadunidense" title="Dólar estadunidense">
#    dólares
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#   <a class="mw-redirect" href="/wiki/%C3%8Dndice_de_Desarrollo_Humano" title="Índice de Desarrollo Humano">
#    IDH
#   </a>
#   (2018
#   <sup class="reference separada" id="cite_ref-6">
#    <a href="#cite_note-6">
#     <span class="corchete-llamada">
#      [
#     </span>
#     6
#     <span class="corchete-llamada">
#      ]
#     </span>
#    </a>
#   </sup>
#   ​)
#  </th>
#  <td colspan="2" style="padding:2px 7px 1px 1px;">
#   <span title="Crecimiento">
#    <img alt="Crecimiento" data-file-height="300" data-file-width="300" decoding="async" height="11" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/11px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/17px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/22px-Increase2.svg.png 2x" width="11"/>
#   </span>
#   0,806
#   <span style="color:#009900;">
#    <b>
#     Muy alto
#    </b>
#   </span>
#   (
#   <a href="/wiki/Anexo:Departamentos_de_Colombia_por_IDH" title="Anexo:Departamentos de Colombia por IDH">
#    1 de 33
#   </a>
#   .º)
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#   <a href="/wiki/Huso_horario" title="Huso horario">
#    Huso horario
#   </a>
#  </th>
#  <td colspan="2" style="padding:2px 7px 1px 1px;">
#   <a href="/wiki/UTC-05:00" title="UTC-05:00">
#    UTC-5
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#   <a href="/wiki/Anexo:C%C3%B3digos_postales_de_Colombia" title="Anexo:Códigos postales de Colombia">
#    Código postal
#   </a>
#  </th>
#  <td colspan="2" style="padding:2px 7px 1px 1px;">
#   <span class="postal-code">
#    11
#   </span>
#   <sup class="reference separada" id="cite_ref-7">
#    <a href="#cite_note-7">
#     <span class="corchete-llamada">
#      [
#     </span>
#     7
#     <span class="corchete-llamada">
#      ]
#     </span>
#    </a>
#   </sup>
#   ​
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#   <a href="/wiki/Prefijo_telef%C3%B3nico" title="Prefijo telefónico">
#    Prefijo telefónico
#   </a>
#  </th>
#  <td colspan="2" style="padding:2px 7px 1px 1px;">
#   1
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#   <a class="mw-redirect" href="/wiki/Matr%C3%ADcula_(autom%C3%B3viles)" title="Matrícula (automóviles)">
#    Matrícula
#   </a>
#  </th>
#  <td colspan="2" style="padding:2px 7px 1px 1px;">
#   BOG
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#   <a href="/wiki/Santo_patr%C3%B3n" title="Santo patrón">
#    Patrono(a)
#   </a>
#  </th>
#  <td colspan="2" style="padding:2px 7px 1px 1px;">
#   <a href="/wiki/Inmaculada_Concepci%C3%B3n" title="Inmaculada Concepción">
#    Inmaculada Concepción
#   </a>
#   <br/>
#   /
#   <a class="mw-redirect" href="/wiki/Santa_Isabel_de_Hungr%C3%ADa" title="Santa Isabel de Hungría">
#    Santa Isabel de Hungría
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;padding:2px 7px; width:30%;;">
#   Otras superficies:
#  </th>
#  <td colspan="2" style="padding:2px 7px 1px 1px;">
#   Urbana: 307,36 km²
#   <br/>
#   Suburbana: 170,45 km²
#   <br/>
#   Rural: 1298,15 km²
#  </td>
# </tr>
#
# <tr>
#  <td colspan="3" style="text-align:center;padding:2px 7px 1px 1px;">
#   <a class="external text" href="http://www.bogota.gov.co/" rel="nofollow">
#    Sitio web oficial
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <td class="noprint" colspan="3" style="text-align:left;">
#   <div class="plainlinks wikidata-link" style="font-size: 0.85em">
#    [
#    <a class="extiw" href="https://www.wikidata.org/wiki/Q2841" title="d:Q2841">
#     editar datos en Wikidata
#    </a>
#    ]
#   </div>
#  </td>
# </tr>

# %%
# Función para obtener los valores dados diferentes casos, además, se reemplazan caracteres extraños (unicode).
def obtener_valores(fila_data):
    if fila_data.find("div") and fila_data.find("br"):
        return [texto for texto in fila_data.stripped_strings]
    else:
        return fila_data.get_text(" ").replace("\xa0", " ").replace("\u200b", "").strip()

# Crear función para eliminar etiquetas [1] (span) solo en el caso de que no tengan información relevante
def limpiar_etiquetas(bs_objeto):
    if bs_objeto.find_all("sup", {'class': 'reference separada'}):
        for etiqueta in bs_objeto.find_all("sup"):
            etiqueta.decompose()
    pass

limpiar_etiquetas(bsobj)
         
municipios_info = {}

# Crear una lista de títulos para tomar el indice desde el cuál empezar a obtener los datos
titulos = [fila.get('title') for fila in info_caja.find_all("a") if fila.get('title') is not None]
contador = 0
for indice, fila in enumerate(info_filas):
    if indice == 0 and fila.find("th"):
        municipios_info['municipio'] = fila.find("th").get_text(" ", strip=True)
    # En caso de que el tag "th" no contenga información o no exista, tomar el nombre del municipio del encabezado (tag "h1")
    elif indice == 0 and not fila.find("th"):
        municipios_info['municipio'] = bsobj.find("h1").get_text(" ", strip=True)
    elif indice < titulos.index('Coordenadas geográficas'): # Imágenes y otros datos irrelevantes no serán tenidos en cuenta
        continue
    else: # Las filas de tabla (tr) que no contengan elementos "th" & "td" serán evitadas
        try:
            # Se obtiene las llaves y se reemplazan caracteres extraños. 
            # Se anexa un número a aquellas llaves que posean el mismo nombre "* Total" para evitar errores en los datos
            if fila.find("th").get_text(" ", strip=True) == "• Total":
                llaves = fila.find("th").get_text(" ", strip=True).replace("•", "").strip() + f"_{contador}"
                valores = obtener_valores(fila.find("td"))
                municipios_info[llaves] = valores
                contador += 1
            else:
                llaves = fila.find("th").get_text(" ", strip=True).replace("•", "").replace("\u200b", "").strip()
                valores = obtener_valores(fila.find("td"))
                municipios_info[llaves] = valores
        except AttributeError as e:
            pass

municipios_info
# Out:
# {'municipio': 'Bogotá',
#  'Subdivisiones': '20  localidades 1922  barrios',
#  'Localidades': ['Ver lista',
#   'Usaquén',
#   'Chapinero',
#   'Santa Fe',
#   'San Cristóbal',
#   'Usme',
#   'Tunjuelito',
#   'Bosa',
#   'Kennedy',
#   'Fontibón',
#   'Engativá',
#   'Suba',
#   'Barrios Unidos',
#   'Teusaquillo',
#   'Los Mártires',
#   'Antonio Nariño',
#   'Puente Aranda',
#   'La Candelaria',
#   '(Centro Histórico)',
#   'Rafael Uribe Uribe',
#   'Ciudad Bolívar',
#   'Sumapaz'],
#  'Eventos históricos': '',
#  'Fundación': '6 de agosto de 1538 (483 años)   ( Gonzalo Jiménez de Quesada )',
#  'Erección': '3 de diciembre de 1548 (472 años)',
#  'Creación': '17 de diciembre de 1954 (66 años) (conformación del  Distrito Capital )',
#  'Superficie': '',
#  'Total_0': '1775  km²',
#  'Altitud': '',
#  'Media': '2640  m s. n. m.',
#  'Máxima': '4000  m s. n. m.',
#  'Mínima': '2540  m s. n. m.',
#  'Clima': 'Oceánico mediterráneo  Csb',
#  'Población (2020)': '',
#  'Total_1': '7 743 955 hab.',
#  'Densidad': '4907,45 hab/km²',
#  'Urbana': '7 412 566 hab.',
#  'Metropolitana': '8 848 588  hab.',
#  'Gentilicio': 'Bogotano, -na',
#  'PIB (nominal)': '',
#  'Total_2': '201.174 millones  dólares',
#  'PIB per cápita': '26.013  dólares',
#  'IDH (2018 )': '0,806  Muy alto  ( 1 de 33 .º)',
#  'Huso horario': 'UTC-5',
#  'Código postal': '11',
#  'Prefijo telefónico': '1',
#  'Matrícula': 'BOG',
#  'Patrono(a)': 'Inmaculada Concepción /  Santa Isabel de Hungría',
#  'Otras superficies:': 'Urbana: 307,36 km² Suburbana: 170,45 km² Rural: 1298,15 km²'}

# %% [markdown]
# #### Tarea #2: Obtener la información para todos los municipios de Colombia

# %%
# Cargar el contenido de la página (Lista de municipios de Colombia por población)
url = requests.get("https://es.wikipedia.org/wiki/Anexo:Municipios_de_Colombia_por_poblaci%C3%B3n")

# Convertir a un objeto BS
bso = bs(url.content)

# Imprimir HTML
print(bso.prettify())

# %%
# Extraer las etiquetas "href" para la clase especificada
municipios = bso.select(".wikitable.sortable td")
rutas = [m.a['href'] for m in municipios if m.a and m.get('align') is None]
print(rutas)

# %%
# Extraer las rutas de cada municipio y formar junto al dominio, los enlaces completos.

dominio = "https://es.wikipedia.org"
enlaces = []
for ruta in rutas:
    enlaces.append(dominio + ruta)

# %%
# En algunos casos, las rutas estaban conectadas a municipalidades de otros paises. Se cambian por los enlaces correctos
for n, i in enumerate(enlaces):
    if i == 'https://es.wikipedia.org/wiki/Aquitania':
        enlaces[n] = 'https://es.wikipedia.org/wiki/Aquitania_(Boyac%C3%A1)'
    elif i == 'https://es.wikipedia.org/wiki/Saman%C3%A1':
        enlaces[n] = 'https://es.wikipedia.org/wiki/Saman%C3%A1_(Caldas)'
    elif i == 'https://es.wikipedia.org/wiki/Roncesvalles':
        enlaces[n] = 'https://es.wikipedia.org/wiki/Roncesvalles_(Tolima)'

# %%
# Crear función para obtener los valores dependiendo de la etiqueta, además, se eliminan caracteres extraños.
def obtener_valores(fila_data):
    if fila_data.find("div") and fila_data.find("br"):
        return [texto for texto in fila_data.stripped_strings]
    else:
        return fila_data.get_text(" ").replace("\xa0", " ").replace("\u200b", "").strip()

# Crear función para eliminar etiquetas [1] (span) solo en el caso de que no tengan información relevante
def limpiar_etiquetas(bs_objeto):
    if bs_objeto.find_all("sup", {'class': 'reference separada'}):
        for etiqueta in bs_objeto.find_all("sup"):
            etiqueta.decompose()
    pass

# Crear función para obtener la información de un municipio dada su dirección url.
def obtener_info(url):
    
    w = requests.get(url)
    
    bsobj = bs(w.content)
    info_caja = bsobj.find(class_="infobox geography vcard")
    info_filas = info_caja.find_all("tr")
    
    limpiar_etiquetas(bsobj)
    
    municipios_info = {}

    # Crear una lista de títulos para tomar el indice desde el cuál empezar a obtener los datos
    titulos = [fila.get('title') for fila in info_caja.find_all("a") if fila.get('title') is not None]
    contador = 0
    for indice, fila in enumerate(info_filas):
        if indice == 0 and fila.find("th"):
            municipios_info['municipio'] = fila.find("th").get_text(" ", strip=True)
        # En el caso de que no exista la etiqueta "th", será necesario tomar el nombre de la cabecera "h1" del código HTML.
        elif indice == 0 and not fila.find("th"):
            municipios_info['municipio'] = bsobj.find("h1").get_text(" ", strip=True)
        elif indice < titulos.index('Coordenadas geográficas'): # Imágenes y otros datos irrelevantes no serán tenidos en cuenta
            continue
        # Manejo de excepciones y reemplazo de strings en la obtención de los datos
        else:
            try:# Caso especial: En el caso de que una dos etiquetas "th" contengan el mismo texto, se le agrega un caracter 
                # adicional al texto para diferenciarlos, y así evitar errores en la conexión con los "td" relacionados.
                if fila.find("th").get_text(" ", strip=True) == "• Total":
                    llaves = fila.find("th").get_text(" ", strip=True).replace("•", "").strip() + f"_{contador}"
                    valores = obtener_valores(fila.find("td"))
                    municipios_info[llaves] = valores
                    contador += 1
                # Evitar tomar los datos de IDH y Población Metropolitana, debido a que solo se encuentran contabilizados en pocos municipios (Ciudades Capitales)
                elif 'IDH' in fila.find("th").get_text(" ", strip=True).upper() or 'METROPOLITANA' in fila.find("th").get_text(" ", strip=True).upper():
                    continue
                else:
                    llaves = fila.find("th").get_text(" ", strip=True).replace("•", "").replace("\u200b", "").strip()
                    valores = obtener_valores(fila.find("td"))
                    municipios_info[llaves] = valores
            except AttributeError as e:
                pass

    return municipios_info

# %%
# Probar la función "obtener_info()" para solo un municipio. Verificar que funcione correctamente.
obtener_info("https://es.wikipedia.org/wiki/Medell%C3%ADn")
# Out:
# {'municipio': 'Medellín',
#  'Coordenadas': '6°14′41″N  75°34′29″O \ufeff / \ufeff 6.2447472222222,  -75.574827777778 Coordenadas :  6°14′41″N  75°34′29″O \ufeff / \ufeff 6.2447472222222,  -75.574827777778',
#  'Entidad': 'Municipio',
#  'País': 'Colombia',
#  'Departamento': 'Antioquia',
#  'Región': 'Valle de Aburrá',
#  'Alcalde': 'Daniel Quintero Calle  ( Independientes )   2020 - 2023',
#  'Subdivisiones': '5  corregimientos  16  comunas  275  barrios',
#  'Corregimientos': ['Ver lista',
#   'Altavista',
#   'Palmitas',
#   'San Antonio de Prado',
#   'San Cristóbal',
#   'Santa Elena'],
#  'Comunas': ['Ver lista',
#   'Aranjuez',
#   'Belén',
#   'Buenos Aires',
#   'Castilla',
#   'Doce de Octubre',
#   'El Poblado',
#   'Guayabal',
#   'La América',
#   'La Candelaria',
#   'Laureles - Estadio',
#   'Manrique',
#   'Popular',
#   'Robledo',
#   'San Javier',
#   'Santa Cruz',
#   'Villa Hermosa'],
#  'Eventos históricos': '',
#  'Fundación': '2 de marzo  de  1616  (405 años)  ( Miguel de Aguinaga y Mendigoitia )',
#  'Erección': '21 de agosto  de  1813',
#  'Superficie': '',
#  'Total_0': '382  km²',
#  'Altitud': '',
#  'Media': '1495  m s. n. m.',
#  'Clima': 'Tropical monzónico  Am   Subtropical húmedo  Cfa  22 °C (promedio)',
#  'Población (2020)': '',
#  'Total_1': '2 533 424 hab.',
#  'Densidad': '6643,39 hab/km²',
#  'Urbana': '2 501 470 hab.',
#  'Gentilicio': 'Medellinense',
#  'Huso horario': 'UTC  -5',
#  'Código postal': '050001',
#  'Prefijo telefónico': '4',
#  'Fiestas mayores': 'Feria de las Flores',
#  'Patrono(a)': 'Virgen de la Candelaria'}

# %%
# Se inicia el proceso de extracción de datos para todos los municipios (Guardar todos los diccionarios en una lista)

municipios = []
for enlace in enlaces:
    try:
        municipios.append(obtener_info(enlace))
    except Exception as e:
        print(enlace)
        print(e)
# Out:
# https://es.wikipedia.org/wiki/Isla_de_San_Andr%C3%A9s_(Colombia)
# 'NoneType' object has no attribute 'find_all'
# https://es.wikipedia.org/wiki/Cerrito_(Santander)
# 'NoneType' object has no attribute 'find_all'
# https://es.wikipedia.org/wiki/Isla_de_Providencia
# 'NoneType' object has no attribute 'find_all'
# https://es.wikipedia.org/wiki/%C3%9Atica
# 'NoneType' object has no attribute 'find_all'

# %%
len(municipios)
# Se logra obtener los datos de 1118 municipios de 1122 existentes. 
# Para el caso de los municipios de "Isla de San Andrés" e "Isla de Providencia" las tablas no soportan el método "find_all"
# En los otros dos casos, no existe una tabla para la obtención de los datos.
# Out:
# 1118

# %%
# Definir una función para guardar el archivo .json y otra para cargar el archivo .json

import json

def guardar_datos(titulo, datos):
    with open(titulo, 'w', encoding='utf-8') as a:
        json.dump(datos, a, ensure_ascii=False, indent=2)
        
def cargar_datos(titulo):
    with open(titulo, encoding="utf-8") as a:
        return json.load(a)

# %%
# Guardar resultados obtenidos hasta el momento.

guardar_datos("municipios_col.json", municipios)

# %% [markdown]
# #### Tarea #3: Limpieza de Datos

# %%
# Cargar datos

municipios_col = cargar_datos("municipios_col.json")

# %%
# Imprimir todas las distintas llaves de la lista de dictionarios

all_keys = set().union(*(d.keys() for d in municipios_col))
all_keys

# Se identifican diversas llaves que no contienen información relevante, otras que contienen valores faltantes excesivos,
# algunas difieren en el nombre pero guardan valores similares.
# Out:
# {'',
#  'Aeropuerto',
#  'Alcald',
#  'Alcalde',
#  'Alcalde 2020 - 2023 Camilo Correa Álvarez',
#  'Alcalde 2020-2023',
#  'Alcalde Distrital',
#  'Alcalde Federico alfonso  gomez jimenez',
#  'Alcalde Municipal',
#  'Alcalde de Plato',
#  'Alcalde, Alcalde (Interino)',
#  'Alcaldes',
#  'Alcaldesa',
#  'Altitud',
#  "Autoridad tradicional Ne'jwesx 2019 - 2021",
#  'Ave',
#  'Barrios',
#  'Cabecera',
#  'Cabecera municipal',
#  'Capital',
#  'Caseríos',
#  'Centros Poblados',
#  'Clima',
#  'Comunas',
#  'Coordenadas',
#  'Corregidor',
#  'Corregimientos',
#  'Creación',
#  'Curso de agua',
#  'Código Dane (Divipola)',
#  'Código Dian',
#  'Código ZIP',
#  'Código postal',
#  'Densidad',
#  'Departamento',
#  'Departamento Boyacá',
#  'Departamentos',
#  'Departamentos de abril',
#  'Entidad',
#  'Erección',
#  'Eventos históricos',
#  'Fiestas mayores',
#  'Flor',
#  'Fundación',
#  'Gentilicio',
#  'Hermanada con',
#  'Huso horario',
#  'Idioma oficial',
#  'Localidades',
#  'Matrícula',
#  'Media',
#  'Moneda',
#  'Municipio',
#  'Municipio Barrancominas',
#  'Máxima',
#  'Mínima',
#  'Nombre',
#  'Otras Superficies:',
#  'Otras superficies:',
#  'Otros idiomas',
#  'PIB (nominal)',
#  'PIB per cápita',
#  'Partidos gobernantes',
#  'Patrono(a)',
#  'País',
#  'Población ( 2018 )',
#  'Población ()',
#  'Población (2005)',
#  'Población (2015\nclima                  =12ºC)',
#  'Población (2015)',
#  'Población (2016)',
#  'Población (2017)',
#  'Población (2018)',
#  'Población (2019)',
#  'Población (2020 est. )',
#  'Población (2020)',
#  'Población (2021)',
#  'Población (4512)',
#  'Población (5105)',
#  'Población (Censo DANE 2018)',
#  'Población (Proyección 2020)',
#  'Prefijo telefónico',
#  'Presupuesto anual',
#  'Provincia',
#  'Región',
#  'Subdivisiones',
#  'Subregión',
#  'Superficie',
#  'Temperatura',
#  'Temperatura promedio',
#  'Total_0',
#  'Total_1',
#  'Total_2',
#  'Urbana',
#  'Veredas',
#  'Zona',
#  '[[Departamentos de \nColombia|Departamento]]',
#  '[xau[Subregiones de Antioquia',
#  'departamento',
#  'municipio',
#  'Árbol'}

# %%
# Para este ejercicio, se trabaja con la información bajo un DataFrame (para facilitar algunas operaciones de limpieza)

municipios_df = pd.DataFrame(municipios_col)

# %%
# Aquitania Boyacá (Cambiar link) https://es.wikipedia.org/wiki/Aquitania_(Boyac%C3%A1)
# Samaná Caldas (Cambiar link) https://es.wikipedia.org/wiki/Saman%C3%A1_(Caldas)
# Roncesvalles Tolima (Cambiar link) https://es.wikipedia.org/wiki/Roncesvalles_(Tolima)
# Eliminar key "Aeropuerto"
# Eliminar key "Autoridad tradicional Ne'jwesx 2019 - 2021"
# Eliminar "Flor", "Arbol", "Ave", "Cabecera", "Cabecera municipal", "Capital", "Barrios", "Veredas", "Caseríos"
# Eliminar "Centros Poblados", "Hermanada con", "Idioma oficial", "Moneda", "Máxima", "Mínima", "Matrícula"
# Unir Alcalde/Corregidor
# Unir localidades, comunas, barrios
# Eliminar "Otras S(s)uperficies" 'PIB (nominal)','PIB per cápita','Partidos gobernantes'
# Eliminar 'Presidente regional','Presupuesto anual', 'Temperatura', 'Temperatura promedio', 'Total_2'
# Ajustar verdadero nombre '[[Departamentos de \nColombia|Departamento]]','[xau[Subregiones de Antioquia'

# %%
municipios_df.head()
# Out:
#                municipio                                  Subdivisiones  \
# 0                 Bogotá                  20  localidades 1922  barrios
# 1               Medellín   5  corregimientos  16  comunas  275  barrios
# 2  Cali Santiago de Cali  15  corregimientos  22  comunas  249  barrios
# 3           Barranquilla  2  corregimientos 5  localidades 188  barrios
# 4    Cartagena de Indias                                            NaN
#
#                                          Localidades Eventos históricos  \
# 0  [Ver lista, Usaquén, Chapinero, Santa Fe, San ...
# 1                                                NaN
# 2                                                NaN
# 3  [Ver lista, Riomar, Norte-Centro Histórico, Su...
# 4                                                NaN
#
#                                            Fundación  \
# 0  6 de agosto de 1538 (483 años)   ( Gonzalo Jim...
# 1  2 de marzo  de  1616  (405 años)  ( Miguel de ...
# 2  25 de julio  de  1536  (485 años)  (por  Sebas...
# 3                                  Entre 1627 y 1637
# 4  1 de junio  de  1533  (488 años)  ( Pedro de H...
#
#                             Erección  \
# 0  3 de diciembre de 1548 (472 años)
# 1             21 de agosto  de  1813
# 2              17 de junio  de  1559
# 3                 7 de abril de 1813
# 4                               1533
#
#                                             Creación Superficie     Total_0  \
# 0  17 de diciembre de 1954 (66 años) (conformació...              1775  km²
# 1                                                NaN               382  km²
# 2                                                NaN               564  km²
# 3                                                NaN               154  km²
# 4                                                NaN             609.1  km²
#
#   Altitud  ... Barrios Población (2015\nclima                  =12ºC)  \
# 0          ...     NaN                                            NaN
# 1          ...     NaN                                            NaN
# 2          ...     NaN                                            NaN
# 3          ...     NaN                                            NaN
# 4          ...     NaN                                            NaN
#
#   Población ( 2018 ) Alcald Departamento Boyacá Población (4512) departamento  \
# 0                NaN    NaN                 NaN              NaN          NaN
# 1                NaN    NaN                 NaN              NaN          NaN
# 2                NaN    NaN                 NaN              NaN          NaN
# 3                NaN    NaN                 NaN              NaN          NaN
# 4                NaN    NaN                 NaN              NaN          NaN
#
#   Corregidor Departamentos de abril Municipio Barrancominas
# 0        NaN                    NaN                     NaN
# 1        NaN                    NaN                     NaN
# 2        NaN                    NaN                     NaN
# 3        NaN                    NaN                     NaN
# 4        NaN                    NaN                     NaN
#
# [5 rows x 101 columns]

# %% [markdown]
# ##### ** Eliminar columnas con información irrelevante, incompleta o nula **

# %%
columnas_erradas = ["Aeropuerto", "Flor", "Arbol", "Árbol", "Ave", "Cabecera", "Cabecera municipal",
        "Capital", "Barrios", "Veredas", "Caseríos", "Centros Poblados", "Nombre", "Fiestas mayores",
        "Hermanada con","Idioma oficial","Moneda","Máxima","Mínima","Matrícula","Patrono(a)","Localidades",
        "Otras Superficies:","PIB (nominal)","PIB per cápita","Partidos gobernantes","Corregimientos",
        "Otras superficies:", "Presidente regional","Presupuesto anual", "Temperatura", "Creación",
        "Temperatura promedio", "Total_2", "Eventos históricos","Superficie","Altitud", "Comunas",
        "Curso de agua","Código Dane (Divipola)","Código Dian","Correspondencia actual","Subdivisiones",
        "Autoridad tradicional Ne'jwesx 2019 - 2021", "Otros idiomas", "", "Prefijo telefónico",
        "Región", "Provincia", "Zona"]

for col in columnas_erradas:
    if col in municipios_df.columns:
        municipios_df = municipios_df.drop(col, 1)
    continue

#municipio['Superficie'] = municipio.pop('Total_0')
#municipio['Altitud Media'] = municipio.pop('Media')
# Unir Región, Subregión y Zona

# %%
# Las columnas 'Total_0', Total_1', 'Urbana' y 'Media' contiene la información correspondiente 
# a 'Superficie', 'Población', 'Pobl. Urbana' y 'Altitud Media' respectivamente, por lo tanto,
# cambiamos el nombre de las columnas.

municipios_df = municipios_df.rename(columns={'Total_0': 'Superficie', 'Total_1': 'Población Total',
                                              'Media': 'Altitud Media', 'Urbana': 'Pobl. Urbana'})

# %% [markdown]
# ##### ** Unir columnas con igual información pero diferente nombre **

# %%
# Reducir a una sola columna aquellas que contienen la misma información pero difieren en su encabezado

from re import search

columnas = {'lcald': 'Alcalde', 'epartamento': 'Departamento', 'unicipio': 'Municipio',
           'oblación': 'Población Total', 'Subregi': 'Subregión', 'Código': 'Código postal'}

for col in municipios_df.columns:
    for key, value in columnas.items():
        if search(key, col) and col != value:
            municipios_df[value].fillna(municipios_df[col], inplace=True)
            municipios_df = municipios_df.drop(col, 1)
        continue

municipios_df = municipios_df.drop("Subregión", 1)

# %%
# Unir las columnas Alcalde/Corregidor

municipios_df['Alcalde'].fillna(municipios_df['Corregidor'], inplace=True)
municipios_df = municipios_df.drop('Corregidor', 1)

# %% [markdown]
# ##### Extraer y añadir la información de códigos postales para todos los municipios

# %%
# Extraer el contenido de la página y crear el objeto BS (Departamentos)

url = requests.get("https://codigo-postal.co/colombia/")
soup = bs(url.content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Código Postal de Colombia
#   </title>
#   <meta content="codigo-postal.co" name="author"/>
#   <meta content="Descubre el Código Postal de Colombia. Selecciona el departamento, luego el municipio y, por fin, filtra por la localidad o barrio para encontrar el código postal correspondiente." name="description"/>
#   <meta content="286861161921582" property="fb:app_id"/>
#   <meta content="Código Postal de Colombia" property="og:title"/>
#   <meta content="https://codigo-postal.co/colombia/" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://cdn.codigo-postal.co/data/co/images/colombia.svg" property="og:image"/>
#   <meta content="Descubre el Código Postal de Colombia. Selecciona el departamento, luego el municipio y, por fin, filtra por la localidad o barrio para encontrar el código postal correspondiente." property="og:description"/>
#   <link href="https://codigo-postal.co/colombia/" hreflang="es" rel="alternate"/>
#   <link href="https://codigo-postal.co/en-us/colombia/" hreflang="en-US" rel="alternate"/>
#   <link href="https://codigo-postal.co/pt-br/colombia/" hreflang="pt-BR" rel="alternate"/>
#   <!-- CSS files -->
#   <link href="https://cdn.codigo-postal.co/assets/css/stylesheet-responsive-grid.co.min.css" rel="stylesheet" type="text/css"/>
#   <link href="https://cdn.codigo-postal.co/assets/css/stylesheet-responsive.co.min.css" rel="stylesheet" type="text/css"/>
#   <link href="https://cdn.codigo-postal.co/data/co/images/spritesheet/departamentos.css" rel="stylesheet" type="text/css"/>
#   <!-- Favorite Icon -->
#   <link href="https://codigo-postal.co/images/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <!-- Jquery -->
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.4.1/jquery.min.js">
#   </script>
#   <style>
#    ul.column-list{column-count:1;-moz-column-count:1;-webkit-column-count:1;list-style:none;margin:10px;padding:0}ul.column-list li{height:49px;line-height:49px;margin-left:10px;border-bottom:1px solid #f1f1f1;font-size:16px}ul.column-list li img{width:40px;margin-right:8px;border:1px solid #e1e1e1}@media (min-width:768px){ul.column-list{column-count:2;-moz-column-count:2;-webkit-column-count:2}}
# 			.co{background-image:url(https://cdn.codigo-postal.org/data/co/images/spritesheet/departamentos.png);background-repeat:no-repeat;display:inline-block;border:1px solid #f1f1f1;margin-right:7px;vertical-align:middle}
# 			@media screen and (max-width:960px){.ad-slot{min-height:280px}}
#   </style>
#  </head>
#  <body>
#   <div id="fb-root">
#   </div>
#   <script async="" crossorigin="anonymous" defer="" nonce="XYNssKb4" src="https://connect.facebook.net/es_ES/sdk.js#xfbml=1&amp;version=v9.0&amp;appId=286861161921582&amp;autoLogAppEvents=1">
#   </script>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		  })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# 		  ga('create', 'UA-19355113-6', 'auto');
# 		  ga('send', 'pageview');
#   </script>
#   <script>
#    function openNav() {document.getElementById("offcanvas_menu").style.left = "0px";document.getElementById("offcanvas_menu").style.position = "fixed";}
# 		function closeNav() {document.getElementById("offcanvas_menu").style.left = "-300px";document.getElementById("offcanvas_menu").style.position = "absolute";}
#   </script>
#   <!-- Offcanvas Menu -->
#   <div class="offcanvas-menu" id="offcanvas_menu">
#    <div class="clearfix">
#     <a class="xclose off-canvas-menu-toogle" onclick="closeNav();" style="margin-right:15px;padding: 5px 10px;" title="Cerrar">
#      ×
#     </a>
#    </div>
#    <div class="clearfix">
#     <ul>
#      <li>
#       <a href="https://codigo-postal.co/">
#        inicio
#       </a>
#      </li>
#      <li>
#       <a href="https://codigo-postal.co/mi-codigo-postal/">
#        mi código postal
#       </a>
#      </li>
#      <li>
#       <a href="https://codigo-postal.co/blog/">
#        blog
#       </a>
#      </li>
#     </ul>
#    </div>
#   </div>
#   <!-- Fixed navbar -->
#   <nav class="navbar">
#    <div class="container">
#     <div class="navbar-header">
#      <button class="navbar-toggle hidden-lg off-canvas-menu-toogle" id="offcanvas_menu_button" onclick="openNav();" type="button">
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#      </button>
#      <a class="navbar-brand visible-lg-block" href="/" title="codigo-postal.co">
#      </a>
#      <a class="navbar-brand-xs hidden-lg" href="/" title="codigo-postal">
#      </a>
#     </div>
#     <div class="navbar-collapse collapse">
#      <ul class="nav navbar-nav visible-lg-block">
#       <li>
#        <a href="https://codigo-postal.co/">
#         inicio
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/mi-codigo-postal/">
#         mi código postal
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/blog/">
#         blog
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </nav>
#   <div id="ant" style="position:fixed;top:70px;right:20px;display:block;height:26px;">
#    <img alt="the ant game" height="26" id="the_ant" src="/images/template/smallant.gif" width="26"/>
#   </div>
#   <!-- Content -->
#   <div class="container content_container" style="margin-top:60px;">
#    <div class="row">
#     <!-- Left column -->
#     <div class="col-md-2">
#      <div class="ad-slot">
#       <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#       </script>
#       <!-- codigo-postal.org | Left Column -->
#       <ins class="adsbygoogle" data-ad-client="ca-pub-3248513691157520" data-ad-format="auto" data-ad-slot="5278200073" data-full-width-responsive="true" style="display:block">
#       </ins>
#       <script>
#        (adsbygoogle = window.adsbygoogle || []).push({});
#       </script>
#      </div>
#     </div>
#     <!-- Main column -->
#     <div class="col-md-6">
#      <div class="breadcrumbs_div">
#       <ol class="breadcrumb" itemscope="" itemtype="http://schema.org/BreadcrumbList">
#        <li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#         <a href="https://codigo-postal.co/" itemprop="item" title="Código Postal">
#          <span itemprop="name">
#           Código Postal
#          </span>
#         </a>
#         <meta content="1" itemprop="position"/>
#        </li>
#        <li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#         <span itemprop="name">
#          Colombia
#         </span>
#         <meta content="2" itemprop="position"/>
#        </li>
#       </ol>
#      </div>
#      <h1 itemprop="headline">
#       Código Postal de Colombia
#      </h1>
#      <p>
#       En esta plataforma buscamos incentivar la utilización del código postal en Colombia. Ten en cuenta que no existe código postal general para el país. Deberás navegar por departamentos, luego por municipios hasta encontrar el código postal de tu zona.
#      </p>
#      <h2>
#       Elige el departamento para buscar el código postal
#      </h2>
#      <ul class="column-list">
#       <li>
#        <a href="https://codigo-postal.co/colombia/amazonas/" title="Código Postal Amazonas">
#         <span class="co co-amazonas">
#         </span>
#         Amazonas
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/antioquia/" title="Código Postal Antioquia">
#         <span class="co co-antioquia">
#         </span>
#         Antioquia
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/arauca/" title="Código Postal Arauca">
#         <span class="co co-arauca">
#         </span>
#         Arauca
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/archipielago-de-san-andres/" title="Código Postal San Andres">
#         <span class="co co-archipielago-de-san-andres">
#         </span>
#         Archipielago de San Andres
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/atlantico/" title="Código Postal Atlántico">
#         <span class="co co-atlantico">
#         </span>
#         Atlantico
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/bogota-dc/" title="Código Postal Bogotá">
#         <span class="co co-bogota-dc">
#         </span>
#         Bogota DC
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/bolivar/" title="Código Postal Bolivar">
#         <span class="co co-bolivar">
#         </span>
#         Bolivar
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/boyaca/" title="Código Postal Boyacá">
#         <span class="co co-boyaca">
#         </span>
#         Boyaca
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/caldas/" title="Código Postal Caldas">
#         <span class="co co-caldas">
#         </span>
#         Caldas
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/caqueta/" title="Código Postal Caquetá">
#         <span class="co co-caqueta">
#         </span>
#         Caqueta
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/casanare/" title="Código Postal Casanare">
#         <span class="co co-casanare">
#         </span>
#         Casanare
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/cauca/" title="Código Postal Cauca">
#         <span class="co co-cauca">
#         </span>
#         Cauca
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/cesar/" title="Código Postal Cesar">
#         <span class="co co-cesar">
#         </span>
#         Cesar
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/choco/" title="Código Postal Chocó">
#         <span class="co co-choco">
#         </span>
#         Choco
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/cordoba/" title="Código Postal Cordoba">
#         <span class="co co-cordoba">
#         </span>
#         Cordoba
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/cundinamarca/" title="Código Postal Cundinamarca">
#         <span class="co co-cundinamarca">
#         </span>
#         Cundinamarca
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/guainia/" title="Código Postal Guainia">
#         <span class="co co-guainia">
#         </span>
#         Guainia
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/guaviare/" title="Código Postal Guaviare">
#         <span class="co co-guaviare">
#         </span>
#         Guaviare
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/huila/" title="Código Postal Huila">
#         <span class="co co-huila">
#         </span>
#         Huila
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/la-guajira/" title="Código Postal Guajira">
#         <span class="co co-la-guajira">
#         </span>
#         La Guajira
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/magdalena/" title="Código Postal Magdalena">
#         <span class="co co-magdalena">
#         </span>
#         Magdalena
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/meta/" title="Código Postal Meta">
#         <span class="co co-meta">
#         </span>
#         Meta
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/narino/" title="Código Postal Nariño">
#         <span class="co co-narino">
#         </span>
#         Nariño
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/norte-de-santander/" title="Código Postal Norte de Santander">
#         <span class="co co-norte-de-santander">
#         </span>
#         Norte de Santander
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/putumayo/" title="Código Postal Putumayo">
#         <span class="co co-putumayo">
#         </span>
#         Putumayo
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/quindio/" title="Código Postal Quindio">
#         <span class="co co-quindio">
#         </span>
#         Quindio
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/risaralda/" title="Código Postal Risaralda">
#         <span class="co co-risaralda">
#         </span>
#         Risaralda
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/santander/" title="Código Postal Santander">
#         <span class="co co-santander">
#         </span>
#         Santander
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/sucre/" title="Código Postal Sucre">
#         <span class="co co-sucre">
#         </span>
#         Sucre
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/tolima/" title="Código Postal Tolima">
#         <span class="co co-tolima">
#         </span>
#         Tolima
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/valle-del-cauca/" title="Código Postal Valle del Cauca">
#         <span class="co co-valle-del-cauca">
#         </span>
#         Valle del Cauca
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/vaupes/" title="Código Postal Vaupes">
#         <span class="co co-vaupes">
#         </span>
#         Vaupes
#        </a>
#       </li>
#       <li>
#        <a href="https://codigo-postal.co/colombia/vichada/" title="Código Postal Vichada">
#         <span class="co co-vichada">
#         </span>
#         Vichada
#        </a>
#       </li>
#      </ul>
#      <div style="padding-top:10px">
#       <div class="question">
#        <h2>
#         El código postal en Colombia
#        </h2>
#        <p>
#         Desde 2009, el territorio colombiano es dividido en zonas postales, cada una de ellas cuenta con un código postal. El código postal colombiano tiene 6 dígitos, los dos primeros digitos hacen referencia a los departamentos, los siguientes a zonas regionales y los dos últimos a cada zona municipal. Para envío de cartas, encomiendas o paquetes siempre deberás utilizar el código postal para facilitar la entrega por la empresa transportadora.
#        </p>
#        <img alt="Departamentos de Colombia." src="https://cdn.codigo-postal.co/data/co/images/colombia.svg" width="100%"/>
#       </div>
#      </div>
#      <div style="margin-top:20px;width:100%;">
#       <h3>
#        Comentarios
#       </h3>
#       <div class="fb-comments" data-href="https://codigo-postal.co/colombia/" data-numposts="5" data-order-by="reverse_time" data-width="100%">
#       </div>
#      </div>
#     </div>
#     <!-- Right column -->
#     <div class="col-md-4">
#      <!-- Carbon Ad -->
#      <div>
#       <div class="carbonad">
#        <div class="clearfix slide" data-slide="0">
#         <div class="carbonad-image">
#          <a href="http://www.autoreseditores.com/index.html?utm_source=codigopostal&amp;utm_medium=sponsored_ads&amp;utm_content=quieres-publicar-tu-libro-text&amp;utm_campaign=codigopostal01" rel="noopener" target="_blank">
#           <img alt="" border="0" height="100" src="/images/ads/ad-01.jpg" style="float:left;max-width:130px;" width="130"/>
#          </a>
#         </div>
#         <div class="carbonad-text">
#          <span>
#           <a href="http://www.autoreseditores.com/index.html?utm_source=codigopostal&amp;utm_medium=sponsored_ads&amp;utm_content=quieres-publicar-tu-libro-text&amp;utm_campaign=codigopostal01" target="_blank" title="¿Cómo publicar un libro en Colombia?">
#            ¿Publicar un libro impreso en Colombia?
#           </a>
#           ¡Ahora es posible con
#           <strong>
#            AutoresEditores.com
#           </strong>
#           . Ordena la impresión desde un sólo ejemplar.
#          </span>
#         </div>
#         <span class="carbonad-tag">
#          recomendado por
#          <strong>
#           codigo-postal.co
#          </strong>
#         </span>
#        </div>
#        <div class="clearfix slide" data-slide="1" style="display:none;">
#         <div class="carbonad-image">
#          <a href="https://www.autoreseditores.com/publica-tu-libro.html?utm_source=codigopostal&amp;utm_medium=sponsored_ads&amp;utm_content=correccion-text&amp;utm_campaign=codigopostal02" rel="noopener" target="_blank">
#           <img alt="" border="0" height="100" src="/images/ads/ad-02.jpg" style="float:left;max-width:130px;" width="130"/>
#          </a>
#         </div>
#         <div class="carbonad-text">
#          <span>
#           <a href="http://www.autoreseditores.com/servicio-correccion-estilo.html?utm_source=codigopostal&amp;utm_medium=sponsored_ads&amp;utm_content=correccion-text&amp;utm_campaign=codigopostal02" target="_blank">
#            ¿Buscando editorial para publicar un libro en Colombia?
#           </a>
#           Ofrecemos servicio de corrección de estilo. Además puedes imprimir en formato libro y ordenar copias impresas desde un ejemplar.
#          </span>
#         </div>
#         <span class="carbonad-tag">
#          recomendado por
#          <strong>
#           codigo-postal.co
#          </strong>
#         </span>
#        </div>
#        <div class="clearfix slide" data-slide="2" style="display:none;">
#         <div class="carbonad-image">
#          <a href="https://www.autoreseditores.com/como-funciona.html?utm_source=codigopostal&amp;utm_medium=sponsored_ads&amp;utm_content=mercadeo-text&amp;utm_campaign=codigopostal03" rel="noopener" target="_blank">
#           <img alt="" border="0" height="100" src="/images/ads/ad-05.png" style="float:left;max-width:130px;" width="130"/>
#          </a>
#         </div>
#         <div class="carbonad-text">
#          <span>
#           Publicar un libro es solamente el primer paso de un largo camino a ser recorrido. AutoresEditores.com es la
#           <a href="https://www.autoreseditores.com/como-funciona.html?utm_source=codigopostal&amp;utm_medium=sponsored_ads&amp;utm_content=editorial-independiente&amp;utm_campaign=codigopostal03" target="_blank">
#            editorial independiente
#           </a>
#           que te ayudará a alcanzar tus objetivos.
#          </span>
#         </div>
#         <span class="carbonad-tag">
#          recomendado por
#          <strong>
#           codigo-postal.co
#          </strong>
#         </span>
#        </div>
#        <div class="clearfix slide" data-slide="3" style="display:none;">
#         <div class="carbonad-image">
#          <a href="https://www.autoreseditores.com/cuanto-cuesta-publicar-un-libro.html?utm_source=codigopostal&amp;utm_medium=sponsored_ads&amp;utm_content=cuanto-cuesta-imprimir-un-libro&amp;utm_campaign=codigopostal04" rel="noopener" target="_blank">
#           <img alt="" border="0" height="100" src="/images/ads/ad-03.jpg" style="float:left;max-width:130px;" width="130"/>
#          </a>
#         </div>
#         <div class="carbonad-text">
#          <span>
#           <a href="https://www.autoreseditores.com/cuanto-cuesta-publicar-un-libro.html?utm_source=codigopostal&amp;utm_medium=sponsored_ads&amp;utm_content=cuanto-cuesta-imprimir-un-libro&amp;utm_campaign=codigopostal04" target="_blank" title="¿Cuánto cuesta editar un libro?">
#            ¿Cuánto cuesta imprimir un libro en Colombia?
#           </a>
#           ¡Ingresa a nuestra calculadora en línea y calcula el costo de impresión de cada ejemplar de acuerdo a la especificación de impresión!
#          </span>
#         </div>
#         <span class="carbonad-tag">
#          recomendado por
#          <strong>
#           codigo-postal.co
#          </strong>
#         </span>
#        </div>
#        <div class="clearfix slide" data-slide="4" style="display:none;">
#         <div class="carbonad-image">
#          <a href="https://normas-apa.org/formato/titulos-y-subtitulos/?utm_source=codigopostal&amp;utm_medium=sponsored_ads&amp;utm_content=normas-apa&amp;utm_campaign=codigopostal05" rel="noopener" target="_blank">
#           <img alt="" border="0" height="100" src="/images/ads/ad-97.jpg" style="float:left;max-width:130px;" width="130"/>
#          </a>
#         </div>
#         <div class="carbonad-text">
#          <span>
#           <a href="https://normas-apa.org/formato/titulos-y-subtitulos/?utm_source=codigopostal&amp;utm_medium=sponsored_ads&amp;utm_content=normas-apa&amp;utm_campaign=codigopostal05" target="_blank" title="Títulos y Subtítulos Normas APA">
#            Títulos y Subtítulos Normas APA
#           </a>
#           La mejor guía para ayudarte a formatar tu trabajo académico según las Normas APA 7
#           <sup>
#            ma
#           </sup>
#           (séptima edición).
#          </span>
#         </div>
#         <span class="carbonad-tag">
#          recomendado por
#          <strong>
#           codigo-postal.co
#          </strong>
#         </span>
#        </div>
#        <div class="controls-area clearfix">
#         <ul class="step-marker">
#          <li>
#           <a class="step-circle" data-target="0" href="javascript:void();" style="font-size:20px;">
#            •
#           </a>
#          </li>
#          <li>
#           <a class="step-circle" data-target="1" href="javascript:void();" style="font-size:20px;">
#            •
#           </a>
#          </li>
#          <li>
#           <a class="step-circle" data-target="2" href="javascript:void();" style="font-size:20px;">
#            •
#           </a>
#          </li>
#          <li>
#           <a class="step-circle" data-target="3" href="javascript:void();" style="font-size:20px;">
#            •
#           </a>
#          </li>
#         </ul>
#         <ul class="navigation-buttons">
#          <li>
#           <a class="step-chevron" data-target="left" href="javascript:void();" style="font-size:20px;">
#            «
#           </a>
#          </li>
#          <li>
#           <a class="step-chevron" data-target="right" href="javascript:void();" style="font-size:20px;">
#            »
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <!-- AdSense -->
#      <div style="margin-top:20px;">
#       <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#       </script>
#       <!-- Codigo Postal - Columna Derecha -->
#       <ins class="adsbygoogle" data-ad-client="ca-pub-3248513691157520" data-ad-format="auto" data-ad-slot="9577825202" style="display:block">
#       </ins>
#       <script>
#        (adsbygoogle = window.adsbygoogle || []).push({});
#       </script>
#      </div>
#      <!-- AdSense -->
#      <div style="margin-top:20px;">
#       <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#       </script>
#       <!-- Codigo Postal - Columna Derecha -->
#       <ins class="adsbygoogle" data-ad-client="ca-pub-3248513691157520" data-ad-format="auto" data-ad-slot="9577825202" style="display:block">
#       </ins>
#       <script>
#        (adsbygoogle = window.adsbygoogle || []).push({});
#       </script>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- Footer -->
#   <!-- Footer -->
#   <div class="container-fluid" id="footer_page" style="background:#f1f1f1;padding:20px 20px 40px 20px;margin-top:20px;font-size:12px;">
#    <div class="container">
#     <div class="row">
#      <div class="col-md-12">
#       <p style="text-align:center;">
#        <strong>
#         <a href="http://codigo-postal.co/" title="Buscar Código Postal">
#          Código Postal
#         </a>
#        </strong>
#        <br/>
#        © 2016-2021 - Todos los derechos reservados.
#       </p>
#       <div style="text-align:center;">
#        <a href="https://codigo-postal.co/colombia/" title="Versión en español">
#         <span class="lang_flag lang_es">
#         </span>
#        </a>
#        <a href="https://codigo-postal.co/en-us/colombia/" title="English version">
#         <span class="lang_flag lang_us">
#         </span>
#        </a>
#        <a href="https://codigo-postal.co/pt-br/colombia/" title="Versão em português">
#         <span class="lang_flag lang_pt">
#         </span>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    $(document).ready(function() {
#
# 				var currentSlide = 0;
# 				var refreshIntervalId = 0;
#
# 				function autoSlide (currentSlide) {
# 					refreshIntervalId = setInterval(function () {
# 						if (currentSlide == 3)
# 							nextSlide = 0;
# 						else
# 							nextSlide = currentSlide + 1;
#
# 						$('.carbonad .slide[data-slide="'+currentSlide+'"]').fadeOut(900, function() {
# 							$('.step-circle[data-target="'+currentSlide+'"]').removeClass('active');
# 							$('.step-circle[data-target="'+nextSlide+'"]').addClass('active');
# 							$('.carbonad div[data-slide="'+nextSlide+'"]').fadeIn(900);
# 							currentSlide = nextSlide;
# 						});
# 					}, 8000);
# 				}
#
# 				$('.step-circle').mouseenter(function() {
# 					clearInterval(refreshIntervalId);
# 					$('.step-circle').removeClass('active');
# 					$('.carbonad .slide').hide();
# 					var slide_target = $(this).data("target");
# 					$('.carbonad .slide[data-slide="'+slide_target+'"]').show();
# 					$('.step-circle[data-target="'+slide_target+'"]').addClass('active');
# 					currentSlide = slide_target;
# 				});
#
# 				$('.step-circle').mouseleave(function() {
# 					autoSlide(currentSlide);
# 				});
#
# 				$('.step-chevron').click(function() {
# 					//Clear time
# 					clearInterval(refreshIntervalId);
# 					$('.step-circle').removeClass('active');
# 					$('.carbonad .slide').hide();
# 					var direction = $(this).data("target");
# 					if (direction == 'left') {
# 						if (currentSlide == 0)
# 							slide_target = 3;
# 						else
# 							slide_target = currentSlide - 1;
# 					} else {
# 						if (currentSlide == 3)
# 							slide_target = 0;
# 						else
# 							slide_target = currentSlide + 1;
# 					}
#
# 					$('.carbonad .slide[data-slide="'+slide_target+'"]').show();
# 					$('.step-circle[data-target="'+slide_target+'"]').addClass('active');
# 					currentSlide = slide_target;
# 					autoSlide(currentSlide);
# 				});
#
# 				autoSlide(0);
# 			});
#   </script>
#  </body>
# </html>

# %%
# Identificar todas las etiquetas "li" dentro de contenido de la clase especificada

info_box = soup.find(class_="column-list")
info_rows = info_box.find_all("li")
for row in info_rows:
    print(row.prettify())
# Out:
# <li>
#  <a href="https://codigo-postal.co/colombia/amazonas/" title="Código Postal Amazonas">
#   <span class="co co-amazonas">
#   </span>
#   Amazonas
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/antioquia/" title="Código Postal Antioquia">
#   <span class="co co-antioquia">
#   </span>
#   Antioquia
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/arauca/" title="Código Postal Arauca">
#   <span class="co co-arauca">
#   </span>
#   Arauca
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/archipielago-de-san-andres/" title="Código Postal San Andres">
#   <span class="co co-archipielago-de-san-andres">
#   </span>
#   Archipielago de San Andres
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/atlantico/" title="Código Postal Atlántico">
#   <span class="co co-atlantico">
#   </span>
#   Atlantico
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/bogota-dc/" title="Código Postal Bogotá">
#   <span class="co co-bogota-dc">
#   </span>
#   Bogota DC
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/bolivar/" title="Código Postal Bolivar">
#   <span class="co co-bolivar">
#   </span>
#   Bolivar
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/boyaca/" title="Código Postal Boyacá">
#   <span class="co co-boyaca">
#   </span>
#   Boyaca
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/caldas/" title="Código Postal Caldas">
#   <span class="co co-caldas">
#   </span>
#   Caldas
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/caqueta/" title="Código Postal Caquetá">
#   <span class="co co-caqueta">
#   </span>
#   Caqueta
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/casanare/" title="Código Postal Casanare">
#   <span class="co co-casanare">
#   </span>
#   Casanare
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/cauca/" title="Código Postal Cauca">
#   <span class="co co-cauca">
#   </span>
#   Cauca
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/cesar/" title="Código Postal Cesar">
#   <span class="co co-cesar">
#   </span>
#   Cesar
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/choco/" title="Código Postal Chocó">
#   <span class="co co-choco">
#   </span>
#   Choco
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/cordoba/" title="Código Postal Cordoba">
#   <span class="co co-cordoba">
#   </span>
#   Cordoba
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/cundinamarca/" title="Código Postal Cundinamarca">
#   <span class="co co-cundinamarca">
#   </span>
#   Cundinamarca
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/guainia/" title="Código Postal Guainia">
#   <span class="co co-guainia">
#   </span>
#   Guainia
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/guaviare/" title="Código Postal Guaviare">
#   <span class="co co-guaviare">
#   </span>
#   Guaviare
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/huila/" title="Código Postal Huila">
#   <span class="co co-huila">
#   </span>
#   Huila
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/la-guajira/" title="Código Postal Guajira">
#   <span class="co co-la-guajira">
#   </span>
#   La Guajira
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/magdalena/" title="Código Postal Magdalena">
#   <span class="co co-magdalena">
#   </span>
#   Magdalena
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/meta/" title="Código Postal Meta">
#   <span class="co co-meta">
#   </span>
#   Meta
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/narino/" title="Código Postal Nariño">
#   <span class="co co-narino">
#   </span>
#   Nariño
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/norte-de-santander/" title="Código Postal Norte de Santander">
#   <span class="co co-norte-de-santander">
#   </span>
#   Norte de Santander
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/putumayo/" title="Código Postal Putumayo">
#   <span class="co co-putumayo">
#   </span>
#   Putumayo
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/quindio/" title="Código Postal Quindio">
#   <span class="co co-quindio">
#   </span>
#   Quindio
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/risaralda/" title="Código Postal Risaralda">
#   <span class="co co-risaralda">
#   </span>
#   Risaralda
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/santander/" title="Código Postal Santander">
#   <span class="co co-santander">
#   </span>
#   Santander
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/sucre/" title="Código Postal Sucre">
#   <span class="co co-sucre">
#   </span>
#   Sucre
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/tolima/" title="Código Postal Tolima">
#   <span class="co co-tolima">
#   </span>
#   Tolima
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/valle-del-cauca/" title="Código Postal Valle del Cauca">
#   <span class="co co-valle-del-cauca">
#   </span>
#   Valle del Cauca
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/vaupes/" title="Código Postal Vaupes">
#   <span class="co co-vaupes">
#   </span>
#   Vaupes
#  </a>
# </li>
#
# <li>
#  <a href="https://codigo-postal.co/colombia/vichada/" title="Código Postal Vichada">
#   <span class="co co-vichada">
#   </span>
#   Vichada
#  </a>
# </li>

# %%
# Extraer y guardar los enlaces de cada departamento

dptos = []

for row in info_rows:
    dptos.append(row.a['href'])

dptos
# Out:
# ['https://codigo-postal.co/colombia/amazonas/',
#  'https://codigo-postal.co/colombia/antioquia/',
#  'https://codigo-postal.co/colombia/arauca/',
#  'https://codigo-postal.co/colombia/archipielago-de-san-andres/',
#  'https://codigo-postal.co/colombia/atlantico/',
#  'https://codigo-postal.co/colombia/bogota-dc/',
#  'https://codigo-postal.co/colombia/bolivar/',
#  'https://codigo-postal.co/colombia/boyaca/',
#  'https://codigo-postal.co/colombia/caldas/',
#  'https://codigo-postal.co/colombia/caqueta/',
#  'https://codigo-postal.co/colombia/casanare/',
#  'https://codigo-postal.co/colombia/cauca/',
#  'https://codigo-postal.co/colombia/cesar/',
#  'https://codigo-postal.co/colombia/choco/',
#  'https://codigo-postal.co/colombia/cordoba/',
#  'https://codigo-postal.co/colombia/cundinamarca/',
#  'https://codigo-postal.co/colombia/guainia/',
#  'https://codigo-postal.co/colombia/guaviare/',
#  'https://codigo-postal.co/colombia/huila/',
#  'https://codigo-postal.co/colombia/la-guajira/',
#  'https://codigo-postal.co/colombia/magdalena/',
#  'https://codigo-postal.co/colombia/meta/',
#  'https://codigo-postal.co/colombia/narino/',
#  'https://codigo-postal.co/colombia/norte-de-santander/',
#  'https://codigo-postal.co/colombia/putumayo/',
#  'https://codigo-postal.co/colombia/quindio/',
#  'https://codigo-postal.co/colombia/risaralda/',
#  'https://codigo-postal.co/colombia/santander/',
#  'https://codigo-postal.co/colombia/sucre/',
#  'https://codigo-postal.co/colombia/tolima/',
#  'https://codigo-postal.co/colombia/valle-del-cauca/',
#  'https://codigo-postal.co/colombia/vaupes/',
#  'https://codigo-postal.co/colombia/vichada/']

# %%
# Se define la función "get_urls" la cual accede al enlace del departamento, extrae y guarda los enlaces de todos sus municipios

def get_urls(dpto, mpios):
    url = requests.get(dpto)
    soup = bs(url.content)

    info_box = soup.find(class_="col-md-8")
    info_rows = info_box.find_all("ul")

    info_lists = []
    for row in info_rows:
        info_lists.append(row.find_all("li"))
    
    for info_list in info_lists:
        for renglon in info_list:
            mpios.append(renglon.a['href'])


    return mpios

# Extraer los enlaces de todos los municipios de cada departamento. Guardar en una misma lista todos los enlaces.
mpios = []
for dpto in dptos:
    get_urls(dpto, mpios)

# %%
# En este caso, se procede a crear una nueva columna que contenga los nombres de cada municipio pero sin tildes (´) en caso...
# ... de que existan. Esto para facilitar el proceso de asignación del código postal para su correspondiente. Mas adelante...

import re
from unicodedata import normalize

municipios_df['New_municipios'] = ""

series = municipios_df['Municipio']
for index, value in series.items():
    municipios_df['New_municipios'][index] = normalize('NFC', re.sub(
        r"([^n\u0300-\u036f]|n(?!\u0303(?![\u0300-\u036f])))[\u0300-\u036f]+", r"\1", 
        normalize( "NFD", value), 0, re.I))

# %%
# Se asigna la nueva columna como indice del DataFrame
municipios_df = municipios_df.set_index('New_municipios')

# %%
municipios_df.head()
# Out:
#                                                                Fundación  \
# New_municipios
# Bogota                 6 de agosto de 1538 (483 años)   ( Gonzalo Jim...
# Medellin               2 de marzo  de  1616  (405 años)  ( Miguel de ...
# Cali Santiago de Cali  25 de julio  de  1536  (485 años)  (por  Sebas...
# Barranquilla                                           Entre 1627 y 1637
# Cartagena de Indias    1 de junio  de  1533  (488 años)  ( Pedro de H...
#
#                                                 Erección  Superficie  \
# New_municipios
# Bogota                 3 de diciembre de 1548 (472 años)   1775  km²
# Medellin                          21 de agosto  de  1813    382  km²
# Cali Santiago de Cali              17 de junio  de  1559    564  km²
# Barranquilla                          7 de abril de 1813    154  km²
# Cartagena de Indias                                 1533  609.1  km²
#
#                           Altitud Media  \
# New_municipios
# Bogota                 2640  m s. n. m.
# Medellin               1495  m s. n. m.
# Cali Santiago de Cali  1018  m s. n. m.
# Barranquilla             18  m s. n. m.
# Cartagena de Indias       2  m s. n. m.
#
#                                                                    Clima  \
# New_municipios
# Bogota                                        Oceánico mediterráneo  Csb
# Medellin               Tropical monzónico  Am   Subtropical húmedo  C...
# Cali Santiago de Cali                                  Tropical seco  As
# Barranquilla                                            Tropical seco Aw
# Cartagena de Indias                                Semiárido cálido  BSh
#
#                       Población Total         Densidad    Pobl. Urbana  \
# New_municipios
# Bogota                 7 743 955 hab.  4907,45 hab/km²  7 412 566 hab.
# Medellin               2 533 424 hab.  6643,39 hab/km²  2 501 470 hab.
# Cali Santiago de Cali  2 445 281 hab.  4382,05 hab/km²  2 408 653 hab.
# Barranquilla           2 274 250 hab.  8274,35 hab/km²  2 273 646 hab.
# Cartagena de Indias    1 028 736 hab.  1811,91 hab/km²    914 552 hab.
#
#                                Gentilicio Huso horario Código postal  \
# New_municipios
# Bogota                      Bogotano, -na        UTC-5            11
# Medellin                     Medellinense      UTC  -5        050001
# Cali Santiago de Cali         Caleño, -ña      UTC  -5           NaN
# Barranquilla           Barranquillero, ra        UTC-5         08000
# Cartagena de Indias       Cartagenero, -a        UTC-5        130000
#
#                                                              Coordenadas  \
# New_municipios
# Bogota                                              4°36′46″N 74°04′14″O
# Medellin               6°14′41″N  75°34′29″O ﻿ / ﻿ 6.2447472222222,  ...
# Cali Santiago de Cali                                                NaN
# Barranquilla           10°57′50″N  74°47′47″O ﻿ / ﻿ 10.963888888889, ...
# Cartagena de Indias                                                  NaN
#
#                                    Entidad      País  Departamento  \
# New_municipios
# Bogota                 Capital de Colombia  Colombia  Cundinamarca
# Medellin                         Municipio  Colombia     Antioquia
# Cali Santiago de Cali                  NaN       NaN           NaN
# Barranquilla                      Distrito  Colombia     Atlántico
# Cartagena de Indias                    NaN  Colombia       Bolívar
#
#                                                                  Alcalde  \
# New_municipios
# Bogota                                    Claudia López (AV) (2020-2023)
# Medellin               Daniel Quintero Calle  ( Independientes )   20...
# Cali Santiago de Cali                                                NaN
# Barranquilla           Jaime Pumarejo Heins  ( PCR )     ( 2020 - 2023 )
# Cartagena de Indias                 William Dau Chamat   ( 2020 - 2023 )
#
#                                    Municipio
# New_municipios
# Bogota                                Bogotá
# Medellin                            Medellín
# Cali Santiago de Cali  Cali Santiago de Cali
# Barranquilla                    Barranquilla
# Cartagena de Indias      Cartagena de Indias

# %%
# La función "get_codes" accede al enlace del municipio, extrae y guarda el nombre del municipio y su código postal.

def get_codes(mpio, postales):
    try:
        url = requests.get(mpio)
        soup = bs(url.content)

        info_box_head = soup.find(class_="breadcrumb")
        info_rows_head = info_box_head.find_all("li")
    
        llave = info_rows_head[3].find("span").get_text(" ", strip=True)
    
        info_box_body = soup.find(class_="table-responsive")
        info_rows_body = info_box_body.find_all("tr")
    
        valor = info_rows_body[1].find("a").get_text(" ", strip=True)
    
        postales[llave] = valor

        return postales
    
    except AttributeError as e:
        print(f"¡{llave} no tiene código postal asignado!")
        pass

# Extraer el código postal para todos los municipio. Guardar la información en un diccionario.
postales = {}
for mpio in mpios:
    get_codes(mpio, postales)
# Out:
# ¡La Victoria no tiene código ZIP asignado!
# ¡Antonio Nariño no tiene código ZIP asignado!
# ¡Candelaria no tiene código ZIP asignado!
# ¡Los Martires no tiene código ZIP asignado!
# ¡Guadalupe no tiene código ZIP asignado!

# %%
# La razón por la que se creó una nueva columna con los nombres de cada municipio sin tilde es porque es necesario asignarlos...
# ... usando el nombre de la llave, cuyos nombres no poseen tildes en los casos en los que debería tenerla. Por lo tanto, ...
# ... se utilizan los nuevos indices para 

municipios_df = municipios_df.drop("Código postal", 1)

municipios_df['Código Postal'] = 0
for key, value in postales.items():
    for index, val in municipios_df['Clima'].items():
        if search(key, index):
            municipios_df['Código Postal'][index] = value
# Out:
# <ipython-input-206-123bebd76470>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   municipios_df['Código Postal'][index] = value

# %%
# Se elimina la columna indice que fue tomada solo como referencia
municipios_df.reset_index(drop=True, inplace=True)

# %%
municipios_df.head()
# Out:
#                                                                Fundación  \
# Municipio
# Bogotá                 6 de agosto de 1538 (483 años)   ( Gonzalo Jim...
# Medellín               2 de marzo  de  1616  (405 años)  ( Miguel de ...
# Cali Santiago de Cali  25 de julio  de  1536  (485 años)  (por  Sebas...
# Barranquilla                                           Entre 1627 y 1637
# Cartagena de Indias    1 de junio  de  1533  (488 años)  ( Pedro de H...
#
#                                                 Erección  Superficie  \
# Municipio
# Bogotá                 3 de diciembre de 1548 (472 años)   1775  km²
# Medellín                          21 de agosto  de  1813    382  km²
# Cali Santiago de Cali              17 de junio  de  1559    564  km²
# Barranquilla                          7 de abril de 1813    154  km²
# Cartagena de Indias                                 1533  609.1  km²
#
#                           Altitud Media  \
# Municipio
# Bogotá                 2640  m s. n. m.
# Medellín               1495  m s. n. m.
# Cali Santiago de Cali  1018  m s. n. m.
# Barranquilla             18  m s. n. m.
# Cartagena de Indias       2  m s. n. m.
#
#                                                                    Clima  \
# Municipio
# Bogotá                                        Oceánico mediterráneo  Csb
# Medellín               Tropical monzónico  Am   Subtropical húmedo  C...
# Cali Santiago de Cali                                  Tropical seco  As
# Barranquilla                                            Tropical seco Aw
# Cartagena de Indias                                Semiárido cálido  BSh
#
#                       Población Total         Densidad    Pobl. Urbana  \
# Municipio
# Bogotá                 7 743 955 hab.  4907,45 hab/km²  7 412 566 hab.
# Medellín               2 533 424 hab.  6643,39 hab/km²  2 501 470 hab.
# Cali Santiago de Cali  2 445 281 hab.  4382,05 hab/km²  2 408 653 hab.
# Barranquilla           2 274 250 hab.  8274,35 hab/km²  2 273 646 hab.
# Cartagena de Indias    1 028 736 hab.  1811,91 hab/km²    914 552 hab.
#
#                                Gentilicio Huso horario  \
# Municipio
# Bogotá                      Bogotano, -na        UTC-5
# Medellín                     Medellinense      UTC  -5
# Cali Santiago de Cali         Caleño, -ña      UTC  -5
# Barranquilla           Barranquillero, ra        UTC-5
# Cartagena de Indias       Cartagenero, -a        UTC-5
#
#                                                              Coordenadas  \
# Municipio
# Bogotá                                              4°36′46″N 74°04′14″O
# Medellín               6°14′41″N  75°34′29″O ﻿ / ﻿ 6.2447472222222,  ...
# Cali Santiago de Cali                               3°26′24″N 76°31′11″O
# Barranquilla           10°57′50″N  74°47′47″O ﻿ / ﻿ 10.963888888889, ...
# Cartagena de Indias                                10°25′25″N 75°31′31″O
#
#                                    Entidad      País     Departamento  \
# Municipio
# Bogotá                 Capital de Colombia  Colombia     Cundinamarca
# Medellín                          Distrito  Colombia        Antioquia
# Cali Santiago de Cali             Distrito       NaN  Valle del Cauca
# Barranquilla                      Distrito  Colombia        Atlántico
# Cartagena de Indias               Distrito  Colombia          Bolívar
#
#                                                                  Alcalde  \
# Municipio
# Bogotá                                    Claudia López (AV) (2020-2023)
# Medellín               Daniel Quintero Calle  ( Independientes )   20...
# Cali Santiago de Cali                                  Jorge Iván Ospina
# Barranquilla           Jaime Pumarejo Heins  ( PCR )     ( 2020 - 2023 )
# Cartagena de Indias                 William Dau Chamat   ( 2020 - 2023 )
#
#                        Código Postal
# Municipio
# Bogotá                             0
# Medellín                       50035
# Cali Santiago de Cali         760036
# Barranquilla                   80001
# Cartagena de Indias           130010

# %% [markdown]
# ##### ** Convertir fechas en string a datetime **

# %%
# Extraer la fecha de cada string de la columna "Fundación" ("5 de junio de 1935" --> "5/junio/1935")

for idx in municipios_df.index:
    try:
        if len(municipios_df['Fundación'][idx].split()) > 4:
            municipios_df['Fundación'][idx] = ' '.join(municipios_df['Fundación'][idx].split()[:5]).replace(' de', '').replace(' ', '/')
        continue
    except Exception as e:
        print(f"{idx}: {e}")
# Out:
# <ipython-input-370-14e015da813a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   municipios_df['Fundación'][idx] = ' '.join(municipios_df['Fundación'][idx].split()[:5]).replace(' de', '').replace(' ', '/')
# 80: 'float' object has no attribute 'split'
# 84: 'float' object has no attribute 'split'
# 89: 'float' object has no attribute 'split'
# 142: 'float' object has no attribute 'split'
# 150: 'float' object has no attribute 'split'
# 276: 'float' object has no attribute 'split'
# 293: 'float' object has no attribute 'split'
# 312: 'float' object has no attribute 'split'
# 325: 'float' object has no attribute 'split'
# 394: 'float' object has no attribute 'split'
# 403: 'float' object has no attribute 'split'
# 414: 'float' object has no attribute 'split'
# 418: 'float' object has no attribute 'split'
# 477: 'float' object has no attribute 'split'
# 488: 'float' object has no attribute 'split'
# 522: 'float' object has no attribute 'split'
# 524: 'float' object has no attribute 'split'
# 599: 'float' object has no attribute 'split'
# 635: 'float' object has no attribute 'split'
# 655: 'float' object has no attribute 'split'
# 666: 'float' object has no attribute 'split'
# 679: 'float' object has no attribute 'split'
# 735: 'float' object has no attribute 'split'
# 736: 'float' object has no attribute 'split'
# 825: 'float' object has no attribute 'split'
# 852: 'float' object has no attribute 'split'
# 893: 'float' object has no attribute 'split'
# 901: 'float' object has no attribute 'split'
# 947: 'float' object has no attribute 'split'
# 960: 'float' object has no attribute 'split'
# 963: 'float' object has no attribute 'split'
# 979: 'float' object has no attribute 'split'
# 1003: 'float' object has no attribute 'split'
# 1018: 'float' object has no attribute 'split'
# 1020: 'float' object has no attribute 'split'
# 1021: 'float' object has no attribute 'split'
# 1030: 'float' object has no attribute 'split'
# 1050: 'float' object has no attribute 'split'
# 1073: 'float' object has no attribute 'split'
# 1079: 'float' object has no attribute 'split'
# 1081: 'float' object has no attribute 'split'
# 1082: 'float' object has no attribute 'split'
# 1084: 'float' object has no attribute 'split'
# 1089: 'float' object has no attribute 'split'
# 1093: 'float' object has no attribute 'split'
# 1096: 'float' object has no attribute 'split'
# 1109: 'float' object has no attribute 'split'
# 1110: 'float' object has no attribute 'split'
# 1112: 'float' object has no attribute 'split'
# 1113: 'float' object has no attribute 'split'
# 1114: 'float' object has no attribute 'split'
# 1116: 'float' object has no attribute 'split'
# 1117: 'float' object has no attribute 'split'

# %%
# Extraer la fecha de cada string de la columna "Erección" ("5 de junio de 1935" --> "5/junio/1935")

for idx in municipios_df.index:
    try:
        if len(municipios_df['Erección'][idx].split()) > 4:
            municipios_df['Erección'][idx] = ' '.join(municipios_df['Erección'][idx].split()[:5]).replace(' de', '').replace(' ', '/')
        continue
    except Exception as e:
        print(f"{idx}: {e}")
# Out:
# <ipython-input-371-8a957b6dc445>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   municipios_df['Erección'][idx] = ' '.join(municipios_df['Erección'][idx].split()[:5]).replace(' de', '').replace(' ', '/')
# 13: 'float' object has no attribute 'split'
# 16: 'float' object has no attribute 'split'
# 18: 'float' object has no attribute 'split'
# 21: 'float' object has no attribute 'split'
# 31: 'float' object has no attribute 'split'
# 35: 'float' object has no attribute 'split'
# 39: 'float' object has no attribute 'split'
# 40: 'float' object has no attribute 'split'
# 41: 'float' object has no attribute 'split'
# 42: 'float' object has no attribute 'split'
# 43: 'float' object has no attribute 'split'
# 45: 'float' object has no attribute 'split'
# 56: 'float' object has no attribute 'split'
# 61: 'float' object has no attribute 'split'
# 62: 'float' object has no attribute 'split'
# 65: 'float' object has no attribute 'split'
# 77: 'float' object has no attribute 'split'
# 78: 'float' object has no attribute 'split'
# 80: 'float' object has no attribute 'split'
# 83: 'float' object has no attribute 'split'
# 86: 'float' object has no attribute 'split'
# 93: 'float' object has no attribute 'split'
# 105: 'float' object has no attribute 'split'
# 108: 'float' object has no attribute 'split'
# 110: 'float' object has no attribute 'split'
# 112: 'float' object has no attribute 'split'
# 116: 'float' object has no attribute 'split'
# 119: 'float' object has no attribute 'split'
# 140: 'float' object has no attribute 'split'
# 144: 'float' object has no attribute 'split'
# 147: 'float' object has no attribute 'split'
# 154: 'float' object has no attribute 'split'
# 163: 'float' object has no attribute 'split'
# 172: 'float' object has no attribute 'split'
# 180: 'float' object has no attribute 'split'
# 194: 'float' object has no attribute 'split'
# 202: 'float' object has no attribute 'split'
# 203: 'float' object has no attribute 'split'
# 217: 'float' object has no attribute 'split'
# 218: 'float' object has no attribute 'split'
# 233: 'float' object has no attribute 'split'
# 234: 'float' object has no attribute 'split'
# 236: 'float' object has no attribute 'split'
# 249: 'float' object has no attribute 'split'
# 257: 'float' object has no attribute 'split'
# 260: 'float' object has no attribute 'split'
# 269: 'float' object has no attribute 'split'
# 278: 'float' object has no attribute 'split'
# 290: 'float' object has no attribute 'split'
# 310: 'float' object has no attribute 'split'
# 311: 'float' object has no attribute 'split'
# 323: 'float' object has no attribute 'split'
# 326: 'float' object has no attribute 'split'
# 330: 'float' object has no attribute 'split'
# 334: 'float' object has no attribute 'split'
# 335: 'float' object has no attribute 'split'
# 339: 'float' object has no attribute 'split'
# 345: 'float' object has no attribute 'split'
# 346: 'float' object has no attribute 'split'
# 347: 'float' object has no attribute 'split'
# 352: 'float' object has no attribute 'split'
# 360: 'float' object has no attribute 'split'
# 363: 'float' object has no attribute 'split'
# 365: 'float' object has no attribute 'split'
# 375: 'float' object has no attribute 'split'
# 379: 'float' object has no attribute 'split'
# 380: 'float' object has no attribute 'split'
# 397: 'float' object has no attribute 'split'
# 406: 'float' object has no attribute 'split'
# 408: 'float' object has no attribute 'split'
# 410: 'float' object has no attribute 'split'
# 411: 'float' object has no attribute 'split'
# 418: 'float' object has no attribute 'split'
# 428: 'float' object has no attribute 'split'
# 433: 'float' object has no attribute 'split'
# 437: 'float' object has no attribute 'split'
# 441: 'float' object has no attribute 'split'
# 444: 'float' object has no attribute 'split'
# 445: 'float' object has no attribute 'split'
# 451: 'float' object has no attribute 'split'
# 452: 'float' object has no attribute 'split'
# 453: 'float' object has no attribute 'split'
# 458: 'float' object has no attribute 'split'
# 462: 'float' object has no attribute 'split'
# 466: 'float' object has no attribute 'split'
# 476: 'float' object has no attribute 'split'
# 478: 'float' object has no attribute 'split'
# 479: 'float' object has no attribute 'split'
# 492: 'float' object has no attribute 'split'
# 504: 'float' object has no attribute 'split'
# 505: 'float' object has no attribute 'split'
# 506: 'float' object has no attribute 'split'
# 507: 'float' object has no attribute 'split'
# 511: 'float' object has no attribute 'split'
# 514: 'float' object has no attribute 'split'
# 526: 'float' object has no attribute 'split'
# 530: 'float' object has no attribute 'split'
# 532: 'float' object has no attribute 'split'
# 538: 'float' object has no attribute 'split'
# 545: 'float' object has no attribute 'split'
# 547: 'float' object has no attribute 'split'
# 548: 'float' object has no attribute 'split'
# 551: 'float' object has no attribute 'split'
# 569: 'float' object has no attribute 'split'
# 571: 'float' object has no attribute 'split'
# 589: 'float' object has no attribute 'split'
# 595: 'float' object has no attribute 'split'
# 599: 'float' object has no attribute 'split'
# 600: 'float' object has no attribute 'split'
# 601: 'float' object has no attribute 'split'
# 602: 'float' object has no attribute 'split'
# 608: 'float' object has no attribute 'split'
# 612: 'float' object has no attribute 'split'
# 613: 'float' object has no attribute 'split'
# 617: 'float' object has no attribute 'split'
# 618: 'float' object has no attribute 'split'
# 619: 'float' object has no attribute 'split'
# 624: 'float' object has no attribute 'split'
# 631: 'float' object has no attribute 'split'
# 636: 'float' object has no attribute 'split'
# 637: 'float' object has no attribute 'split'
# 657: 'float' object has no attribute 'split'
# 660: 'float' object has no attribute 'split'
# 662: 'float' object has no attribute 'split'
# 668: 'float' object has no attribute 'split'
# 669: 'float' object has no attribute 'split'
# 671: 'float' object has no attribute 'split'
# 672: 'float' object has no attribute 'split'
# 674: 'float' object has no attribute 'split'
# 676: 'float' object has no attribute 'split'
# 693: 'float' object has no attribute 'split'
# 696: 'float' object has no attribute 'split'
# 712: 'float' object has no attribute 'split'
# 713: 'float' object has no attribute 'split'
# 714: 'float' object has no attribute 'split'
# 722: 'float' object has no attribute 'split'
# 734: 'float' object has no attribute 'split'
# 735: 'float' object has no attribute 'split'
# 736: 'float' object has no attribute 'split'
# 739: 'float' object has no attribute 'split'
# 742: 'float' object has no attribute 'split'
# 747: 'float' object has no attribute 'split'
# 748: 'float' object has no attribute 'split'
# 749: 'float' object has no attribute 'split'
# 758: 'float' object has no attribute 'split'
# 760: 'float' object has no attribute 'split'
# 767: 'float' object has no attribute 'split'
# 769: 'float' object has no attribute 'split'
# 771: 'float' object has no attribute 'split'
# 776: 'float' object has no attribute 'split'
# 777: 'float' object has no attribute 'split'
# 778: 'float' object has no attribute 'split'
# 783: 'float' object has no attribute 'split'
# 785: 'float' object has no attribute 'split'
# 786: 'float' object has no attribute 'split'
# 787: 'float' object has no attribute 'split'
# 800: 'float' object has no attribute 'split'
# 808: 'float' object has no attribute 'split'
# 810: 'float' object has no attribute 'split'
# 812: 'float' object has no attribute 'split'
# 814: 'float' object has no attribute 'split'
# 817: 'float' object has no attribute 'split'
# 818: 'float' object has no attribute 'split'
# 819: 'float' object has no attribute 'split'
# 820: 'float' object has no attribute 'split'
# 834: 'float' object has no attribute 'split'
# 836: 'float' object has no attribute 'split'
# 845: 'float' object has no attribute 'split'
# 849: 'float' object has no attribute 'split'
# 850: 'float' object has no attribute 'split'
# 855: 'float' object has no attribute 'split'
# 863: 'float' object has no attribute 'split'
# 866: 'float' object has no attribute 'split'
# 867: 'float' object has no attribute 'split'
# 870: 'float' object has no attribute 'split'
# 876: 'float' object has no attribute 'split'
# 882: 'float' object has no attribute 'split'
# 885: 'float' object has no attribute 'split'
# 889: 'float' object has no attribute 'split'
# 891: 'float' object has no attribute 'split'
# 898: 'float' object has no attribute 'split'
# 901: 'float' object has no attribute 'split'
# 915: 'float' object has no attribute 'split'
# 917: 'float' object has no attribute 'split'
# 918: 'float' object has no attribute 'split'
# 920: 'float' object has no attribute 'split'
# 921: 'float' object has no attribute 'split'
# 923: 'float' object has no attribute 'split'
# 924: 'float' object has no attribute 'split'
# 926: 'float' object has no attribute 'split'
# 932: 'float' object has no attribute 'split'
# 936: 'float' object has no attribute 'split'
# 948: 'float' object has no attribute 'split'
# 950: 'float' object has no attribute 'split'
# 954: 'float' object has no attribute 'split'
# 956: 'float' object has no attribute 'split'
# 960: 'float' object has no attribute 'split'
# 965: 'float' object has no attribute 'split'
# 968: 'float' object has no attribute 'split'
# 969: 'float' object has no attribute 'split'
# 980: 'float' object has no attribute 'split'
# 984: 'float' object has no attribute 'split'
# 990: 'float' object has no attribute 'split'
# 997: 'float' object has no attribute 'split'
# 1003: 'float' object has no attribute 'split'
# 1006: 'float' object has no attribute 'split'
# 1010: 'float' object has no attribute 'split'
# 1011: 'float' object has no attribute 'split'
# 1012: 'float' object has no attribute 'split'
# 1017: 'float' object has no attribute 'split'
# 1021: 'float' object has no attribute 'split'
# 1023: 'float' object has no attribute 'split'
# 1024: 'float' object has no attribute 'split'
# 1026: 'float' object has no attribute 'split'
# 1032: 'float' object has no attribute 'split'
# 1033: 'float' object has no attribute 'split'
# 1037: 'float' object has no attribute 'split'
# 1040: 'float' object has no attribute 'split'
# 1042: 'float' object has no attribute 'split'
# 1045: 'float' object has no attribute 'split'
# 1048: 'float' object has no attribute 'split'
# 1049: 'float' object has no attribute 'split'
# 1052: 'float' object has no attribute 'split'
# 1054: 'float' object has no attribute 'split'
# 1057: 'float' object has no attribute 'split'
# 1065: 'float' object has no attribute 'split'
# 1068: 'float' object has no attribute 'split'
# 1070: 'float' object has no attribute 'split'
# 1082: 'float' object has no attribute 'split'
# 1084: 'float' object has no attribute 'split'
# 1085: 'float' object has no attribute 'split'
# 1091: 'float' object has no attribute 'split'
# 1093: 'float' object has no attribute 'split'
# 1096: 'float' object has no attribute 'split'
# 1108: 'float' object has no attribute 'split'
# 1109: 'float' object has no attribute 'split'
# 1110: 'float' object has no attribute 'split'
# 1112: 'float' object has no attribute 'split'
# 1113: 'float' object has no attribute 'split'
# 1114: 'float' object has no attribute 'split'
# 1115: 'float' object has no attribute 'split'
# 1116: 'float' object has no attribute 'split'
# 1117: 'float' object has no attribute 'split'

# %%
# Convertir las fechas de las columnas "Fundación" y "Erección" de formato string a datetime

from datetime import datetime
import locale # Usar locale para configurar la lectura de las fechas en idioma español.

locale.setlocale(locale.LC_TIME, 'es_ES.UTF-8')

columnas = ['Fundación', 'Erección']

for col in columnas:
    for idx in municipios_df.index:
        try:
            municipios_df[col][idx] = datetime.strptime(municipios_df[col][idx], '%d/%B/%Y')
        except Exception as e:
            print(f"{idx}: {e}")
# Out:
# <ipython-input-372-f8caf235b868>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   municipios_df[col][idx] = datetime.strptime(municipios_df[col][idx], '%d/%B/%Y')
# 3: time data 'Entre 1627 y 1637' does not match format '%d/%B/%Y'
# 6: time data '1600' does not match format '%d/%B/%Y'
# 9: time data '1676  (345 años)' does not match format '%d/%B/%Y'
# 19: time data '1680/(341/años)/(primeros/asentamientos)' does not match format '%d/%B/%Y'
# 25: time data '1743  (278 años)' does not match format '%d/%B/%Y'
# 28: time data '1844' does not match format '%d/%B/%Y'
# 49: time data 'Anterior a la Conquista' does not match format '%d/%B/%Y'
# 55: time data '1907' does not match format '%d/%B/%Y'
# 58: time data '1521' does not match format '%d/%B/%Y'
# 60: time data 'Los/indígenas/Pastos,/en/época' does not match format '%d/%B/%Y'
# 66: time data '1536' does not match format '%d/%B/%Y'
# 67: time data '1840' does not match format '%d/%B/%Y'
# 71: time data '1815' does not match format '%d/%B/%Y'
# 76: time data '1723' does not match format '%d/%B/%Y'
# 80: strptime() argument 1 must be str, not float
# 81: time data '1840  \n \n180 Años' does not match format '%d/%B/%Y'
# 84: strptime() argument 1 must be str, not float
# 85: time data '1685' does not match format '%d/%B/%Y'
# 88: time data '1886   (por Antonio Acosta)' does not match format '%d/%B/%Y'
# 89: strptime() argument 1 must be str, not float
# 98: time data '1690' does not match format '%d/%B/%Y'
# 102: time data '1600' does not match format '%d/%B/%Y'
# 104: time data '1702/(por/Félix/Arias/)' does not match format '%d/%B/%Y'
# 106: time data '1976' does not match format '%d/%B/%Y'
# 109: time data '1706   (Juan Zabaleta)' does not match format '%d/%B/%Y'
# 120: time data '1675' does not match format '%d/%B/%Y'
# 122: time data '1518' does not match format '%d/%B/%Y'
# 124: time data '1620' does not match format '%d/%B/%Y'
# 136: time data '1771' does not match format '%d/%B/%Y'
# 142: strptime() argument 1 must be str, not float
# 150: strptime() argument 1 must be str, not float
# 157: time data '1509' does not match format '%d/%B/%Y'
# 164: time data '1525' does not match format '%d/%B/%Y'
# 176: time data '1963' does not match format '%d/%B/%Y'
# 180: time data '1750' does not match format '%d/%B/%Y'
# 184: time data '1872' does not match format '%d/%B/%Y'
# 189: time data '1529' does not match format '%d/%B/%Y'
# 196: time data '1868' does not match format '%d/%B/%Y'
# 202: time data 'Se/conmemora/el/23' does not match format '%d/%B/%Y'
# 212: time data '1920' does not match format '%d/%B/%Y'
# 216: time data '1872' does not match format '%d/%B/%Y'
# 220: time data 'n/d' does not match format '%d/%B/%Y'
# 232: time data '1956' does not match format '%d/%B/%Y'
# 238: time data '1847' does not match format '%d/%B/%Y'
# 242: time data '1850' does not match format '%d/%B/%Y'
# 245: time data '1806' does not match format '%d/%B/%Y'
# 252: time data '1576' does not match format '%d/%B/%Y'
# 253: time data '1533' does not match format '%d/%B/%Y'
# 273: time data '1875' does not match format '%d/%B/%Y'
# 276: strptime() argument 1 must be str, not float
# 277: time data '1650' does not match format '%d/%B/%Y'
# 278: time data 'Noviembre de  1954' does not match format '%d/%B/%Y'
# 280: time data 'Noviembre de  1888' does not match format '%d/%B/%Y'
# 282: time data '1844' does not match format '%d/%B/%Y'
# 289: time data '1838' does not match format '%d/%B/%Y'
# 293: strptime() argument 1 must be str, not float
# 294: time data '1772' does not match format '%d/%B/%Y'
# 295: time data '1912' does not match format '%d/%B/%Y'
# 298: time data '1882' does not match format '%d/%B/%Y'
# 302: time data '1920' does not match format '%d/%B/%Y'
# 307: time data '1871' does not match format '%d/%B/%Y'
# 312: strptime() argument 1 must be str, not float
# 313: time data '1887' does not match format '%d/%B/%Y'
# 315: time data '1817' does not match format '%d/%B/%Y'
# 317: time data '1790  (228 años)' does not match format '%d/%B/%Y'
# 321: time data '1842' does not match format '%d/%B/%Y'
# 325: strptime() argument 1 must be str, not float
# 327: time data '1854' does not match format '%d/%B/%Y'
# 333: time data '1933' does not match format '%d/%B/%Y'
# 336: time data '1850' does not match format '%d/%B/%Y'
# 337: time data '1560' does not match format '%d/%B/%Y'
# 343: time data '1782' does not match format '%d/%B/%Y'
# 349: time data '1556' does not match format '%d/%B/%Y'
# 353: time data '1748' does not match format '%d/%B/%Y'
# 354: time data '1900' does not match format '%d/%B/%Y'
# 355: time data '1836' does not match format '%d/%B/%Y'
# 361: time data '1778' does not match format '%d/%B/%Y'
# 367: time data '1943' does not match format '%d/%B/%Y'
# 368: time data '1938' does not match format '%d/%B/%Y'
# 372: time data '1880' does not match format '%d/%B/%Y'
# 375: time data '1680' does not match format '%d/%B/%Y'
# 376: time data '1912' does not match format '%d/%B/%Y'
# 377: time data '1936' does not match format '%d/%B/%Y'
# 378: time data '1885' does not match format '%d/%B/%Y'
# 392: time data '1870' does not match format '%d/%B/%Y'
# 394: strptime() argument 1 must be str, not float
# 396: time data '1787' does not match format '%d/%B/%Y'
# 399: time data '1900' does not match format '%d/%B/%Y'
# 401: time data '1560' does not match format '%d/%B/%Y'
# 402: time data '1913' does not match format '%d/%B/%Y'
# 403: strptime() argument 1 must be str, not float
# 409: time data '1684' does not match format '%d/%B/%Y'
# 414: strptime() argument 1 must be str, not float
# 416: time data '1882' does not match format '%d/%B/%Y'
# 418: strptime() argument 1 must be str, not float
# 419: time data 'Antes de  1533' does not match format '%d/%B/%Y'
# 432: time data '1810' does not match format '%d/%B/%Y'
# 433: time data '1556' does not match format '%d/%B/%Y'
# 442: time data '1704' does not match format '%d/%B/%Y'
# 443: time data '1864' does not match format '%d/%B/%Y'
# 446: time data '1779' does not match format '%d/%B/%Y'
# 447: time data '1877' does not match format '%d/%B/%Y'
# 456: time data '1681' does not match format '%d/%B/%Y'
# 465: time data '1900' does not match format '%d/%B/%Y'
# 477: strptime() argument 1 must be str, not float
# 482: time data '1905' does not match format '%d/%B/%Y'
# 485: time data '1533' does not match format '%d/%B/%Y'
# 488: strptime() argument 1 must be str, not float
# 490: time data '1864' does not match format '%d/%B/%Y'
# 494: time data '1632' does not match format '%d/%B/%Y'
# 497: time data '1708' does not match format '%d/%B/%Y'
# 498: time data '1952' does not match format '%d/%B/%Y'
# 509: time data '1864' does not match format '%d/%B/%Y'
# 514: time data '1538' does not match format '%d/%B/%Y'
# 515: time data 'Precolombina' does not match format '%d/%B/%Y'
# 516: time data '1882' does not match format '%d/%B/%Y'
# 517: time data '1920' does not match format '%d/%B/%Y'
# 520: time data '1850' does not match format '%d/%B/%Y'
# 522: strptime() argument 1 must be str, not float
# 523: time data '1791' does not match format '%d/%B/%Y'
# 524: strptime() argument 1 must be str, not float
# 525: time data '1845' does not match format '%d/%B/%Y'
# 528: time data '1684' does not match format '%d/%B/%Y'
# 529: time data '1887' does not match format '%d/%B/%Y'
# 534: time data '1932' does not match format '%d/%B/%Y'
# 538: time data '1849' does not match format '%d/%B/%Y'
# 540: time data '1620' does not match format '%d/%B/%Y'
# 541: time data '1935' does not match format '%d/%B/%Y'
# 544: time data '1903' does not match format '%d/%B/%Y'
# 549: time data '1840' does not match format '%d/%B/%Y'
# 551: time data '1586' does not match format '%d/%B/%Y'
# 559: time data '1745' does not match format '%d/%B/%Y'
# 560: time data '1832' does not match format '%d/%B/%Y'
# 562: time data '1750/(José/Fernando/Mier/y' does not match format '%d/%B/%Y'
# 564: time data '1954' does not match format '%d/%B/%Y'
# 565: time data '1962' does not match format '%d/%B/%Y'
# 583: time data '1758/(por/Luis/Lozano/Scipión)' does not match format '%d/%B/%Y'
# 584: time data '1946' does not match format '%d/%B/%Y'
# 591: time data '1602' does not match format '%d/%B/%Y'
# 593: time data '1537' does not match format '%d/%B/%Y'
# 597: time data '1760' does not match format '%d/%B/%Y'
# 599: strptime() argument 1 must be str, not float
# 602: time data '1860' does not match format '%d/%B/%Y'
# 607: time data '1830' does not match format '%d/%B/%Y'
# 609: time data '1637' does not match format '%d/%B/%Y'
# 616: time data '1860' does not match format '%d/%B/%Y'
# 620: time data '1578' does not match format '%d/%B/%Y'
# 622: time data '1784' does not match format '%d/%B/%Y'
# 626: time data '1958' does not match format '%d/%B/%Y'
# 627: time data '1882' does not match format '%d/%B/%Y'
# 635: strptime() argument 1 must be str, not float
# 647: time data '1910' does not match format '%d/%B/%Y'
# 655: strptime() argument 1 must be str, not float
# 656: time data '1626' does not match format '%d/%B/%Y'
# 659: time data '1923' does not match format '%d/%B/%Y'
# 661: time data '1800' does not match format '%d/%B/%Y'
# 663: time data '1950' does not match format '%d/%B/%Y'
# 666: strptime() argument 1 must be str, not float
# 667: time data '1961' does not match format '%d/%B/%Y'
# 672: time data '1890  (131 años)' does not match format '%d/%B/%Y'
# 679: strptime() argument 1 must be str, not float
# 681: time data '1827' does not match format '%d/%B/%Y'
# 683: time data '1910' does not match format '%d/%B/%Y'
# 684: time data '1780' does not match format '%d/%B/%Y'
# 689: time data '1592   (por Melchor Guerra)' does not match format '%d/%B/%Y'
# 690: time data '1807' does not match format '%d/%B/%Y'
# 707: time data '1827' does not match format '%d/%B/%Y'
# 708: time data '1958' does not match format '%d/%B/%Y'
# 709: time data '1600' does not match format '%d/%B/%Y'
# 710: time data '1863' does not match format '%d/%B/%Y'
# 711: time data '1870' does not match format '%d/%B/%Y'
# 727: time data '1540' does not match format '%d/%B/%Y'
# 735: strptime() argument 1 must be str, not float
# 736: strptime() argument 1 must be str, not float
# 737: time data '1973' does not match format '%d/%B/%Y'
# 740: unconverted data remains: (218
# 741: time data '1870' does not match format '%d/%B/%Y'
# 745: time data '1815' does not match format '%d/%B/%Y'
# 746: time data '1801' does not match format '%d/%B/%Y'
# 755: time data '1582' does not match format '%d/%B/%Y'
# 766: time data '1737' does not match format '%d/%B/%Y'
# 768: time data '1826' does not match format '%d/%B/%Y'
# 775: time data '1610   (Pedro Beltrán Valdez)' does not match format '%d/%B/%Y'
# 780: time data '1850' does not match format '%d/%B/%Y'
# 792: time data '1572' does not match format '%d/%B/%Y'
# 793: time data '1627' does not match format '%d/%B/%Y'
# 799: time data '1728   (por Narcisa Quiscualtud)' does not match format '%d/%B/%Y'
# 802: time data '1535' does not match format '%d/%B/%Y'
# 803: time data '1761' does not match format '%d/%B/%Y'
# 807: time data '4 de octubre de1602' does not match format '%d/%B/%Y'
# 809: time data '1776' does not match format '%d/%B/%Y'
# 821: time data '1959' does not match format '%d/%B/%Y'
# 822: time data '1920' does not match format '%d/%B/%Y'
# 825: strptime() argument 1 must be str, not float
# 828: time data '1882' does not match format '%d/%B/%Y'
# 829: time data '1840' does not match format '%d/%B/%Y'
# 830: time data '1635' does not match format '%d/%B/%Y'
# 832: time data 'Se/trazó/pueblo/indios' does not match format '%d/%B/%Y'
# 838: time data '1875' does not match format '%d/%B/%Y'
# 842: time data '1936' does not match format '%d/%B/%Y'
# 844: time data '1652' does not match format '%d/%B/%Y'
# 850: time data '1920' does not match format '%d/%B/%Y'
# 852: strptime() argument 1 must be str, not float
# 854: time data '1945' does not match format '%d/%B/%Y'
# 857: time data '1837' does not match format '%d/%B/%Y'
# 859: time data '1908' does not match format '%d/%B/%Y'
# 860: time data '1876 (Managrú)' does not match format '%d/%B/%Y'
# 862: time data '1912' does not match format '%d/%B/%Y'
# 865: time data 'Segunda mitad de  1700' does not match format '%d/%B/%Y'
# 868: time data '1895' does not match format '%d/%B/%Y'
# 877: time data '1830' does not match format '%d/%B/%Y'
# 878: time data '1901' does not match format '%d/%B/%Y'
# 884: time data '1897' does not match format '%d/%B/%Y'
# 893: strptime() argument 1 must be str, not float
# 894: time data '1925' does not match format '%d/%B/%Y'
# 895: time data '1915' does not match format '%d/%B/%Y'
# 897: time data '1750' does not match format '%d/%B/%Y'
# 900: time data '1953' does not match format '%d/%B/%Y'
# 901: strptime() argument 1 must be str, not float
# 903: time data '1912' does not match format '%d/%B/%Y'
# 932: time data '19 Marzo  de  1938' does not match format '%d/%B/%Y'
# 942: time data '1822' does not match format '%d/%B/%Y'
# 947: strptime() argument 1 must be str, not float
# 960: strptime() argument 1 must be str, not float
# 963: strptime() argument 1 must be str, not float
# 964: time data '1537' does not match format '%d/%B/%Y'
# 973: time data '1617' does not match format '%d/%B/%Y'
# 975: time data '1683' does not match format '%d/%B/%Y'
# 979: strptime() argument 1 must be str, not float
# 981: time data '1538' does not match format '%d/%B/%Y'
# 986: time data '1780' does not match format '%d/%B/%Y'
# 990: time data '1935' does not match format '%d/%B/%Y'
# 991: time data '1909' does not match format '%d/%B/%Y'
# 992: time data '1593' does not match format '%d/%B/%Y'
# 1000: time data '1710' does not match format '%d/%B/%Y'
# 1003: strptime() argument 1 must be str, not float
# 1007: time data '1890' does not match format '%d/%B/%Y'
# 1008: time data '1816' does not match format '%d/%B/%Y'
# 1009: time data '1944' does not match format '%d/%B/%Y'
# 1013: time data '1917' does not match format '%d/%B/%Y'
# 1014: time data '1810' does not match format '%d/%B/%Y'
# 1018: strptime() argument 1 must be str, not float
# 1020: strptime() argument 1 must be str, not float
# 1021: strptime() argument 1 must be str, not float
# 1025: time data '1967' does not match format '%d/%B/%Y'
# 1030: strptime() argument 1 must be str, not float
# 1036: time data '1972' does not match format '%d/%B/%Y'
# 1045: time data '1715' does not match format '%d/%B/%Y'
# 1050: strptime() argument 1 must be str, not float
# 1059: time data '1930' does not match format '%d/%B/%Y'
# 1064: time data '1985' does not match format '%d/%B/%Y'
# 1073: strptime() argument 1 must be str, not float
# 1074: time data '1683' does not match format '%d/%B/%Y'
# 1079: strptime() argument 1 must be str, not float
# 1081: strptime() argument 1 must be str, not float
# 1082: strptime() argument 1 must be str, not float
# 1084: strptime() argument 1 must be str, not float
# 1086: time data '1670' does not match format '%d/%B/%Y'
# 1087: time data '1935' does not match format '%d/%B/%Y'
# 1089: strptime() argument 1 must be str, not float
# 1090: time data '1926' does not match format '%d/%B/%Y'
# 1093: strptime() argument 1 must be str, not float
# 1095: time data '1946' does not match format '%d/%B/%Y'
# 1096: strptime() argument 1 must be str, not float
# 1098: time data '1914' does not match format '%d/%B/%Y'
# 1109: strptime() argument 1 must be str, not float
# 1110: strptime() argument 1 must be str, not float
# 1111: time data '1930' does not match format '%d/%B/%Y'
# 1112: strptime() argument 1 must be str, not float
# 1113: strptime() argument 1 must be str, not float
# 1114: strptime() argument 1 must be str, not float
# 1116: strptime() argument 1 must be str, not float
# 1117: strptime() argument 1 must be str, not float
# 4: time data '1533' does not match format '%d/%B/%Y'
# 6: time data '1875' does not match format '%d/%B/%Y'
# 7: time data '1824' does not match format '%d/%B/%Y'
# 8: time data '1857' does not match format '%d/%B/%Y'
# 9: time data '1913' does not match format '%d/%B/%Y'
# 10: time data '1909' does not match format '%d/%B/%Y'
# 11: time data '1606' does not match format '%d/%B/%Y'
# 12: time data '1525' does not match format '%d/%B/%Y'
# 13: strptime() argument 1 must be str, not float
# 14: time data '1923' does not match format '%d/%B/%Y'
# 15: time data '' does not match format '%d/%B/%Y'
# 16: strptime() argument 1 must be str, not float
# 17: time data '1537' does not match format '%d/%B/%Y'
# 18: strptime() argument 1 must be str, not float
# 19: time data '1824' does not match format '%d/%B/%Y'
# 20: time data '1537' does not match format '%d/%B/%Y'
# 21: strptime() argument 1 must be str, not float
# 23: time data '1903' does not match format '%d/%B/%Y'
# 24: time data '1897' does not match format '%d/%B/%Y'
# 26: time data '1861' does not match format '%d/%B/%Y'
# 27: time data '1814' does not match format '%d/%B/%Y'
# 31: strptime() argument 1 must be str, not float
# 33: time data '' does not match format '%d/%B/%Y'
# 35: strptime() argument 1 must be str, not float
# 38: time data '1857' does not match format '%d/%B/%Y'
# 39: strptime() argument 1 must be str, not float
# 40: strptime() argument 1 must be str, not float
# 41: strptime() argument 1 must be str, not float
# 42: strptime() argument 1 must be str, not float
# 43: strptime() argument 1 must be str, not float
# 45: strptime() argument 1 must be str, not float
# 48: time data '1916' does not match format '%d/%B/%Y'
# 51: time data '1847' does not match format '%d/%B/%Y'
# 52: time data '1849' does not match format '%d/%B/%Y'
# 53: time data '1811' does not match format '%d/%B/%Y'
# 54: time data '1820' does not match format '%d/%B/%Y'
# 56: strptime() argument 1 must be str, not float
# 58: time data '1817' does not match format '%d/%B/%Y'
# 59: time data 'Formalmente Instituido  1914' does not match format '%d/%B/%Y'
# 60: time data '1832' does not match format '%d/%B/%Y'
# 61: strptime() argument 1 must be str, not float
# 62: strptime() argument 1 must be str, not float
# 65: strptime() argument 1 must be str, not float
# 66: time data '1864' does not match format '%d/%B/%Y'
# 68: time data '1923' does not match format '%d/%B/%Y'
# 72: time data '1959' does not match format '%d/%B/%Y'
# 77: strptime() argument 1 must be str, not float
# 78: strptime() argument 1 must be str, not float
# 80: strptime() argument 1 must be str, not float
# 82: time data '1812' does not match format '%d/%B/%Y'
# 83: strptime() argument 1 must be str, not float
# 85: time data '1833' does not match format '%d/%B/%Y'
# 86: strptime() argument 1 must be str, not float
# 90: time data '1870' does not match format '%d/%B/%Y'
# 91: time data '1813/-/1842/(como/cantón)' does not match format '%d/%B/%Y'
# 93: strptime() argument 1 must be str, not float
# 96: time data '1871' does not match format '%d/%B/%Y'
# 97: time data '1855' does not match format '%d/%B/%Y'
# 105: strptime() argument 1 must be str, not float
# 106: time data '3 de febrero' does not match format '%d/%B/%Y'
# 107: time data '1814' does not match format '%d/%B/%Y'
# 108: strptime() argument 1 must be str, not float
# 110: strptime() argument 1 must be str, not float
# 112: strptime() argument 1 must be str, not float
# 113: time data '1958' does not match format '%d/%B/%Y'
# 115: time data '1817' does not match format '%d/%B/%Y'
# 116: strptime() argument 1 must be str, not float
# 119: strptime() argument 1 must be str, not float
# 120: time data '1943' does not match format '%d/%B/%Y'
# 125: time data '1812' does not match format '%d/%B/%Y'
# 128: time data '1914' does not match format '%d/%B/%Y'
# 130: time data '1923' does not match format '%d/%B/%Y'
# 131: time data 'Marzo de  1950' does not match format '%d/%B/%Y'
# 136: time data '1979' does not match format '%d/%B/%Y'
# 137: time data '1837' does not match format '%d/%B/%Y'
# 138: time data '1932' does not match format '%d/%B/%Y'
# 139: time data '1863' does not match format '%d/%B/%Y'
# 140: strptime() argument 1 must be str, not float
# 141: time data '1925' does not match format '%d/%B/%Y'
# 142: time data '1864' does not match format '%d/%B/%Y'
# 144: strptime() argument 1 must be str, not float
# 146: time data '1870' does not match format '%d/%B/%Y'
# 147: strptime() argument 1 must be str, not float
# 148: time data '1951' does not match format '%d/%B/%Y'
# 149: time data '1836/(185/años)/(/República' does not match format '%d/%B/%Y'
# 151: time data '1540' does not match format '%d/%B/%Y'
# 152: time data '1758' does not match format '%d/%B/%Y'
# 153: time data '1793' does not match format '%d/%B/%Y'
# 154: strptime() argument 1 must be str, not float
# 157: time data '1978' does not match format '%d/%B/%Y'
# 161: time data '1911' does not match format '%d/%B/%Y'
# 162: time data '1821' does not match format '%d/%B/%Y'
# 163: strptime() argument 1 must be str, not float
# 166: time data '1912' does not match format '%d/%B/%Y'
# 171: time data '1881' does not match format '%d/%B/%Y'
# 172: strptime() argument 1 must be str, not float
# 173: time data '1965' does not match format '%d/%B/%Y'
# 175: time data '1912' does not match format '%d/%B/%Y'
# 177: time data '1870' does not match format '%d/%B/%Y'
# 178: time data '1892' does not match format '%d/%B/%Y'
# 179: time data '1551' does not match format '%d/%B/%Y'
# 180: strptime() argument 1 must be str, not float
# 182: time data '1954' does not match format '%d/%B/%Y'
# 183: time data '1814' does not match format '%d/%B/%Y'
# 188: time data '1944' does not match format '%d/%B/%Y'
# 192: time data '1875' does not match format '%d/%B/%Y'
# 193: time data '1892' does not match format '%d/%B/%Y'
# 194: strptime() argument 1 must be str, not float
# 197: time data '1808' does not match format '%d/%B/%Y'
# 202: strptime() argument 1 must be str, not float
# 203: strptime() argument 1 must be str, not float
# 204: time data '1982' does not match format '%d/%B/%Y'
# 208: time data 'Julio de  1954' does not match format '%d/%B/%Y'
# 213: time data '1890' does not match format '%d/%B/%Y'
# 217: strptime() argument 1 must be str, not float
# 218: strptime() argument 1 must be str, not float
# 219: time data '1926' does not match format '%d/%B/%Y'
# 221: time data '1771' does not match format '%d/%B/%Y'
# 223: time data '1864' does not match format '%d/%B/%Y'
# 224: time data '1779' does not match format '%d/%B/%Y'
# 233: strptime() argument 1 must be str, not float
# 234: strptime() argument 1 must be str, not float
# 236: strptime() argument 1 must be str, not float
# 240: time data '1860' does not match format '%d/%B/%Y'
# 241: time data '1812' does not match format '%d/%B/%Y'
# 246: time data '184' does not match format '%d/%B/%Y'
# 247: time data '1910' does not match format '%d/%B/%Y'
# 248: time data '1874' does not match format '%d/%B/%Y'
# 249: strptime() argument 1 must be str, not float
# 250: time data '1958' does not match format '%d/%B/%Y'
# 251: time data '1825' does not match format '%d/%B/%Y'
# 252: time data '1903' does not match format '%d/%B/%Y'
# 256: time data '1828' does not match format '%d/%B/%Y'
# 257: strptime() argument 1 must be str, not float
# 258: time data '1840' does not match format '%d/%B/%Y'
# 260: strptime() argument 1 must be str, not float
# 261: time data '1885' does not match format '%d/%B/%Y'
# 262: time data '1997' does not match format '%d/%B/%Y'
# 264: time data '1777' does not match format '%d/%B/%Y'
# 267: time data '1848' does not match format '%d/%B/%Y'
# 268: time data '' does not match format '%d/%B/%Y'
# 269: strptime() argument 1 must be str, not float
# 271: time data '1983' does not match format '%d/%B/%Y'
# 275: time data '1977' does not match format '%d/%B/%Y'
# 278: strptime() argument 1 must be str, not float
# 279: time data '1979' does not match format '%d/%B/%Y'
# 282: time data '1847' does not match format '%d/%B/%Y'
# 284: time data '1872' does not match format '%d/%B/%Y'
# 285: time data '1923' does not match format '%d/%B/%Y'
# 286: time data '1982' does not match format '%d/%B/%Y'
# 288: time data '1822' does not match format '%d/%B/%Y'
# 289: time data '1843' does not match format '%d/%B/%Y'
# 290: strptime() argument 1 must be str, not float
# 291: time data '1547' does not match format '%d/%B/%Y'
# 297: time data '1869' does not match format '%d/%B/%Y'
# 300: time data '1918' does not match format '%d/%B/%Y'
# 301: time data '1807' does not match format '%d/%B/%Y'
# 303: time data '1965' does not match format '%d/%B/%Y'
# 304: time data '1963' does not match format '%d/%B/%Y'
# 305: time data '1770' does not match format '%d/%B/%Y'
# 306: time data '1835' does not match format '%d/%B/%Y'
# 310: strptime() argument 1 must be str, not float
# 311: strptime() argument 1 must be str, not float
# 313: time data '1961' does not match format '%d/%B/%Y'
# 319: time data '1789' does not match format '%d/%B/%Y'
# 320: time data '1911' does not match format '%d/%B/%Y'
# 322: time data '1874' does not match format '%d/%B/%Y'
# 323: strptime() argument 1 must be str, not float
# 325: time data '1886' does not match format '%d/%B/%Y'
# 326: strptime() argument 1 must be str, not float
# 327: time data '1961' does not match format '%d/%B/%Y'
# 328: time data '1761' does not match format '%d/%B/%Y'
# 330: strptime() argument 1 must be str, not float
# 332: time data '1954' does not match format '%d/%B/%Y'
# 334: strptime() argument 1 must be str, not float
# 335: strptime() argument 1 must be str, not float
# 336: time data '1887' does not match format '%d/%B/%Y'
# 337: time data '1883' does not match format '%d/%B/%Y'
# 339: strptime() argument 1 must be str, not float
# 341: time data '1845' does not match format '%d/%B/%Y'
# 342: time data '1977' does not match format '%d/%B/%Y'
# 345: strptime() argument 1 must be str, not float
# 346: strptime() argument 1 must be str, not float
# 347: strptime() argument 1 must be str, not float
# 352: strptime() argument 1 must be str, not float
# 357: time data '1967' does not match format '%d/%B/%Y'
# 359: time data '1814' does not match format '%d/%B/%Y'
# 360: strptime() argument 1 must be str, not float
# 362: time data '1983' does not match format '%d/%B/%Y'
# 363: strptime() argument 1 must be str, not float
# 364: time data '1573' does not match format '%d/%B/%Y'
# 365: strptime() argument 1 must be str, not float
# 369: time data '1774' does not match format '%d/%B/%Y'
# 370: time data '1877' does not match format '%d/%B/%Y'
# 375: strptime() argument 1 must be str, not float
# 379: strptime() argument 1 must be str, not float
# 380: strptime() argument 1 must be str, not float
# 382: time data '1986' does not match format '%d/%B/%Y'
# 383: time data '1850' does not match format '%d/%B/%Y'
# 387: time data '1814' does not match format '%d/%B/%Y'
# 389: time data '1963' does not match format '%d/%B/%Y'
# 396: time data '1814' does not match format '%d/%B/%Y'
# 397: strptime() argument 1 must be str, not float
# 400: time data '1844' does not match format '%d/%B/%Y'
# 401: time data '2002' does not match format '%d/%B/%Y'
# 404: time data '1827' does not match format '%d/%B/%Y'
# 405: time data '1873' does not match format '%d/%B/%Y'
# 406: strptime() argument 1 must be str, not float
# 408: strptime() argument 1 must be str, not float
# 410: strptime() argument 1 must be str, not float
# 411: strptime() argument 1 must be str, not float
# 417: time data '1911' does not match format '%d/%B/%Y'
# 418: strptime() argument 1 must be str, not float
# 419: time data 'Junio de  1833' does not match format '%d/%B/%Y'
# 420: time data '' does not match format '%d/%B/%Y'
# 421: time data '1779' does not match format '%d/%B/%Y'
# 428: strptime() argument 1 must be str, not float
# 430: time data '1932' does not match format '%d/%B/%Y'
# 431: time data '1844' does not match format '%d/%B/%Y'
# 433: strptime() argument 1 must be str, not float
# 435: time data '1939' does not match format '%d/%B/%Y'
# 436: time data '1903' does not match format '%d/%B/%Y'
# 437: strptime() argument 1 must be str, not float
# 438: time data '1960' does not match format '%d/%B/%Y'
# 440: time data '1857' does not match format '%d/%B/%Y'
# 441: strptime() argument 1 must be str, not float
# 444: strptime() argument 1 must be str, not float
# 445: strptime() argument 1 must be str, not float
# 448: time data '1934' does not match format '%d/%B/%Y'
# 449: time data '1915' does not match format '%d/%B/%Y'
# 450: time data '' does not match format '%d/%B/%Y'
# 451: strptime() argument 1 must be str, not float
# 452: strptime() argument 1 must be str, not float
# 453: strptime() argument 1 must be str, not float
# 454: time data '1734' does not match format '%d/%B/%Y'
# 455: time data '1919' does not match format '%d/%B/%Y'
# 456: time data '1860' does not match format '%d/%B/%Y'
# 458: strptime() argument 1 must be str, not float
# 459: time data '1778' does not match format '%d/%B/%Y'
# 462: strptime() argument 1 must be str, not float
# 464: time data '1911' does not match format '%d/%B/%Y'
# 466: strptime() argument 1 must be str, not float
# 467: time data '' does not match format '%d/%B/%Y'
# 469: time data '1922' does not match format '%d/%B/%Y'
# 470: time data '1908' does not match format '%d/%B/%Y'
# 471: time data '1940' does not match format '%d/%B/%Y'
# 472: time data '1811' does not match format '%d/%B/%Y'
# 474: time data '1864' does not match format '%d/%B/%Y'
# 475: time data '1868' does not match format '%d/%B/%Y'
# 476: strptime() argument 1 must be str, not float
# 478: strptime() argument 1 must be str, not float
# 479: strptime() argument 1 must be str, not float
# 480: time data '1757' does not match format '%d/%B/%Y'
# 486: time data '1830' does not match format '%d/%B/%Y'
# 487: time data '1884' does not match format '%d/%B/%Y'
# 489: time data '1876' does not match format '%d/%B/%Y'
# 490: time data '1871' does not match format '%d/%B/%Y'
# 491: time data '1823' does not match format '%d/%B/%Y'
# 492: strptime() argument 1 must be str, not float
# 493: time data '1814' does not match format '%d/%B/%Y'
# 495: time data '1982' does not match format '%d/%B/%Y'
# 497: time data '1994' does not match format '%d/%B/%Y'
# 502: time data '1997' does not match format '%d/%B/%Y'
# 504: strptime() argument 1 must be str, not float
# 505: strptime() argument 1 must be str, not float
# 506: strptime() argument 1 must be str, not float
# 507: strptime() argument 1 must be str, not float
# 509: time data '1882' does not match format '%d/%B/%Y'
# 511: strptime() argument 1 must be str, not float
# 514: strptime() argument 1 must be str, not float
# 518: time data '1968' does not match format '%d/%B/%Y'
# 519: time data '' does not match format '%d/%B/%Y'
# 524: time data '1834' does not match format '%d/%B/%Y'
# 525: time data '1995' does not match format '%d/%B/%Y'
# 526: strptime() argument 1 must be str, not float
# 530: strptime() argument 1 must be str, not float
# 532: strptime() argument 1 must be str, not float
# 535: time data '1780' does not match format '%d/%B/%Y'
# 538: strptime() argument 1 must be str, not float
# 542: time data '1852' does not match format '%d/%B/%Y'
# 543: time data '1864' does not match format '%d/%B/%Y'
# 545: strptime() argument 1 must be str, not float
# 546: time data '' does not match format '%d/%B/%Y'
# 547: strptime() argument 1 must be str, not float
# 548: strptime() argument 1 must be str, not float
# 550: time data '1877' does not match format '%d/%B/%Y'
# 551: strptime() argument 1 must be str, not float
# 553: time data '1984' does not match format '%d/%B/%Y'
# 556: time data '1882' does not match format '%d/%B/%Y'
# 558: time data '1832' does not match format '%d/%B/%Y'
# 561: time data '1761' does not match format '%d/%B/%Y'
# 569: strptime() argument 1 must be str, not float
# 571: strptime() argument 1 must be str, not float
# 572: time data '1930' does not match format '%d/%B/%Y'
# 573: time data '1779' does not match format '%d/%B/%Y'
# 574: time data '1850' does not match format '%d/%B/%Y'
# 582: time data '1950' does not match format '%d/%B/%Y'
# 586: time data '1814' does not match format '%d/%B/%Y'
# 587: time data '1916' does not match format '%d/%B/%Y'
# 588: time data '1887' does not match format '%d/%B/%Y'
# 589: strptime() argument 1 must be str, not float
# 595: strptime() argument 1 must be str, not float
# 596: time data '1818' does not match format '%d/%B/%Y'
# 599: strptime() argument 1 must be str, not float
# 600: strptime() argument 1 must be str, not float
# 601: strptime() argument 1 must be str, not float
# 602: strptime() argument 1 must be str, not float
# 605: time data '' does not match format '%d/%B/%Y'
# 608: strptime() argument 1 must be str, not float
# 611: time data '1822' does not match format '%d/%B/%Y'
# 612: strptime() argument 1 must be str, not float
# 613: strptime() argument 1 must be str, not float
# 614: time data '' does not match format '%d/%B/%Y'
# 615: time data '1873' does not match format '%d/%B/%Y'
# 617: strptime() argument 1 must be str, not float
# 618: strptime() argument 1 must be str, not float
# 619: strptime() argument 1 must be str, not float
# 621: time data '1978' does not match format '%d/%B/%Y'
# 624: strptime() argument 1 must be str, not float
# 625: time data '1887' does not match format '%d/%B/%Y'
# 628: time data '1602' does not match format '%d/%B/%Y'
# 630: time data '1893' does not match format '%d/%B/%Y'
# 631: strptime() argument 1 must be str, not float
# 634: time data '1933' does not match format '%d/%B/%Y'
# 636: strptime() argument 1 must be str, not float
# 637: strptime() argument 1 must be str, not float
# 642: time data '1780' does not match format '%d/%B/%Y'
# 646: time data '1815' does not match format '%d/%B/%Y'
# 649: time data '1911' does not match format '%d/%B/%Y'
# 650: time data '1887' does not match format '%d/%B/%Y'
# 651: time data '1997' does not match format '%d/%B/%Y'
# 653: time data '1908' does not match format '%d/%B/%Y'
# 656: time data '1948' does not match format '%d/%B/%Y'
# 657: strptime() argument 1 must be str, not float
# 660: strptime() argument 1 must be str, not float
# 661: time data '1998' does not match format '%d/%B/%Y'
# 662: strptime() argument 1 must be str, not float
# 665: time data '1921' does not match format '%d/%B/%Y'
# 667: time data '1984' does not match format '%d/%B/%Y'
# 668: strptime() argument 1 must be str, not float
# 669: strptime() argument 1 must be str, not float
# 671: strptime() argument 1 must be str, not float
# 672: strptime() argument 1 must be str, not float
# 673: time data '1857' does not match format '%d/%B/%Y'
# 674: strptime() argument 1 must be str, not float
# 675: time data '1803' does not match format '%d/%B/%Y'
# 676: strptime() argument 1 must be str, not float
# 677: time data '1915' does not match format '%d/%B/%Y'
# 682: time data '1912' does not match format '%d/%B/%Y'
# 683: time data '1923' does not match format '%d/%B/%Y'
# 684: time data '1903' does not match format '%d/%B/%Y'
# 688: time data '1812' does not match format '%d/%B/%Y'
# 690: time data '1817' does not match format '%d/%B/%Y'
# 691: time data '1999' does not match format '%d/%B/%Y'
# 692: time data '1822' does not match format '%d/%B/%Y'
# 693: strptime() argument 1 must be str, not float
# 696: strptime() argument 1 must be str, not float
# 698: time data '1921' does not match format '%d/%B/%Y'
# 700: time data '1887' does not match format '%d/%B/%Y'
# 703: time data '1740' does not match format '%d/%B/%Y'
# 709: time data '1911' does not match format '%d/%B/%Y'
# 712: strptime() argument 1 must be str, not float
# 713: strptime() argument 1 must be str, not float
# 714: strptime() argument 1 must be str, not float
# 715: time data '1886' does not match format '%d/%B/%Y'
# 716: time data '1838' does not match format '%d/%B/%Y'
# 717: time data '1927' does not match format '%d/%B/%Y'
# 718: time data '1933' does not match format '%d/%B/%Y'
# 722: strptime() argument 1 must be str, not float
# 725: time data '1911' does not match format '%d/%B/%Y'
# 728: time data '1748' does not match format '%d/%B/%Y'
# 729: time data '1997' does not match format '%d/%B/%Y'
# 730: time data '1867' does not match format '%d/%B/%Y'
# 732: time data '1774' does not match format '%d/%B/%Y'
# 734: strptime() argument 1 must be str, not float
# 735: strptime() argument 1 must be str, not float
# 736: strptime() argument 1 must be str, not float
# 739: strptime() argument 1 must be str, not float
# 740: time data '' does not match format '%d/%B/%Y'
# 741: time data '1908' does not match format '%d/%B/%Y'
# 742: strptime() argument 1 must be str, not float
# 744: time data '1816' does not match format '%d/%B/%Y'
# 747: strptime() argument 1 must be str, not float
# 748: strptime() argument 1 must be str, not float
# 749: strptime() argument 1 must be str, not float
# 750: time data '1887' does not match format '%d/%B/%Y'
# 751: time data '1879' does not match format '%d/%B/%Y'
# 754: time data '1921' does not match format '%d/%B/%Y'
# 756: time data '1915' does not match format '%d/%B/%Y'
# 758: strptime() argument 1 must be str, not float
# 759: time data '1942' does not match format '%d/%B/%Y'
# 760: strptime() argument 1 must be str, not float
# 764: time data '1937' does not match format '%d/%B/%Y'
# 765: time data '1870' does not match format '%d/%B/%Y'
# 767: strptime() argument 1 must be str, not float
# 769: strptime() argument 1 must be str, not float
# 771: strptime() argument 1 must be str, not float
# 772: time data '1966' does not match format '%d/%B/%Y'
# 775: time data '1989' does not match format '%d/%B/%Y'
# 776: strptime() argument 1 must be str, not float
# 777: strptime() argument 1 must be str, not float
# 778: strptime() argument 1 must be str, not float
# 782: time data '1832' does not match format '%d/%B/%Y'
# 783: strptime() argument 1 must be str, not float
# 785: strptime() argument 1 must be str, not float
# 786: strptime() argument 1 must be str, not float
# 787: strptime() argument 1 must be str, not float
# 789: time data '1735' does not match format '%d/%B/%Y'
# 791: time data '1937' does not match format '%d/%B/%Y'
# 792: time data '1849' does not match format '%d/%B/%Y'
# 799: time data '1911' does not match format '%d/%B/%Y'
# 800: strptime() argument 1 must be str, not float
# 802: time data '1989' does not match format '%d/%B/%Y'
# 804: time data '' does not match format '%d/%B/%Y'
# 808: strptime() argument 1 must be str, not float
# 809: time data '1842' does not match format '%d/%B/%Y'
# 810: strptime() argument 1 must be str, not float
# 811: time data '1813' does not match format '%d/%B/%Y'
# 812: strptime() argument 1 must be str, not float
# 813: time data '1989' does not match format '%d/%B/%Y'
# 814: strptime() argument 1 must be str, not float
# 817: strptime() argument 1 must be str, not float
# 818: strptime() argument 1 must be str, not float
# 819: strptime() argument 1 must be str, not float
# 820: strptime() argument 1 must be str, not float
# 821: time data '1985' does not match format '%d/%B/%Y'
# 824: time data '1865' does not match format '%d/%B/%Y'
# 826: time data '1909' does not match format '%d/%B/%Y'
# 832: time data '1601' does not match format '%d/%B/%Y'
# 834: strptime() argument 1 must be str, not float
# 836: strptime() argument 1 must be str, not float
# 839: time data '1965' does not match format '%d/%B/%Y'
# 843: time data '1930' does not match format '%d/%B/%Y'
# 845: strptime() argument 1 must be str, not float
# 846: time data '1777' does not match format '%d/%B/%Y'
# 847: time data '1776' does not match format '%d/%B/%Y'
# 848: time data '' does not match format '%d/%B/%Y'
# 849: strptime() argument 1 must be str, not float
# 850: strptime() argument 1 must be str, not float
# 853: time data '1762' does not match format '%d/%B/%Y'
# 855: strptime() argument 1 must be str, not float
# 856: time data '1776' does not match format '%d/%B/%Y'
# 861: time data '1595' does not match format '%d/%B/%Y'
# 863: strptime() argument 1 must be str, not float
# 866: strptime() argument 1 must be str, not float
# 867: strptime() argument 1 must be str, not float
# 870: strptime() argument 1 must be str, not float
# 871: time data '' does not match format '%d/%B/%Y'
# 872: time data '1954' does not match format '%d/%B/%Y'
# 874: time data '1789' does not match format '%d/%B/%Y'
# 876: strptime() argument 1 must be str, not float
# 880: time data 'Julio de  1896' does not match format '%d/%B/%Y'
# 882: strptime() argument 1 must be str, not float
# 885: strptime() argument 1 must be str, not float
# 886: time data '1813' does not match format '%d/%B/%Y'
# 887: time data '1865' does not match format '%d/%B/%Y'
# 889: strptime() argument 1 must be str, not float
# 891: strptime() argument 1 must be str, not float
# 892: time data '1904' does not match format '%d/%B/%Y'
# 894: time data '1984' does not match format '%d/%B/%Y'
# 896: time data '1973' does not match format '%d/%B/%Y'
# 898: strptime() argument 1 must be str, not float
# 901: strptime() argument 1 must be str, not float
# 904: time data '1831' does not match format '%d/%B/%Y'
# 909: time data '1815' does not match format '%d/%B/%Y'
# 910: time data '1832' does not match format '%d/%B/%Y'
# 912: time data '1948' does not match format '%d/%B/%Y'
# 914: time data '1914' does not match format '%d/%B/%Y'
# 915: strptime() argument 1 must be str, not float
# 917: strptime() argument 1 must be str, not float
# 918: strptime() argument 1 must be str, not float
# 919: time data '1926' does not match format '%d/%B/%Y'
# 920: strptime() argument 1 must be str, not float
# 921: strptime() argument 1 must be str, not float
# 923: strptime() argument 1 must be str, not float
# 924: strptime() argument 1 must be str, not float
# 926: strptime() argument 1 must be str, not float
# 929: time data '1785' does not match format '%d/%B/%Y'
# 932: strptime() argument 1 must be str, not float
# 936: strptime() argument 1 must be str, not float
# 938: time data '1823' does not match format '%d/%B/%Y'
# 939: time data '1811' does not match format '%d/%B/%Y'
# 941: time data 'Enero de  1756' does not match format '%d/%B/%Y'
# 943: time data '1773' does not match format '%d/%B/%Y'
# 944: time data '1982' does not match format '%d/%B/%Y'
# 948: strptime() argument 1 must be str, not float
# 950: strptime() argument 1 must be str, not float
# 953: time data '1962' does not match format '%d/%B/%Y'
# 954: strptime() argument 1 must be str, not float
# 956: strptime() argument 1 must be str, not float
# 957: time data '1887' does not match format '%d/%B/%Y'
# 960: strptime() argument 1 must be str, not float
# 965: strptime() argument 1 must be str, not float
# 968: strptime() argument 1 must be str, not float
# 969: strptime() argument 1 must be str, not float
# 971: time data '1636' does not match format '%d/%B/%Y'
# 975: time data '1887' does not match format '%d/%B/%Y'
# 978: time data '1993' does not match format '%d/%B/%Y'
# 980: strptime() argument 1 must be str, not float
# 984: strptime() argument 1 must be str, not float
# 988: time data '1814' does not match format '%d/%B/%Y'
# 990: strptime() argument 1 must be str, not float
# 991: time data '1988' does not match format '%d/%B/%Y'
# 994: time data '1811' does not match format '%d/%B/%Y'
# 997: strptime() argument 1 must be str, not float
# 1002: time data '1781' does not match format '%d/%B/%Y'
# 1003: strptime() argument 1 must be str, not float
# 1004: time data '1832' does not match format '%d/%B/%Y'
# 1006: strptime() argument 1 must be str, not float
# 1010: strptime() argument 1 must be str, not float
# 1011: strptime() argument 1 must be str, not float
# 1012: strptime() argument 1 must be str, not float
# 1015: time data '1778' does not match format '%d/%B/%Y'
# 1017: strptime() argument 1 must be str, not float
# 1019: time data '1778' does not match format '%d/%B/%Y'
# 1021: strptime() argument 1 must be str, not float
# 1023: strptime() argument 1 must be str, not float
# 1024: strptime() argument 1 must be str, not float
# 1026: strptime() argument 1 must be str, not float
# 1027: time data '1936' does not match format '%d/%B/%Y'
# 1032: strptime() argument 1 must be str, not float
# 1033: strptime() argument 1 must be str, not float
# 1035: time data '1978' does not match format '%d/%B/%Y'
# 1037: strptime() argument 1 must be str, not float
# 1038: time data '1844' does not match format '%d/%B/%Y'
# 1039: time data '1776' does not match format '%d/%B/%Y'
# 1040: strptime() argument 1 must be str, not float
# 1041: time data '1656' does not match format '%d/%B/%Y'
# 1042: strptime() argument 1 must be str, not float
# 1043: time data '1976' does not match format '%d/%B/%Y'
# 1044: time data '1787' does not match format '%d/%B/%Y'
# 1045: strptime() argument 1 must be str, not float
# 1048: strptime() argument 1 must be str, not float
# 1049: strptime() argument 1 must be str, not float
# 1052: strptime() argument 1 must be str, not float
# 1053: time data '1959' does not match format '%d/%B/%Y'
# 1054: strptime() argument 1 must be str, not float
# 1055: time data '1887' does not match format '%d/%B/%Y'
# 1057: strptime() argument 1 must be str, not float
# 1058: time data '1885' does not match format '%d/%B/%Y'
# 1060: time data '1857' does not match format '%d/%B/%Y'
# 1061: time data '' does not match format '%d/%B/%Y'
# 1063: time data '1793' does not match format '%d/%B/%Y'
# 1065: strptime() argument 1 must be str, not float
# 1066: time data '1886' does not match format '%d/%B/%Y'
# 1068: strptime() argument 1 must be str, not float
# 1070: strptime() argument 1 must be str, not float
# 1071: time data '1887' does not match format '%d/%B/%Y'
# 1080: time data '1910' does not match format '%d/%B/%Y'
# 1082: strptime() argument 1 must be str, not float
# 1084: strptime() argument 1 must be str, not float
# 1085: strptime() argument 1 must be str, not float
# 1087: time data '1972' does not match format '%d/%B/%Y'
# 1091: strptime() argument 1 must be str, not float
# 1093: strptime() argument 1 must be str, not float
# 1094: time data '1913' does not match format '%d/%B/%Y'
# 1096: strptime() argument 1 must be str, not float
# 1097: time data '1842' does not match format '%d/%B/%Y'
# 1099: time data '1945' does not match format '%d/%B/%Y'
# 1103: time data '1780' does not match format '%d/%B/%Y'
# 1107: time data 'Diciembre de  1965' does not match format '%d/%B/%Y'
# 1108: strptime() argument 1 must be str, not float
# 1109: strptime() argument 1 must be str, not float
# 1110: strptime() argument 1 must be str, not float
# 1111: time data '1988' does not match format '%d/%B/%Y'
# 1112: strptime() argument 1 must be str, not float
# 1113: strptime() argument 1 must be str, not float
# 1114: strptime() argument 1 must be str, not float
# 1115: strptime() argument 1 must be str, not float
# 1116: strptime() argument 1 must be str, not float
# 1117: strptime() argument 1 must be str, not float

# %%
# Para aquellas fechas incompletas extraer, por lo menos, el año.

from re import search

columnas = ['Fundación', 'Erección']

for col in columnas:
    for idx in municipios_df.index:
        try:
            if not isinstance(municipios_df[col][idx], datetime):
                municipios_df[col][idx] = search('\d{4}', municipios_df[col][idx]).group(0)
        except Exception as e:
            print(f"{idx}: {e}")
# Out:
# <ipython-input-373-918fd63860d4>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   municipios_df[col][idx] = search('\d{4}', municipios_df[col][idx]).group(0)
# 49: 'NoneType' object has no attribute 'group'
# 60: 'NoneType' object has no attribute 'group'
# 80: expected string or bytes-like object
# 84: expected string or bytes-like object
# 89: expected string or bytes-like object
# 142: expected string or bytes-like object
# 150: expected string or bytes-like object
# 202: 'NoneType' object has no attribute 'group'
# 220: 'NoneType' object has no attribute 'group'
# 276: expected string or bytes-like object
# 293: expected string or bytes-like object
# 312: expected string or bytes-like object
# 325: expected string or bytes-like object
# 394: expected string or bytes-like object
# 403: expected string or bytes-like object
# 414: expected string or bytes-like object
# 418: expected string or bytes-like object
# 477: expected string or bytes-like object
# 488: expected string or bytes-like object
# 515: 'NoneType' object has no attribute 'group'
# 522: expected string or bytes-like object
# 524: expected string or bytes-like object
# 599: expected string or bytes-like object
# 635: expected string or bytes-like object
# 655: expected string or bytes-like object
# 666: expected string or bytes-like object
# 679: expected string or bytes-like object
# 735: expected string or bytes-like object
# 736: expected string or bytes-like object
# 825: expected string or bytes-like object
# 832: 'NoneType' object has no attribute 'group'
# 852: expected string or bytes-like object
# 893: expected string or bytes-like object
# 901: expected string or bytes-like object
# 947: expected string or bytes-like object
# 960: expected string or bytes-like object
# 963: expected string or bytes-like object
# 979: expected string or bytes-like object
# 1003: expected string or bytes-like object
# 1018: expected string or bytes-like object
# 1020: expected string or bytes-like object
# 1021: expected string or bytes-like object
# 1030: expected string or bytes-like object
# 1050: expected string or bytes-like object
# 1073: expected string or bytes-like object
# 1079: expected string or bytes-like object
# 1081: expected string or bytes-like object
# 1082: expected string or bytes-like object
# 1084: expected string or bytes-like object
# 1089: expected string or bytes-like object
# 1093: expected string or bytes-like object
# 1096: expected string or bytes-like object
# 1109: expected string or bytes-like object
# 1110: expected string or bytes-like object
# 1112: expected string or bytes-like object
# 1113: expected string or bytes-like object
# 1114: expected string or bytes-like object
# 1116: expected string or bytes-like object
# 1117: expected string or bytes-like object
# 13: expected string or bytes-like object
# 15: 'NoneType' object has no attribute 'group'
# 16: expected string or bytes-like object
# 18: expected string or bytes-like object
# 21: expected string or bytes-like object
# 31: expected string or bytes-like object
# 33: 'NoneType' object has no attribute 'group'
# 35: expected string or bytes-like object
# 39: expected string or bytes-like object
# 40: expected string or bytes-like object
# 41: expected string or bytes-like object
# 42: expected string or bytes-like object
# 43: expected string or bytes-like object
# 45: expected string or bytes-like object
# 56: expected string or bytes-like object
# 61: expected string or bytes-like object
# 62: expected string or bytes-like object
# 65: expected string or bytes-like object
# 77: expected string or bytes-like object
# 78: expected string or bytes-like object
# 80: expected string or bytes-like object
# 83: expected string or bytes-like object
# 86: expected string or bytes-like object
# 93: expected string or bytes-like object
# 105: expected string or bytes-like object
# 106: 'NoneType' object has no attribute 'group'
# 108: expected string or bytes-like object
# 110: expected string or bytes-like object
# 112: expected string or bytes-like object
# 116: expected string or bytes-like object
# 119: expected string or bytes-like object
# 140: expected string or bytes-like object
# 144: expected string or bytes-like object
# 147: expected string or bytes-like object
# 154: expected string or bytes-like object
# 163: expected string or bytes-like object
# 172: expected string or bytes-like object
# 180: expected string or bytes-like object
# 194: expected string or bytes-like object
# 202: expected string or bytes-like object
# 203: expected string or bytes-like object
# 217: expected string or bytes-like object
# 218: expected string or bytes-like object
# 233: expected string or bytes-like object
# 234: expected string or bytes-like object
# 236: expected string or bytes-like object
# 246: 'NoneType' object has no attribute 'group'
# 249: expected string or bytes-like object
# 257: expected string or bytes-like object
# 260: expected string or bytes-like object
# 268: 'NoneType' object has no attribute 'group'
# 269: expected string or bytes-like object
# 278: expected string or bytes-like object
# 290: expected string or bytes-like object
# 310: expected string or bytes-like object
# 311: expected string or bytes-like object
# 323: expected string or bytes-like object
# 326: expected string or bytes-like object
# 330: expected string or bytes-like object
# 334: expected string or bytes-like object
# 335: expected string or bytes-like object
# 339: expected string or bytes-like object
# 345: expected string or bytes-like object
# 346: expected string or bytes-like object
# 347: expected string or bytes-like object
# 352: expected string or bytes-like object
# 360: expected string or bytes-like object
# 363: expected string or bytes-like object
# 365: expected string or bytes-like object
# 375: expected string or bytes-like object
# 379: expected string or bytes-like object
# 380: expected string or bytes-like object
# 397: expected string or bytes-like object
# 406: expected string or bytes-like object
# 408: expected string or bytes-like object
# 410: expected string or bytes-like object
# 411: expected string or bytes-like object
# 418: expected string or bytes-like object
# 420: 'NoneType' object has no attribute 'group'
# 428: expected string or bytes-like object
# 433: expected string or bytes-like object
# 437: expected string or bytes-like object
# 441: expected string or bytes-like object
# 444: expected string or bytes-like object
# 445: expected string or bytes-like object
# 450: 'NoneType' object has no attribute 'group'
# 451: expected string or bytes-like object
# 452: expected string or bytes-like object
# 453: expected string or bytes-like object
# 458: expected string or bytes-like object
# 462: expected string or bytes-like object
# 466: expected string or bytes-like object
# 467: 'NoneType' object has no attribute 'group'
# 476: expected string or bytes-like object
# 478: expected string or bytes-like object
# 479: expected string or bytes-like object
# 492: expected string or bytes-like object
# 504: expected string or bytes-like object
# 505: expected string or bytes-like object
# 506: expected string or bytes-like object
# 507: expected string or bytes-like object
# 511: expected string or bytes-like object
# 514: expected string or bytes-like object
# 519: 'NoneType' object has no attribute 'group'
# 526: expected string or bytes-like object
# 530: expected string or bytes-like object
# 532: expected string or bytes-like object
# 538: expected string or bytes-like object
# 545: expected string or bytes-like object
# 546: 'NoneType' object has no attribute 'group'
# 547: expected string or bytes-like object
# 548: expected string or bytes-like object
# 551: expected string or bytes-like object
# 569: expected string or bytes-like object
# 571: expected string or bytes-like object
# 589: expected string or bytes-like object
# 595: expected string or bytes-like object
# 599: expected string or bytes-like object
# 600: expected string or bytes-like object
# 601: expected string or bytes-like object
# 602: expected string or bytes-like object
# 605: 'NoneType' object has no attribute 'group'
# 608: expected string or bytes-like object
# 612: expected string or bytes-like object
# 613: expected string or bytes-like object
# 614: 'NoneType' object has no attribute 'group'
# 617: expected string or bytes-like object
# 618: expected string or bytes-like object
# 619: expected string or bytes-like object
# 624: expected string or bytes-like object
# 631: expected string or bytes-like object
# 636: expected string or bytes-like object
# 637: expected string or bytes-like object
# 657: expected string or bytes-like object
# 660: expected string or bytes-like object
# 662: expected string or bytes-like object
# 668: expected string or bytes-like object
# 669: expected string or bytes-like object
# 671: expected string or bytes-like object
# 672: expected string or bytes-like object
# 674: expected string or bytes-like object
# 676: expected string or bytes-like object
# 693: expected string or bytes-like object
# 696: expected string or bytes-like object
# 712: expected string or bytes-like object
# 713: expected string or bytes-like object
# 714: expected string or bytes-like object
# 722: expected string or bytes-like object
# 734: expected string or bytes-like object
# 735: expected string or bytes-like object
# 736: expected string or bytes-like object
# 739: expected string or bytes-like object
# 740: 'NoneType' object has no attribute 'group'
# 742: expected string or bytes-like object
# 747: expected string or bytes-like object
# 748: expected string or bytes-like object
# 749: expected string or bytes-like object
# 758: expected string or bytes-like object
# 760: expected string or bytes-like object
# 767: expected string or bytes-like object
# 769: expected string or bytes-like object
# 771: expected string or bytes-like object
# 776: expected string or bytes-like object
# 777: expected string or bytes-like object
# 778: expected string or bytes-like object
# 783: expected string or bytes-like object
# 785: expected string or bytes-like object
# 786: expected string or bytes-like object
# 787: expected string or bytes-like object
# 800: expected string or bytes-like object
# 804: 'NoneType' object has no attribute 'group'
# 808: expected string or bytes-like object
# 810: expected string or bytes-like object
# 812: expected string or bytes-like object
# 814: expected string or bytes-like object
# 817: expected string or bytes-like object
# 818: expected string or bytes-like object
# 819: expected string or bytes-like object
# 820: expected string or bytes-like object
# 834: expected string or bytes-like object
# 836: expected string or bytes-like object
# 845: expected string or bytes-like object
# 848: 'NoneType' object has no attribute 'group'
# 849: expected string or bytes-like object
# 850: expected string or bytes-like object
# 855: expected string or bytes-like object
# 863: expected string or bytes-like object
# 866: expected string or bytes-like object
# 867: expected string or bytes-like object
# 870: expected string or bytes-like object
# 871: 'NoneType' object has no attribute 'group'
# 876: expected string or bytes-like object
# 882: expected string or bytes-like object
# 885: expected string or bytes-like object
# 889: expected string or bytes-like object
# 891: expected string or bytes-like object
# 898: expected string or bytes-like object
# 901: expected string or bytes-like object
# 915: expected string or bytes-like object
# 917: expected string or bytes-like object
# 918: expected string or bytes-like object
# 920: expected string or bytes-like object
# 921: expected string or bytes-like object
# 923: expected string or bytes-like object
# 924: expected string or bytes-like object
# 926: expected string or bytes-like object
# 932: expected string or bytes-like object
# 936: expected string or bytes-like object
# 948: expected string or bytes-like object
# 950: expected string or bytes-like object
# 954: expected string or bytes-like object
# 956: expected string or bytes-like object
# 960: expected string or bytes-like object
# 965: expected string or bytes-like object
# 968: expected string or bytes-like object
# 969: expected string or bytes-like object
# 980: expected string or bytes-like object
# 984: expected string or bytes-like object
# 990: expected string or bytes-like object
# 997: expected string or bytes-like object
# 1003: expected string or bytes-like object
# 1006: expected string or bytes-like object
# 1010: expected string or bytes-like object
# 1011: expected string or bytes-like object
# 1012: expected string or bytes-like object
# 1017: expected string or bytes-like object
# 1021: expected string or bytes-like object
# 1023: expected string or bytes-like object
# 1024: expected string or bytes-like object
# 1026: expected string or bytes-like object
# 1032: expected string or bytes-like object
# 1033: expected string or bytes-like object
# 1037: expected string or bytes-like object
# 1040: expected string or bytes-like object
# 1042: expected string or bytes-like object
# 1045: expected string or bytes-like object
# 1048: expected string or bytes-like object
# 1049: expected string or bytes-like object
# 1052: expected string or bytes-like object
# 1054: expected string or bytes-like object
# 1057: expected string or bytes-like object
# 1061: 'NoneType' object has no attribute 'group'
# 1065: expected string or bytes-like object
# 1068: expected string or bytes-like object
# 1070: expected string or bytes-like object
# 1082: expected string or bytes-like object
# 1084: expected string or bytes-like object
# 1085: expected string or bytes-like object
# 1091: expected string or bytes-like object
# 1093: expected string or bytes-like object
# 1096: expected string or bytes-like object
# 1108: expected string or bytes-like object
# 1109: expected string or bytes-like object
# 1110: expected string or bytes-like object
# 1112: expected string or bytes-like object
# 1113: expected string or bytes-like object
# 1114: expected string or bytes-like object
# 1115: expected string or bytes-like object
# 1116: expected string or bytes-like object
# 1117: expected string or bytes-like object

# %% [markdown]
# ##### ** Conversión de datos númericos, modificación de strings y  manejo de valores faltantes (NaN) **

# %%
# Convertir valores de la columna superficie a flotantes, creando una nueva columna que muestre la unidad de medida en (km²)

municipios_df['Superficie (km²)'] = np.NaN

for idx in municipios_df.index:
    try:
        municipios_df['Superficie (km²)'][idx] = float(municipios_df['Superficie'][idx].split()[0])
    except ValueError:
        try:
            municipios_df['Superficie (km²)'][idx] = float(municipios_df['Superficie'][idx].split()[0].replace(',', '.'))
        except Exception as e:
            print(f"{idx}: {e}")

# Eliminar columna 'Superficie'
municipios_df = municipios_df.drop("Superficie", 1)
# Out:
# <ipython-input-375-715a539a50c3>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   municipios_df['Superficie (km²)'][idx] = float(municipios_df['Superficie'][idx].split()[0])
# <ipython-input-375-715a539a50c3>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   municipios_df['Superficie (km²)'][idx] = float(municipios_df['Superficie'][idx].split()[0].replace(',', '.'))
# 614: could not convert string to float: '43.112.3'
# 815: could not convert string to float: '256M2'

# %%
# Convertir valores de la columna 'Altitud Media' a enteros, creando una nueva columna que muestre la unidad de medida en (msnm)

municipios_df['Altitud Media (m.s.n.m)'] = np.NaN

for idx in municipios_df.index:
    try:
        municipios_df['Altitud Media (m.s.n.m)'][idx] = float(municipios_df['Altitud Media'][idx].split()[0].replace(',', '.'))
    except Exception as e:
        print(f"{idx}: {e}")

# Eliminar columna 'Altitud Media'
municipios_df = municipios_df.drop("Altitud Media", 1)
# Out:
# <ipython-input-376-48130f1d33da>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   municipios_df['Altitud Media (m.s.n.m)'][idx] = float(municipios_df['Altitud Media'][idx].split()[0].replace(',', '.'))
# 215: could not convert string to float: '402-2987'
# 717: could not convert string to float: '1600/3000'
# 986: could not convert string to float: 'De'
# 1022: could not convert string to float: '85]'
# 1024: could not convert string to float: '2387-3200'

# %%
# Convertir valores de columna 'Densidad' a flotantes, creando una nueva columna que muestre la unidad de medida en (hab/km²)

municipios_df['Densidad (hab/km²)'] = np.NaN

for idx in municipios_df.index:
    try:
        municipios_df['Densidad (hab/km²)'][idx] = float(municipios_df['Densidad'][idx].split()[0])
    except (ValueError, AttributeError):
        try:
            municipios_df['Densidad (hab/km²)'][idx] = float(municipios_df['Densidad'][idx].split()[0].replace(',', '.'))
        except Exception as e:
            print(f"{idx}: {e}")


# Eliminar columna 'Densidad'
municipios_df = municipios_df.drop("Densidad", 1)
# Out:
# <ipython-input-377-76722e60e35f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   municipios_df['Densidad (hab/km²)'][idx] = float(municipios_df['Densidad'][idx].split()[0].replace(',', '.'))
# <ipython-input-377-76722e60e35f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   municipios_df['Densidad (hab/km²)'][idx] = float(municipios_df['Densidad'][idx].split()[0])
# 75: 'float' object has no attribute 'split'
# 85: 'float' object has no attribute 'split'
# 89: 'float' object has no attribute 'split'
# 98: 'float' object has no attribute 'split'
# 103: 'float' object has no attribute 'split'
# 115: 'float' object has no attribute 'split'
# 116: 'float' object has no attribute 'split'
# 118: 'float' object has no attribute 'split'
# 119: 'float' object has no attribute 'split'
# 123: 'float' object has no attribute 'split'
# 125: 'float' object has no attribute 'split'
# 127: 'float' object has no attribute 'split'
# 128: 'float' object has no attribute 'split'
# 134: 'float' object has no attribute 'split'
# 143: 'float' object has no attribute 'split'
# 148: 'float' object has no attribute 'split'
# 150: 'float' object has no attribute 'split'
# 153: 'float' object has no attribute 'split'
# 156: 'float' object has no attribute 'split'
# 157: 'float' object has no attribute 'split'
# 158: 'float' object has no attribute 'split'
# 159: 'float' object has no attribute 'split'
# 160: 'float' object has no attribute 'split'
# 161: 'float' object has no attribute 'split'
# 166: 'float' object has no attribute 'split'
# 167: 'float' object has no attribute 'split'
# 170: 'float' object has no attribute 'split'
# 171: 'float' object has no attribute 'split'
# 172: 'float' object has no attribute 'split'
# 175: 'float' object has no attribute 'split'
# 182: 'float' object has no attribute 'split'
# 185: 'float' object has no attribute 'split'
# 186: 'float' object has no attribute 'split'
# 187: 'float' object has no attribute 'split'
# 189: 'float' object has no attribute 'split'
# 195: 'float' object has no attribute 'split'
# 199: 'float' object has no attribute 'split'
# 214: 'float' object has no attribute 'split'
# 220: 'float' object has no attribute 'split'
# 224: 'float' object has no attribute 'split'
# 233: 'float' object has no attribute 'split'
# 237: 'float' object has no attribute 'split'
# 238: 'float' object has no attribute 'split'
# 239: 'float' object has no attribute 'split'
# 240: 'float' object has no attribute 'split'
# 243: 'float' object has no attribute 'split'
# 244: 'float' object has no attribute 'split'
# 249: 'float' object has no attribute 'split'
# 252: 'float' object has no attribute 'split'
# 255: 'float' object has no attribute 'split'
# 257: 'float' object has no attribute 'split'
# 259: 'float' object has no attribute 'split'
# 260: 'float' object has no attribute 'split'
# 261: 'float' object has no attribute 'split'
# 262: 'float' object has no attribute 'split'
# 263: 'float' object has no attribute 'split'
# 265: 'float' object has no attribute 'split'
# 280: 'float' object has no attribute 'split'
# 281: 'float' object has no attribute 'split'
# 282: 'float' object has no attribute 'split'
# 284: 'float' object has no attribute 'split'
# 286: 'float' object has no attribute 'split'
# 298: 'float' object has no attribute 'split'
# 299: 'float' object has no attribute 'split'
# 302: 'float' object has no attribute 'split'
# 304: 'float' object has no attribute 'split'
# 306: 'float' object has no attribute 'split'
# 307: 'float' object has no attribute 'split'
# 308: 'float' object has no attribute 'split'
# 309: 'float' object has no attribute 'split'
# 312: 'float' object has no attribute 'split'
# 314: 'float' object has no attribute 'split'
# 318: 'float' object has no attribute 'split'
# 319: 'float' object has no attribute 'split'
# 320: 'float' object has no attribute 'split'
# 321: 'float' object has no attribute 'split'
# 322: 'float' object has no attribute 'split'
# 325: 'float' object has no attribute 'split'
# 327: 'float' object has no attribute 'split'
# 332: 'float' object has no attribute 'split'
# 336: 'float' object has no attribute 'split'
# 345: 'float' object has no attribute 'split'
# 346: 'float' object has no attribute 'split'
# 347: 'float' object has no attribute 'split'
# 355: 'float' object has no attribute 'split'
# 368: 'float' object has no attribute 'split'
# 369: 'float' object has no attribute 'split'
# 370: 'float' object has no attribute 'split'
# 371: 'float' object has no attribute 'split'
# 374: 'float' object has no attribute 'split'
# 379: 'float' object has no attribute 'split'
# 380: 'float' object has no attribute 'split'
# 383: 'float' object has no attribute 'split'
# 387: 'float' object has no attribute 'split'
# 388: 'float' object has no attribute 'split'
# 389: 'float' object has no attribute 'split'
# 392: 'float' object has no attribute 'split'
# 396: 'float' object has no attribute 'split'
# 398: 'float' object has no attribute 'split'
# 399: 'float' object has no attribute 'split'
# 406: 'float' object has no attribute 'split'
# 407: 'float' object has no attribute 'split'
# 408: 'float' object has no attribute 'split'
# 416: 'float' object has no attribute 'split'
# 417: 'float' object has no attribute 'split'
# 418: 'float' object has no attribute 'split'
# 423: 'float' object has no attribute 'split'
# 428: 'float' object has no attribute 'split'
# 429: 'float' object has no attribute 'split'
# 434: 'float' object has no attribute 'split'
# 435: 'float' object has no attribute 'split'
# 437: 'float' object has no attribute 'split'
# 438: 'float' object has no attribute 'split'
# 441: 'float' object has no attribute 'split'
# 443: 'float' object has no attribute 'split'
# 448: 'float' object has no attribute 'split'
# 449: 'float' object has no attribute 'split'
# 450: 'float' object has no attribute 'split'
# 452: 'float' object has no attribute 'split'
# 453: 'float' object has no attribute 'split'
# 454: 'float' object has no attribute 'split'
# 461: 'float' object has no attribute 'split'
# 464: 'float' object has no attribute 'split'
# 465: 'float' object has no attribute 'split'
# 466: 'float' object has no attribute 'split'
# 469: 'float' object has no attribute 'split'
# 470: 'float' object has no attribute 'split'
# 471: 'float' object has no attribute 'split'
# 481: 'float' object has no attribute 'split'
# 484: 'float' object has no attribute 'split'
# 487: 'float' object has no attribute 'split'
# 488: 'float' object has no attribute 'split'
# 489: 'float' object has no attribute 'split'
# 497: 'float' object has no attribute 'split'
# 501: 'float' object has no attribute 'split'
# 502: 'float' object has no attribute 'split'
# 511: 'float' object has no attribute 'split'
# 512: 'float' object has no attribute 'split'
# 514: 'float' object has no attribute 'split'
# 517: 'float' object has no attribute 'split'
# 518: 'float' object has no attribute 'split'
# 520: 'float' object has no attribute 'split'
# 522: 'float' object has no attribute 'split'
# 524: 'float' object has no attribute 'split'
# 530: 'float' object has no attribute 'split'
# 531: 'float' object has no attribute 'split'
# 533: 'float' object has no attribute 'split'
# 535: 'float' object has no attribute 'split'
# 538: 'float' object has no attribute 'split'
# 539: 'float' object has no attribute 'split'
# 540: 'float' object has no attribute 'split'
# 541: 'float' object has no attribute 'split'
# 549: 'float' object has no attribute 'split'
# 550: 'float' object has no attribute 'split'
# 554: 'float' object has no attribute 'split'
# 557: 'float' object has no attribute 'split'
# 559: 'float' object has no attribute 'split'
# 560: 'float' object has no attribute 'split'
# 561: 'float' object has no attribute 'split'
# 562: 'float' object has no attribute 'split'
# 569: 'float' object has no attribute 'split'
# 574: 'float' object has no attribute 'split'
# 580: 'float' object has no attribute 'split'
# 581: 'float' object has no attribute 'split'
# 582: 'float' object has no attribute 'split'
# 590: 'float' object has no attribute 'split'
# 592: 'float' object has no attribute 'split'
# 593: 'float' object has no attribute 'split'
# 594: 'float' object has no attribute 'split'
# 595: 'float' object has no attribute 'split'
# 596: 'float' object has no attribute 'split'
# 600: 'float' object has no attribute 'split'
# 602: 'float' object has no attribute 'split'
# 604: 'float' object has no attribute 'split'
# 607: 'float' object has no attribute 'split'
# 611: 'float' object has no attribute 'split'
# 616: 'float' object has no attribute 'split'
# 617: 'float' object has no attribute 'split'
# 622: 'float' object has no attribute 'split'
# 624: 'float' object has no attribute 'split'
# 631: 'float' object has no attribute 'split'
# 632: 'float' object has no attribute 'split'
# 639: 'float' object has no attribute 'split'
# 648: 'float' object has no attribute 'split'
# 653: 'float' object has no attribute 'split'
# 661: 'float' object has no attribute 'split'
# 662: 'float' object has no attribute 'split'
# 663: 'float' object has no attribute 'split'
# 670: 'float' object has no attribute 'split'
# 674: 'float' object has no attribute 'split'
# 675: 'float' object has no attribute 'split'
# 676: 'float' object has no attribute 'split'
# 680: 'float' object has no attribute 'split'
# 681: 'float' object has no attribute 'split'
# 682: 'float' object has no attribute 'split'
# 684: 'float' object has no attribute 'split'
# 686: 'float' object has no attribute 'split'
# 688: 'float' object has no attribute 'split'
# 689: 'float' object has no attribute 'split'
# 691: 'float' object has no attribute 'split'
# 692: 'float' object has no attribute 'split'
# 694: 'float' object has no attribute 'split'
# 695: 'float' object has no attribute 'split'
# 700: 'float' object has no attribute 'split'
# 704: 'float' object has no attribute 'split'
# 706: 'float' object has no attribute 'split'
# 708: 'float' object has no attribute 'split'
# 709: 'float' object has no attribute 'split'
# 712: 'float' object has no attribute 'split'
# 714: 'float' object has no attribute 'split'
# 715: 'float' object has no attribute 'split'
# 716: 'float' object has no attribute 'split'
# 718: 'float' object has no attribute 'split'
# 719: 'float' object has no attribute 'split'
# 725: 'float' object has no attribute 'split'
# 728: 'float' object has no attribute 'split'
# 730: 'float' object has no attribute 'split'
# 731: 'float' object has no attribute 'split'
# 733: 'float' object has no attribute 'split'
# 736: 'float' object has no attribute 'split'
# 737: 'float' object has no attribute 'split'
# 742: 'float' object has no attribute 'split'
# 747: 'float' object has no attribute 'split'
# 751: 'float' object has no attribute 'split'
# 756: 'float' object has no attribute 'split'
# 757: 'float' object has no attribute 'split'
# 759: 'float' object has no attribute 'split'
# 761: 'float' object has no attribute 'split'
# 766: 'float' object has no attribute 'split'
# 769: 'float' object has no attribute 'split'
# 771: 'float' object has no attribute 'split'
# 774: 'float' object has no attribute 'split'
# 781: 'float' object has no attribute 'split'
# 789: 'float' object has no attribute 'split'
# 790: 'float' object has no attribute 'split'
# 792: 'float' object has no attribute 'split'
# 793: 'float' object has no attribute 'split'
# 794: 'float' object has no attribute 'split'
# 795: 'float' object has no attribute 'split'
# 796: 'float' object has no attribute 'split'
# 801: 'float' object has no attribute 'split'
# 805: 'float' object has no attribute 'split'
# 809: 'float' object has no attribute 'split'
# 813: 'float' object has no attribute 'split'
# 814: 'float' object has no attribute 'split'
# 816: 'float' object has no attribute 'split'
# 819: 'float' object has no attribute 'split'
# 822: 'float' object has no attribute 'split'
# 824: 'float' object has no attribute 'split'
# 835: 'float' object has no attribute 'split'
# 837: 'float' object has no attribute 'split'
# 840: 'float' object has no attribute 'split'
# 841: 'float' object has no attribute 'split'
# 844: 'float' object has no attribute 'split'
# 846: 'float' object has no attribute 'split'
# 848: 'float' object has no attribute 'split'
# 850: 'float' object has no attribute 'split'
# 852: 'float' object has no attribute 'split'
# 857: 'float' object has no attribute 'split'
# 859: 'float' object has no attribute 'split'
# 864: 'float' object has no attribute 'split'
# 865: 'float' object has no attribute 'split'
# 866: 'float' object has no attribute 'split'
# 869: 'float' object has no attribute 'split'
# 870: 'float' object has no attribute 'split'
# 878: 'float' object has no attribute 'split'
# 884: 'float' object has no attribute 'split'
# 886: 'float' object has no attribute 'split'
# 887: 'float' object has no attribute 'split'
# 888: 'float' object has no attribute 'split'
# 890: 'float' object has no attribute 'split'
# 894: 'float' object has no attribute 'split'
# 895: 'float' object has no attribute 'split'
# 897: 'float' object has no attribute 'split'
# 899: 'float' object has no attribute 'split'
# 900: 'float' object has no attribute 'split'
# 901: 'float' object has no attribute 'split'
# 905: 'float' object has no attribute 'split'
# 909: 'float' object has no attribute 'split'
# 911: 'float' object has no attribute 'split'
# 914: 'float' object has no attribute 'split'
# 919: 'float' object has no attribute 'split'
# 924: 'float' object has no attribute 'split'
# 926: 'float' object has no attribute 'split'
# 927: 'float' object has no attribute 'split'
# 930: 'float' object has no attribute 'split'
# 934: 'float' object has no attribute 'split'
# 938: 'float' object has no attribute 'split'
# 940: 'float' object has no attribute 'split'
# 945: 'float' object has no attribute 'split'
# 946: 'float' object has no attribute 'split'
# 953: 'float' object has no attribute 'split'
# 954: 'float' object has no attribute 'split'
# 955: 'float' object has no attribute 'split'
# 960: 'float' object has no attribute 'split'
# 962: 'float' object has no attribute 'split'
# 963: 'float' object has no attribute 'split'
# 964: 'float' object has no attribute 'split'
# 966: 'float' object has no attribute 'split'
# 970: 'float' object has no attribute 'split'
# 971: 'float' object has no attribute 'split'
# 974: 'float' object has no attribute 'split'
# 975: 'float' object has no attribute 'split'
# 979: 'float' object has no attribute 'split'
# 984: 'float' object has no attribute 'split'
# 986: 'float' object has no attribute 'split'
# 988: 'float' object has no attribute 'split'
# 989: 'float' object has no attribute 'split'
# 990: 'float' object has no attribute 'split'
# 993: 'float' object has no attribute 'split'
# 995: 'float' object has no attribute 'split'
# 998: 'float' object has no attribute 'split'
# 1001: 'float' object has no attribute 'split'
# 1003: 'float' object has no attribute 'split'
# 1006: 'float' object has no attribute 'split'
# 1008: 'float' object has no attribute 'split'
# 1011: 'float' object has no attribute 'split'
# 1012: 'float' object has no attribute 'split'
# 1017: 'float' object has no attribute 'split'
# 1020: 'float' object has no attribute 'split'
# 1027: 'float' object has no attribute 'split'
# 1029: 'float' object has no attribute 'split'
# 1030: 'float' object has no attribute 'split'
# 1038: 'float' object has no attribute 'split'
# 1042: 'float' object has no attribute 'split'
# 1048: 'float' object has no attribute 'split'
# 1053: 'float' object has no attribute 'split'
# 1056: 'float' object has no attribute 'split'
# 1057: 'float' object has no attribute 'split'
# 1058: 'float' object has no attribute 'split'
# 1061: 'float' object has no attribute 'split'
# 1066: 'float' object has no attribute 'split'
# 1067: 'float' object has no attribute 'split'
# 1068: 'float' object has no attribute 'split'
# 1069: 'float' object has no attribute 'split'
# 1070: 'float' object has no attribute 'split'
# 1071: 'float' object has no attribute 'split'
# 1075: 'float' object has no attribute 'split'
# 1076: 'float' object has no attribute 'split'
# 1077: 'float' object has no attribute 'split'
# 1081: 'float' object has no attribute 'split'
# 1082: 'float' object has no attribute 'split'
# 1084: 'float' object has no attribute 'split'
# 1086: 'float' object has no attribute 'split'
# 1092: 'float' object has no attribute 'split'
# 1095: 'float' object has no attribute 'split'
# 1096: 'float' object has no attribute 'split'
# 1099: 'float' object has no attribute 'split'
# 1103: 'float' object has no attribute 'split'
# 1104: 'float' object has no attribute 'split'
# 1110: 'float' object has no attribute 'split'
# 1111: 'float' object has no attribute 'split'
# 1112: 'float' object has no attribute 'split'
# 1113: 'float' object has no attribute 'split'
# 1114: 'float' object has no attribute 'split'
# 1116: 'float' object has no attribute 'split'

# %%
# Convertir los valores de las columnas 'Población Total' y 'Pobl. Urbana' de string a enteros

columnas = {'Población Total': 'Población Total (hab)', 'Pobl. Urbana': 'Pobl. Urbana (hab)'}

municipios_df['Pobl. Urbana (hab)'] = np.NaN
municipios_df['Población Total (hab)'] = np.NaN

for key, value in columnas.items():
    for idx in municipios_df.index:
        try:
            municipios_df[value][idx] = int(municipios_df[key][idx].split(' hab.')[0].replace(' ', '').replace(',', ''))
        except Exception as e:   
            print(f"{idx}: {e}")
    
    # Eliminar la columna correspondiente (anterior)
    municipios_df = municipios_df.drop(key, 1)
# Out:
# <ipython-input-397-4f322e02f4e6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   municipios_df[value][idx] = int(municipios_df[key][idx].split(' hab.')[0].replace(' ', '').replace(',', ''))
# 82: invalid literal for int() with base 10: "74'500Estimado"
# 172: invalid literal for int() with base 10: '38838(2018)'
# 247: invalid literal for int() with base 10: '21716Habitantes\t10/292'
# 352: invalid literal for int() with base 10: '17487Habitantes(2018)'
# 441: invalid literal for int() with base 10: ''
# 990: invalid literal for int() with base 10: ''
# 998: 'float' object has no attribute 'split'
# 1006: invalid literal for int() with base 10: ''
# 1067: invalid literal for int() with base 10: ''
# 1082: invalid literal for int() with base 10: ''
# 1084: invalid literal for int() with base 10: ''
# 1095: invalid literal for int() with base 10: ''
# 1111: invalid literal for int() with base 10: ''
# 1112: invalid literal for int() with base 10: ''
# 13: 'float' object has no attribute 'split'
# 80: 'float' object has no attribute 'split'
# 100: 'float' object has no attribute 'split'
# 193: 'float' object has no attribute 'split'
# 269: 'float' object has no attribute 'split'
# 371: 'float' object has no attribute 'split'
# 441: 'float' object has no attribute 'split'
# 531: 'float' object has no attribute 'split'
# 562: 'float' object has no attribute 'split'
# 998: 'float' object has no attribute 'split'
# 1006: 'float' object has no attribute 'split'
# 1036: 'float' object has no attribute 'split'
# 1064: 'float' object has no attribute 'split'
# 1067: 'float' object has no attribute 'split'
# 1077: 'float' object has no attribute 'split'
# 1084: 'float' object has no attribute 'split'
# 1097: 'float' object has no attribute 'split'
# 1109: 'float' object has no attribute 'split'
# 1110: 'float' object has no attribute 'split'
# 1117: 'float' object has no attribute 'split'

# %%
# Acortar el tamaño de las coordenadas, mostrando solo la latitud y la longitud.

for idx in municipios_df.index:
    try:
        municipios_df['Coordenadas'][idx] = municipios_df['Coordenadas'][idx].split('/')[0].replace('\ufeff', '').strip()
    except Exception as e:
        print(f"{idx}: {e}")
# Out:
# <ipython-input-432-a195df9feb5e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   municipios_df['Coordenadas'][idx] = municipios_df['Coordenadas'][idx].split('/')[0].replace('\ufeff', '').strip()
# 5: 'float' object has no attribute 'split'
# 20: 'float' object has no attribute 'split'

# %%
# Extraer solo el nombre del alcalde de cada municipio (originalmente aparece el año de posesión y el partido político)

for idx in municipios_df.index:
    try:
        municipios_df['Alcalde'][idx] = municipios_df['Alcalde'][idx].split('(')[0].strip()
    except Exception as e:
        print(f"{idx}: {e}")
# Out:
# <ipython-input-431-b1d4e884c15a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   municipios_df['Alcalde'][idx] = municipios_df['Alcalde'][idx].split('(')[0].replace('\ufeff', '').strip()
# 93: 'float' object has no attribute 'split'
# 94: 'float' object has no attribute 'split'
# 200: 'float' object has no attribute 'split'
# 205: 'float' object has no attribute 'split'
# 224: 'float' object has no attribute 'split'
# 255: 'float' object has no attribute 'split'
# 267: 'float' object has no attribute 'split'
# 294: 'float' object has no attribute 'split'
# 327: 'float' object has no attribute 'split'
# 363: 'float' object has no attribute 'split'
# 392: 'float' object has no attribute 'split'
# 409: 'float' object has no attribute 'split'
# 417: 'float' object has no attribute 'split'
# 440: 'float' object has no attribute 'split'
# 457: 'float' object has no attribute 'split'
# 498: 'float' object has no attribute 'split'
# 501: 'float' object has no attribute 'split'
# 504: 'float' object has no attribute 'split'
# 524: 'float' object has no attribute 'split'
# 540: 'float' object has no attribute 'split'
# 553: 'float' object has no attribute 'split'
# 578: 'float' object has no attribute 'split'
# 601: 'float' object has no attribute 'split'
# 612: 'float' object has no attribute 'split'
# 629: 'float' object has no attribute 'split'
# 638: 'float' object has no attribute 'split'
# 676: 'float' object has no attribute 'split'
# 682: 'float' object has no attribute 'split'
# 698: 'float' object has no attribute 'split'
# 716: 'float' object has no attribute 'split'
# 792: 'float' object has no attribute 'split'
# 818: 'float' object has no attribute 'split'
# 897: 'float' object has no attribute 'split'
# 956: 'float' object has no attribute 'split'
# 1017: 'float' object has no attribute 'split'
# 1020: 'float' object has no attribute 'split'
# 1025: 'float' object has no attribute 'split'
# 1036: 'float' object has no attribute 'split'
# 1066: 'float' object has no attribute 'split'
# 1080: 'float' object has no attribute 'split'
# 1082: 'float' object has no attribute 'split'
# 1084: 'float' object has no attribute 'split'
# 1096: 'float' object has no attribute 'split'
# 1102: 'float' object has no attribute 'split'
# 1110: 'float' object has no attribute 'split'
# 1112: 'float' object has no attribute 'split'
# 1113: 'float' object has no attribute 'split'
# 1117: 'float' object has no attribute 'split'

# %%
# En el caso de las columnas de huso horario, país y entidad los valores son iguales para todos los indices, es decir,
# Uso horario: UTC -5, Entidad: Municipio y País: Colombia. Se usa esta información para rellenar los valores nulos.

municipios_df['Huso horario'].fillna("UTC -5", inplace=True)
municipios_df['Entidad'].fillna("Municipio", inplace=True)
municipios_df['País'].fillna("Colombia", inplace=True)

# %%
# Cambiar el orden de las columnas dependiendo de la relevancia de la información contenida.

municipios_df = municipios_df[['Municipio', 'Departamento', 'Entidad', 'País', 'Fundación', 'Erección', 'Superficie (km²)',
                              'Altitud Media (m.s.n.m)', 'Población Total (hab)', 'Pobl. Urbana (hab)', 'Densidad (hab/km²)',
                              'Coordenadas', 'Clima', 'Gentilicio', 'Alcalde', 'Código Postal', 'Huso horario']]

# %% [markdown]
# ##### ** ¡Trabajo finalizado! Ahora, guardar los datos en formato CSV **

# %%
# Guardar datos en formato CSV

municipios_df.to_csv("municipios_colombia_df.csv")
